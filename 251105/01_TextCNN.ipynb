# %% [markdown]
# ### 연습문제 복습
# - ratings_train.txt 데이터 로드
# - document 컬럼의 결측치 제거
# - 텍스트 정규화(특수문자 제거, 2칸 이상의 공백 제거, 문자열 좌우 공백 제거)
# - document 컬럼의 중복 데이터 제거
# - 데이터프레임의 상위 1000개의 데이터만 사용
# - texts -> document 컬럼의 values 대입
# - labels -> label 컬럼의 values 대입
# - 토큰화 (Komoran)
#     - 품사 선택: NNP, NNG, VV, VA, MAG, XR
#     - 불용어: '하다', '되다', '이다'
# - 단어 사전 생성
#     - 사전 이름 vocab
#     - 단어들의 최소 출현 횟수 2회
#     - 단어 사전 생성 시 \<PAD>, \<UNK>를 가장 앞에 지정
# - 토큰화된 문서들을 단어 사전의 위치값에 맞게 인코딩
#     - enc_inputs 리스트에 저장

# %%
import pandas as pd
import numpy as np
import re
from konlpy.tag import Komoran
from collections import Counter
import torch
from sklearn.model_selection import train_test_split

# %% [markdown]
# ratings_train.txt 데이터 로드

# %%
df = pd.read_csv("../data/ratings_train.txt", sep='\t')
df.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB

# %%
df.isna().sum()
# Out:
# id          0
# document    5
# label       0
# dtype: int64

# %% [markdown]
# document 컬럼의 결측치 제거

# %%
df.dropna(subset='document', inplace=True)
df.isna().sum()
# Out:
# id          0
# document    0
# label       0
# dtype: int64

# %% [markdown]
# 텍스트 정규화(특수문자 제거, 2칸 이상의 공백 제거, 문자열 좌우 공백 제거)

# %%
def normalize(text):
    text = re.sub(r"[^가-힣0-9a-zA-Z\s\.]", " ", str(text))
    text = re.sub(r"\s+", " ", text).strip()
    return text

# normalize() 함수는 데이터에 결측치 있으면 Error 발생함

# %% [markdown]
# 방법 1. document 컬럼의 텍스트만 정규화 $\rightarrow$ Series 데이터에서 `normalize()` 함수를 실행
# </br>방법 2. 여러 컬럼의 텍스트를 정규화 $\rightarrow$ DataFrame 데이터에서 `normalize()` 함수를 실행
# </br>방법 3. 전체 데이터프레임을 정규화

# %%
# 방법 1.
# Series 데이터에서 각각의 value들을 normalize()에 대입
df['document'] = df['document'].map(normalize)
# --> 결과를 df['document']에 대입해야 함

# %%
# 방법 2.
# DataFrame 데이터에서 각각의 value들을 normalize()에 대입
# 'id' 컬럼은 숫자형이므로 str로 변환
# map보다 applymap 추천

# df[ ['id', 'document'] ].astype(str).applymap(normalize)

# --> 결과를 df에 대입하면 label 컬럼 사라짐
# ---> 결과를 df[ ['id', 'document'] ]에 대입해야 함

# %%
# 방법 3.
# 전체 데이터프레임 정규화

# df.applymap(normalize)

# %% [markdown]
# document 컬럼의 중복 데이터 제거

# %%
df.drop_duplicates(subset='document', inplace= True)
df
# Out:
#               id                                           document  label
# 0        9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1        3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2       10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3        9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4        6483659  사이몬페그의 익살스런 연기가 돋보였던 영화 스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...          ...                                                ...    ...
# 149995   6222902                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996   8549745                                      평점이 너무 낮아서...      1
# 149997   9311800                      이게 뭐요 한국인은 거들먹거리고 필리핀 혼혈은 착하다      0
# 149998   2376369                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999   9619869                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [144734 rows x 3 columns]

# %% [markdown]
# 데이터프레임의 상위 1000개의 데이터만 사용

# %%
# df = df[:1000]
df = df.head(1000).copy()

# %% [markdown]
# 토큰화 (Komoran)
# - 품사 선택: NNP, NNG, VV, VA, MAG, XR
# - 불용어: '하다', '되다', '이다'

# %%
komoran = Komoran()

allow_pos = ['NNP', 'NNG', 'VV', 'VA', 'MAG', 'XR']
stop_word = ['하다', '되다', '이다']

def tokenize(doc):
    tokens = []
    for word, pos in komoran.pos(doc):
        if pos in allow_pos and word not in stop_word:
            tokens.append(word)
    return tokens

# %% [markdown]
# texts -> document 컬럼의 values 대입
# </br> labels -> label 컬럼의 values 대입

# %%
texts, labels = df['document'].values, df['label'].values

# texts들을 이용하여 토큰화 
tokens_list = [ tokenize(doc) for doc in texts ]
tokens_list
# Out:
# [['더빙', '진짜', '짜증', '나', '목소리'],
#  ['포스터', '초딩', '영화', '오버', '연기', '가볍'],
#  [],
#  ['교도소', '이야기', '솔직히', '재미', '없', '평점', '조정'],
#  ['익살', '연기', '돋보이', '영화', '스파이더맨', '늙', '보이', '하', '커스틴 던스트', '너무나'],
#  ['막', '걸음마', '떼', '초등학교', '학년', '용', '영화', '별', '반개', '아깝'],
#  ['원작', '긴장감', '제대로', '살리'],
#  ['반개',
#   '아깝',
#   '욕',
#   '나오',
#   '이응경',
#   '길용우',
#   '연기',
#   '생활',
#   '이',
#   '정말',
#   '발로',
#   '납치',
#   '감금',
#   '반복',
#   '반복',
#   '이',
#   '드라마',
#   '가족',
#   '없',
#   '연기',
#   '못하',
#   '사람',
#   '모이'],
#  ['액션', '없', '재미', '있', '안', '영화'],
#  ['왜', '평점', '낮', '꽤', '보', '헐리우드', '화려', '너무', '길들이', '있'],
#  [],
#  ['볼', '때', '눈물', '나서', '죽', '향수', '자극', '허진호', '감성', '절제', '멜로', '달인'],
#  ['울', '손들', '횡단보도', '건너', '때', '뛰쳐나오', '이범수', '연기', '드럽'],
#  ['담백', '깔끔', '좋', '신문', '기사', '로만', '보다', '보', '자꾸', '잊어버리', '사람'],
#  ['취향',
#   '존중',
#   '진짜',
#   '극장',
#   '보',
#   '영화',
#   '가장',
#   '노',
#   '재',
#   '노',
#   '감동',
#   '스토리',
#   '어거지',
#   '감동',
#   '어거지'],
#  ['매번', '긴장'],
#  ['참',
#   '사람',
#   '웃기',
#   '바스코',
#   '이기',
#   '락스',
#   '코',
#   '까',
#   '고',
#   '바비',
#   '이기',
#   '아이돌',
#   '깔',
#   '그냥',
#   '까',
#   '안달',
#   '난',
#   '보이'],
#  ['굿바이 레닌', '표절', '이해', '왜', '뒤', '갈수록', '재미없'],
#  ['이건',
#   '정말',
#   '깨알',
#   '캐스팅',
#   '질퍽',
#   '산뜻',
#   '내용',
#   '구성',
#   '잘',
#   '버',
#   '러',
#   '진',
#   '깨알',
#   '드'],
#  ['약탈', '위하', '변명', '착하', '절대'],
#  ['심오', '뜻', '있', '그냥', '학생', '선생', '놀아나', '영화', '절대'],
#  ['보', '웃', '가능'],
#  ['재미없',
#   '지루',
#   '같',
#   '음식',
#   '영화',
#   '만찬',
#   '넘',
#   '만찬',
#   '이야기',
#   '있',
#   '음식',
#   '보',
#   '재미',
#   '있',
#   '이건',
#   '보',
#   '없',
#   '음식',
#   '별로',
#   '안',
#   '나오',
#   '핀란드',
#   '풍경',
#   '별로',
#   '안',
#   '나오'],
#  ['절대', '평범', '영화', '수작', '말씀', '드리'],
#  ['주제', '좋', '중반', '지루'],
#  ['다', '짜르', '납득', '없', '그렇', '꼭', '그렇', '걸', '끄'],
#  ['고추', '털', '하'],
#  ['카밀라', '벨', '발', '연기'],
#  [],
#  ['센스', '있', '연출력', '탁월', '캐스팅', '90년대', '향수'],
#  ['엄',
#   '포스',
#   '위력',
#   '다시',
#   '깨닫',
#   '하',
#   '남',
#   '꽃',
#   '검사',
#   '연기',
#   '정말',
#   '좋',
#   '완전',
#   '명품',
#   '드라마'],
#  ['졸', '쓰레기', '시간', '아깝'],
#  ['재밌', '별점', '왜', '이리', '낮', '은고'],
#  ['라도', '기대', '죄인', '죄인'],
#  ['아직', '드라마', '인생', '최고'],
#  ['패션', '대하', '열정', '안나', '윈', '투어'],
#  ['키이라 나이틀리', '연기', '하', '대체', '정신', '장애', '틱', '장애'],
#  ['원', '작가', '정신', '나가', '유령', '재미있'],
#  ['포스터', '있', '보이', '관객'],
#  ['영화', '왜', '이렇', '평가', '받', '모르'],
#  ['단순', '은은', '매력', '영화'],
#  ['다',
#   '알바',
#   '내용',
#   '없',
#   '무섭',
#   '거도',
#   '없',
#   '웃기',
#   '거도',
#   '없',
#   '완전',
#   '별',
#   '싱겁',
#   '영화',
#   '시간',
#   '넘',
#   '아깝',
#   '완전',
#   '낚이'],
#  ['오', '서리', '한', '굶주리'],
#  ['정말', '맘', '들', '보', '보', '방법', '없'],
#  ['윤제문',
#   '멋지',
#   '배우',
#   '발견',
#   '되',
#   '소소',
#   '일탈',
#   '잔잔',
#   '미소',
#   '머금',
#   '음악',
#   '조금',
#   '아쉽',
#   '평점',
#   '올리'],
#  ['평점', '속지', '마시', '길', '시간', '낭비', '돈', '낭비'],
#  ['리얼리티',
#   '뛰어나',
#   '하',
#   '크',
#   '공감',
#   '안',
#   '가',
#   '이민기',
#   '캐릭터',
#   '정신의학',
#   '분노',
#   '조절',
#   '장애',
#   '초기',
#   '증상',
#   '일',
#   '툭하면',
#   '사람',
#   '패',
#   '욕',
#   '물건',
#   '파손',
#   '조금',
#   '오바',
#   '극',
#   '초반',
#   '신선',
#   '가',
#   '갈수록',
#   '이민기',
#   '정신',
#   '상태',
#   '공감',
#   '불가'],
#  ['마이너스', '왜', '없', '보', '영화', '수준', '딱', '알', '북한', '만들', '돈', '대'],
#  ['나', '영화', '사랑합니다'],
#  ['데',
#   '리스',
#   '타르',
#   '가르',
#   '용의',
#   '주인',
#   '되',
#   '누',
#   '이랑',
#   '근친상간',
#   '하',
#   '다니',
#   '소설',
#   '속',
#   '제일',
#   '멋지',
#   '자이',
#   '메',
#   '라',
#   '니스',
#   '드라마',
#   '속',
#   '드래곤',
#   '용',
#   '제일',
#   '멋지',
#   '웃음',
#   '감독',
#   '토르',
#   '다크 월드',
#   '잡수',
#   '기본',
#   '선방',
#   '하'],
#  ['영화',
#   '사람',
#   '영혼',
#   '어루만지',
#   '있',
#   '거치',
#   '세상사',
#   '잠시',
#   '잊',
#   '동화',
#   '같',
#   '영화',
#   '행복'],
#  ['르', '게이', '작', '고추', '매운맛', '보이', '콩', '진호', '간다'],
#  ['이렇', '가슴', '시리', '보', '드라마', '있', '감동', '자체'],
#  ['난', '꼬마', '애가', '원한', '깊', '하', '그냥', '혼자', '나대', '걸', '어쩌'],
#  ['재미있'],
#  ['좋'],
#  ['최고'],
#  ['너무',
#   '충격',
#   '기분',
#   '완전히',
#   '푹',
#   '꺼지',
#   '하',
#   '느낌',
#   '활력',
#   '없',
#   '너무나',
#   '무겁',
#   '지독',
#   '차갑',
#   '자비',
#   '그저',
#   '일본인',
#   '상상력',
#   '정말',
#   '대단',
#   '같',
#   '생각',
#   '들'],
#  ['심심', '영화'],
#  ['백봉기', '언제나', '오'],
#  ['보', '그대로', '들어맞', '예측', '카리스마', '없', '악역'],
#  ['불알', '나오', '당황', '아무튼', '영화', '중간', '끝나', '느낌'],
#  ['평범', '함속', '녹', '아든', '평범', '일상', '조금', '밋밋'],
#  ['보',
#   '계속',
#   '보',
#   '전개도',
#   '느리',
#   '주인공',
#   '은희',
#   '컷',
#   '나오',
#   '소극',
#   '모습',
#   '짜증',
#   '맨날',
#   '언제',
#   '끝나',
#   '기대',
#   '하',
#   '전개',
#   '좀',
#   '빨리빨리'],
#  ['사랑', '가슴속', '오', '감정', '헤집', '영화', '예', '요정', '말', '최고'],
#  ['많',
#   '사람',
#   '다',
#   '큐',
#   '보',
#   '우리나라',
#   '슬프',
#   '현대사',
#   '단면',
#   '대하',
#   '깊이',
#   '생각',
#   '사죄',
#   '바로',
#   '잡기',
#   '위하',
#   '노력',
#   '말',
#   '듣',
#   '보도',
#   '연맹',
#   '민간인',
#   '학살',
#   '이정',
#   '이건',
#   '명백',
#   '살인',
#   '살인자',
#   '다',
#   '있'],
#  ['예전',
#   '작품',
#   '캐릭터',
#   '에피소드',
#   '재탕',
#   '삼탕',
#   '사골',
#   '우려',
#   '먹',
#   '내용',
#   '산',
#   '가',
#   '시청률',
#   '아예',
#   '안',
#   '나오',
#   '이제',
#   '중반'],
#  ['김남길', '연기력', '초반', '몰입', '불구', '지루', '손예진'],
#  ['재밌', '비슷', '영화', '안보', '신', '재미있'],
#  ['노래', '실력', '뽑', '맞', '박시환', '가면', '진짜', '망신'],
#  ['일본', '영화', '다', '유치'],
#  ['이틀',
#   '다',
#   '보',
#   '재밌',
#   '안',
#   '물건',
#   '넣',
#   '조작',
#   '하',
#   '안',
#   '열리',
#   '집',
#   '안',
#   '활짝',
#   '열리',
#   '들어가',
#   '문자',
#   '조작',
#   '비번',
#   '안',
#   '걸리',
#   '억지',
#   '내용',
#   '자체',
#   '좋'],
#  ['졸', '작'],
#  ['달팽이', '빠르', '더', '재밌'],
#  ['어설프', '전개', '어이없', '결말'],
#  ['부패', '로마노프 왕조', '기리', '같', '영화', '온몸', '항거', '러시아', '민중', '그저', '폭', '돌'],
#  ['내용', '전개', '무난', '편이', '잘', '보'],
#  ['매우', '실망'],
#  ['한국',
#   '영화',
#   '흥행',
#   '코드',
#   '갈등',
#   '갈등',
#   '계',
#   '에',
#   '속',
#   '갈등',
#   '화해',
#   '감동',
#   '평점',
#   '남발',
#   '흥행',
#   '뻔하'],
#  ['아햏햏', '아햏햏', '아햏햏'],
#  ['시작', '3분', '나오', '리플릿', '사진', '보', '불안'],
#  ['단연', '최고', '하'],
#  ['감독', '영화', '만들', '관객', '말', '모르', '엉망진창', '개진', '창'],
#  ['이건', '우뢰', '매'],
#  ['정말', '쓰레기', '영화'],
#  ['진정', '위대', '영화', '최고'],
#  ['별루'],
#  ['내일', '기대'],
#  ['조미', '막', '문', '좋아하', '가요'],
#  ['진짜', '골', '까', '눈', '부라리', '때', '쓰러지'],
#  ['성룡', '영화', '최', '악인'],
#  ['골', '때리', '걸스데이', '이혜리', '잘', '되'],
#  ['서기', '이쁘'],
#  ['완전', '재밌', '백인', '공주', '귀여움'],
#  ['인상', '영화'],
#  ['세', '레', '스티', '완전', '강', '추', '정말', '재밌'],
#  ['재미있', '영화'],
#  ['클라라', '볼라', '고', '화신', '본'],
#  ['진짜', '보', '너무', '슬프', '영화'],
#  ['설정', '재밌', '새롭', '에피소드', '메인', '스토리', '차차', '나오', '재밌'],
#  ['신카이 마코토', '작화', '미', '유', '카나', '연기', '잘', '더', '대박', '이'],
#  ['재미없', '진심', '캐스팅'],
#  ['잔잔', '생각', '보', '영화인', '같'],
#  ['감독', '고은님', '쓰', '영화', '안', '보'],
#  ['무섭', '스토리'],
#  ['영화', '속', '억지', '노골적', '술', '광고', '좀', '은은', '센스', '있', '하', '어떻'],
#  ['킬링타임'],
#  ['크리스마스', '떠오르', '영화'],
#  ['재미있', '보', '매력', '행복'],
#  ['음악', '완전히', '빠지', '보', '영화', '쪼', '산만', '하'],
#  ['태어나', '처음', '영화', '중간', '나오', '불륜', '로맨스', '냐'],
#  ['왕', '짜증', '아주', '전개', '짬뽕', '믹스', '음향', '무섭', '하'],
#  ['솔직히', '나', '별루', '덜', '시간', '낭비', '느낌'],
#  ['대박'],
#  ['시청률', '기준', '되', '패널', '가구', '거지', '명작', '드라마', '다', '망치', '다', '서운'],
#  ['내용', '이상해'],
#  ['몬스터 주식회사', '3D', '재밌', '보'],
#  ['내용', '전개', '너무나', '느리'],
#  ['소재', '흥미', '끌', '이야기', '전개', '투박', '몰입', '안'],
#  ['절대', '보지', '마라', '쓰레기', '영화'],
#  ['중국인',
#   '특유',
#   '과장',
#   '허풍',
#   '있',
#   '보이',
#   '안간힘',
#   '쓰',
#   '노력',
#   '가상',
#   '고증',
#   '현실감',
#   '떨어지',
#   '설정',
#   '거북',
#   '도대체',
#   '왜',
#   '이렇',
#   '스스로',
#   '대포',
#   '장하'],
#  ['그냥', '불법체류', '때려잡', '영화', '좋', '텐', '우상', '만들', '미국', '따뜻', '설정', '이건'],
#  ['2년', '삶', '속', '주인공', '생애', '전부', '드러나'],
#  ['별점', '가자'],
#  ['별로', '다'],
#  ['보', '꽤', '지나', '후', '남기', '재미있'],
#  ['아니', '이', '왜', '일'],
#  ['지나', '다시', '보', '되', '영화', '다시', '보', '순수', '사랑', '감동', '쇼', '펜', '연기'],
#  ['올레',
#   '공짜',
#   '있',
#   '보',
#   '허',
#   '스토리',
#   '문제',
#   '연기자',
#   '전혀',
#   '배역',
#   '이랑',
#   '어울리',
#   '상대',
#   '배우',
#   '다',
#   '따로',
#   '같',
#   '이건',
#   '연기자',
#   '문제',
#   '있',
#   '보',
#   '진심',
#   '완전',
#   '별로',
#   '라미란',
#   '아들',
#   '젤',
#   '볼',
#   '하'],
#  ['너무', '욕심', '많', '영화', '제대로', '보이'],
#  ['빵점'],
#  ['베', '말', '아주', '잘', '쓰'],
#  ['아주', '모자', '라진'],
#  ['영화', '도둑들', '뫼비우스', '하', '같', '나라', '만들', '믿'],
#  ['온몸', '찌릿', '짜릿', '용기', '가지'],
#  ['정말', '재미있', '교훈', '영화'],
#  ['당시', '상황', '주제', '주입식', '긴장감', '있', '재밌', '전하', '작품'],
#  ['케이블', '그만', '나오'],
#  ['다르', '냐', '리', '차이밍량', '안', '섞이', '짬뽕', '그릇', '담기'],
#  ['여군', '재', '없', '뭐', '건지', '재', '없', '다', '재', '없', '질리', '다이'],
#  ['좋'],
#  ['한석규', '김혜수', '연기', '돋보이', '영화', '모르', '많이', '어설프', '영화'],
#  ['솔직히',
#   '에볼라바이러스',
#   '떠들석',
#   '보',
#   '되',
#   '영화',
#   '작품',
#   '면',
#   '여',
#   '전',
#   '영화',
#   '믿',
#   '힘들',
#   '정도',
#   '정말',
#   '잘',
#   '만들',
#   '마지막',
#   '후반부',
#   '살짝',
#   '아쉽',
#   '하',
#   '이정',
#   '도면',
#   '수작',
#   '시간',
#   '아깝',
#   '영화'],
#  ['보', '만해'],
#  ['재미있', '허풍', '떨', '마'],
#  ['용가리', '진짜', '짱', '짱', '매'],
#  ['영화',
#   '이제서야',
#   '감히',
#   '인생',
#   '최고',
#   '영화',
#   '하나로',
#   '꼽',
#   '있',
#   '작품',
#   '어떻',
#   '살',
#   '위하',
#   '고민',
#   '더',
#   '하',
#   '되',
#   '시간',
#   '모건 프리먼',
#   '나이',
#   '들',
#   '여전히',
#   '섹시'],
#  ['작가',
#   '별로',
#   '다',
#   '내용',
#   '이',
#   '진짜',
#   '맨날',
#   '그냥',
#   '기대',
#   '재방송',
#   '혹시나',
#   '답',
#   '없',
#   '진짜'],
#  ['명작', '명작', '있', '보', '보', '여운', '남', '영화'],
#  ['진짜',
#   '조금',
#   '더',
#   '손',
#   '좀',
#   '보',
#   '왜',
#   '하',
#   '상업',
#   '영화',
#   '못하',
#   '만들',
#   '아쉽',
#   '충분히',
#   '재미있',
#   '개인',
#   '조금',
#   '더',
#   '잔인',
#   '더',
#   '자극',
#   '노출',
#   '화끈',
#   '하',
#   '어떻',
#   '하',
#   '국산',
#   '영화',
#   '많이',
#   '아끼',
#   '보이'],
#  ['그만', '좀', '끌', '이제', '끝내', '지겹', '지겹'],
#  [],
#  ['드니', '연기', '일품', '맥스', '샘', '죽이', '하'],
#  ['괜찮', '작품'],
#  ['너무', '좋', '영화'],
#  ['정말', '실망'],
#  ['배우',
#   '지',
#   '안',
#   '뜨',
#   '영화',
#   '찍',
#   '껀',
#   '왜',
#   '안',
#   '뜨',
#   '진짜',
#   '모르',
#   '면상',
#   '딱',
#   '보',
#   '알',
#   '왜',
#   '자신',
#   '모르'],
#  ['어린이', '좋아하', '어리', '동심', '멀리', '뜨', '낫'],
#  ['무술', '인', '왜', '총', '들'],
#  [],
#  ['크리스토퍼', '왈츠', '타란티노', '조합'],
#  ['한국', '에선', '유명한', '외국', '상상', '초월', '유명', '영화'],
#  ['오랜만'],
#  ['종',
#   '방',
#   '아쉽',
#   '오늘',
#   '막',
#   '방도',
#   '잘',
#   '보',
#   '방송',
#   '대본',
#   '꽤',
#   '완성도',
#   '있',
#   '느낌',
#   '받',
#   '요즘',
#   '드라마',
#   '막장',
#   '지치',
#   '향',
#   '정말',
#   '바른',
#   '드라마',
#   '악역',
#   '그리',
#   '심하',
#   '어이없',
#   '화이팅'],
#  ['평점',
#   '조절',
#   '위원회',
#   '나오',
#   '웃음',
#   '김혜선',
#   '내일이 오면',
#   '의',
#   '김',
#   '순정',
#   '순정',
#   '역할',
#   '정도',
#   '잘',
#   '해내',
#   '정말',
#   '의외',
#   '연기',
#   '20년',
#   '사람',
#   '요즘',
#   '사극',
#   '벌어지',
#   '있',
#   '대하',
#   '연기',
#   '논란',
#   '왠지',
#   '코미디',
#   '의하',
#   '장면',
#   '같',
#   '웃음'],
#  ['영화', '끝나', '때', '멍하', '다', '보', '한마디', '나오', '같'],
#  ['공유', '존', '잘'],
#  ['상쾌', '발랄', '영화', '말', '끌', '성', '소재', '유쾌', '해설'],
#  ['소파', '죽', '치', '앉', '지키', '보', '이유', '없', '작품'],
#  ['로큰롤'],
#  ['주되',
#   '타겟',
#   '어린이',
#   '일반',
#   '논리',
#   '통하',
#   '알',
#   '게임',
#   '흥미',
#   '요원',
#   '주인공',
#   '너무',
#   '능력',
#   '별로',
#   '재미없',
#   '배경',
#   '거슬리'],
#  ['뮤지컬 영화',
#   '사운드',
#   '녹음',
#   '엉망',
#   '남',
#   '주',
#   '춤',
#   '못',
#   '추',
#   '내용',
#   '뻔하',
#   '주인공',
#   '목소리',
#   '너무',
#   '안',
#   '어울리',
#   '어제',
#   '뛰',
#   '나가',
#   '참',
#   '진심',
#   '말리',
#   '영국',
#   '예산',
#   '영화',
#   '뮤지컬',
#   '영화',
#   '맘마미아',
#   '10',
#   '안'],
#  ['어리', '나이', '보', '꽤', '좋아하', '로맨틱', '코미디'],
#  ['게이', '물', '인줄', '모르', '보'],
#  ['알바', '끄', '절'],
#  ['영화', '왜', '받', '보', '알', '이', '영화', '배우', '스텝', '감독', '꼭두각시'],
#  ['최악'],
#  ['정말', '아름답', '영화', '이'],
#  ['자극', '익숙', '현대인', '보', '눈', '떼', '힘들', '연출력'],
#  ['뻑', '뻑', '잘', '읽', '당하'],
#  ['정말',
#   '짜증',
#   '극치',
#   '보이',
#   '영화',
#   '굉장히',
#   '느낌',
#   '뚱뚱',
#   '못생기',
#   '남자',
#   '애',
#   '발',
#   '연기',
#   '시종일관',
#   '보',
#   '고역',
#   '흘러나오',
#   '잔잔',
#   '클래식',
#   '음악',
#   '조차',
#   '듣',
#   '싫',
#   '짜증',
#   '날',
#   '정도',
#   '상당히',
#   '싫',
#   '영화'],
#  ['감동', '감동', '정말', '최고'],
#  ['별점',
#   '아깝',
#   '얼마나',
#   '내용',
#   '진부',
#   '욕',
#   '밖',
#   '안',
#   '나오',
#   '재밌',
#   '하',
#   '사람',
#   '초딩',
#   '죄송',
#   '너무',
#   '화가',
#   '나서',
#   '보',
#   '없',
#   '보',
#   '마',
#   '그냥',
#   '티',
#   '비판',
#   '짜',
#   '집기',
#   '같'],
#  ['왜', '하', '짜증', '안', '내'],
#  ['돼지', '피', '먹', '닭목', '따', '장면', '에선', '무당', '하'],
#  [],
#  ['유치', '지루', '잠'],
#  ['판타지', '가져가'],
#  ['윤종신',
#   '복귀',
#   '좋',
#   '이하늘',
#   '도대체',
#   '왜',
#   '뽑히',
#   '알',
#   '없',
#   '참가자',
#   '실력',
#   '따지',
#   '전',
#   '심사',
#   '위원',
#   '인격',
#   '실력',
#   '쌓',
#   '오시',
#   '길',
#   '어',
#   '허',
#   '그만',
#   '좀',
#   '하'],
#  ['광장', '작품', '옛날', '보고 싶다'],
#  ['생', '최고', '영화'],
#  ['어리',
#   '시절',
#   '너무',
#   '무섭',
#   '재미있',
#   '보',
#   '추억',
#   '판타지',
#   '영화',
#   '절대',
#   '나쁘',
#   '짓',
#   '금물',
#   '지옥',
#   '가요'],
#  ['기존', '멜로', '영화', '형식', '탈피', '하', '감정', '절제', '지나치', '너무', '담백', '영화'],
#  ['나', '사랑비', '서주', '쏙', '빠지', '쏙', '나', '절대', '잊', '후회', '도안', '할거'],
#  ['이영화', '보', '교훈', '남은', '인생', '화려', '말', '안', '나오'],
#  ['추억', '젖', '좋', '생각', '없이', '가볍', '보', '추천'],
#  ['단순', '싸이코', '물', '벗어나'],
#  ['이', '만들', '가요', '예전', '만들', '다시', '개봉', '한', '가요', '너무', '허', '접하'],
#  ['넘', '사랑', '영화', '보고', '연잇', '보', '넘', '귀여워'],
#  ['청춘 영화',
#   '있',
#   '감성',
#   '넘치',
#   '순간',
#   '지나가',
#   '다시',
#   '돌아오',
#   '테',
#   '순간',
#   '무한',
#   '젊음',
#   '있',
#   '감성'],
#  ['건담', '시리즈', '아직', '최고봉'],
#  ['개코', '요즘', '갈수록', '코너', '달', '재', '웃음', '이안', '나'],
#  ['사다코', '한', '서리', '우물', '펀치', '감동'],
#  ['후세',
#   '사랑',
#   '되',
#   '결정',
#   '계기',
#   '시간',
#   '표현',
#   '생명',
#   '빼앗',
#   '이유',
#   '시노',
#   '출현',
#   '연극',
#   '으',
#   '로',
#   '더',
#   '알리',
#   '하',
#   '생각',
#   '시노',
#   '얼마나',
#   '시랑',
#   '하',
#   '노력',
#   '더',
#   '보이',
#   '좋'],
#  ['새벽',
#   '시간',
#   '하',
#   '일본',
#   '영화',
#   '전부',
#   '개',
#   '졸',
#   '작',
#   '일본',
#   '영화',
#   '원래',
#   '다',
#   '이러'],
#  ['강수연', '나가', '최정원', '신음', '신'],
#  ['정말', '김혜성', '너무', '예쁘', '이현진', '웃', '정말'],
#  ['가발', '쓰'],
#  ['화려', '여', '정', '이인상', '깊', '배두나', '연기', '정말', '잘'],
#  ['10대', '위하', '성적', '호기심', '영화'],
#  ['감동', '영화'],
#  ['이건', '말', '필요', '없', '그냥', '닥치', '보'],
#  ['각기', '사람', '재밌', '멋지', '사랑', '영화'],
#  ['미국', '드라마', '파워', '정말', '알', '수없', '미묘', '사로잡', '최고'],
#  ['너무너무', '훈훈'],
#  ['응답하라', '은지원', '원도', '스스로', '욕'],
#  ['너무', '웃기', '배꼽', '빠지', '컴', '영화', '있'],
#  ['구성', '상당히', '부실', '영화', '네이버', '평점', '믿', '없'],
#  ['장', '끌', '로드', '몰락', '가져오', '오우삼', '헐리우드', '작품', '가장', '재미없', '졸', '작'],
#  ['영웅본색', '연출', '인지', '현실', '제로', '영화'],
#  ['작',
#   '하나에',
#   '설레',
#   '학창',
#   '시절',
#   '그때',
#   '느낌',
#   '다시',
#   '느끼',
#   '시간',
#   '장면',
#   '대사',
#   '배경',
#   '음악',
#   '없',
#   '드라마'],
#  ['진심', '재미', '없', '너무', '평점', '높', '화나'],
#  ['더럽', '재미없', '형태', '오', '닿', '허무', '완벽히', '지루', '영화', '영양가', '없', '영화'],
#  ['이승기', '정말', '연기', '잘', '조연', '연기', '정말', '잘'],
#  ['현실', '꿈', '꿈', '현실'],
#  ['오늘', '현충일', '특집', '프로', '보', '되', '매우', '훌륭', '작품'],
#  ['판', '의미', '동급'],
#  ['제대', '보', '더', '재밌'],
#  ['영화',
#   '보',
#   '마음',
#   '휴가',
#   '다녀오',
#   '느낌',
#   '소',
#   '박',
#   '하지',
#   '잔잔',
#   '지루',
#   '다시',
#   '보',
#   '영화',
#   '햇살',
#   '가득',
#   '이',
#   '부엌',
#   '요리',
#   '인상'],
#  ['코믹', '좋', '짜임새', '너무', '허술'],
#  ['그때',
#   '당시',
#   '나라',
#   '판타지',
#   '로맨스',
#   '없',
#   '아직',
#   '신현준',
#   '황',
#   '장군',
#   '연기',
#   '괜찮',
#   '한석규',
#   '전성시대',
#   '열리',
#   '영화',
#   '이때',
#   '한석규',
#   '뿅',
#   '가'],
#  ['일단', '재생', '괴물', '같', '서스펜스', '귀신', '같', '흡입', '력'],
#  ['진짜',
#   '댓글',
#   '한번쯤',
#   '볼',
#   '영화인',
#   '같',
#   '죽기',
#   '직전',
#   '소원',
#   '들어주',
#   '보',
#   '죽기',
#   '직전',
#   '막',
#   '살',
#   '인',
#   '같',
#   '감동',
#   '없',
#   '진짜',
#   '란',
#   '영화',
#   '발톱',
#   '때',
#   '못',
#   '따라가',
#   '쓰레기',
#   '영화',
#   '와',
#   '존',
#   '실망'],
#  ['시간',
#   '좀',
#   '밝',
#   '긍정',
#   '드라마',
#   '보',
#   '보기',
#   '보',
#   '오버',
#   '연기',
#   '거슬리',
#   '연기',
#   '인',
#   '게',
#   '너무',
#   '표',
#   '요',
#   '홍혜정',
#   '역',
#   '이그',
#   '마도',
#   '후련',
#   '기도',
#   '고시원',
#   '나머지',
#   '들',
#   '답답',
#   '내',
#   '월요일',
#   '해피',
#   '한',
#   '보'],
#  ['정치인', '모순', '인가', '정치범', '모순'],
#  ['어떻', '상상', '대단'],
#  ['좀', '어렵', '하', '전쟁', '대하', '묘사', '잘', '모르'],
#  ['일본', '극장판', '만들', '우리나라', '에선', '개봉', '하니', '이건', '좀'],
#  ['개그콘서트', '보', '전화', '끊', '개그', '콘서트', '없애'],
#  ['한물', '동서양', '배우', '싸움판'],
#  ['푸', '하', '하', '하', '기대', '안'],
#  ['세계', '최초', '반공', '애니매이션', '역사', '가치'],
#  ['감각', '시각', '바라보', '색다르', '느낌', '사랑', '문학'],
#  ['엄마', '무고', '딸', '감옥살이', '시키', '시키', '이해', '안'],
#  ['이영화', '제발', '책', '을', '보세', '감독', '미치', '이', '만들', '화', '날', '정도'],
#  ['신나', '흑인', '음악', '아이스 큐브', '남', '없'],
#  ['드럽', '재미없', '시간', '돈', '시간', '어쩌'],
#  ['그저', '한마디', '알리'],
#  ['진짜', '생생', '느끼'],
#  ['재밌', '평점', '이상', '정도', '낮'],
#  ['옥소리', '프로필', '사진', '남기', '가', '완전', '대박', '진짜', '아우', '짜증'],
#  ['드라마', '너무'],
#  ['아', '진짜', '너무', '좋', '짱', '짱'],
#  ['연기', '굿'],
#  ['영화', '다시', '안', '나오', '그때', '시절', '잘', '나타내', '같'],
#  ['중간', '정도', '보', '꽤', '대단'],
#  ['콩', '까', '제맛', '콩', '까', '제맛'],
#  ['소설', '재미없'],
#  ['액션', '영화', '범죄', '느와르', '영화', '범죄', '느와르', '영화', '실패작'],
#  ['가', '알', '없', '매력', '빠지', '영화'],
#  ['모녀',
#   '토막',
#   '살해',
#   '살인자',
#   '성애',
#   '말이',
#   '감동',
#   '받',
#   '사람',
#   '본인',
#   '피해자',
#   '감동',
#   '받',
#   '하',
#   '진심',
#   '묻'],
#  ['재밌', '평점', '왜', '이렇', '구리지'],
#  ['보', '눈', '아깝', '진짜', '놓', '진짜', '기', '명작'],
#  ['필름', '값', '아깝', '재미', '더럽', '없', '점', '수준', '매미'],
#  ['보'],
#  ['영화', '재미있'],
#  ['남주인공',
#   '연기력',
#   '안',
#   '습',
#   '혀',
#   '짧',
#   '소리',
#   '듣',
#   '너무',
#   '힘들',
#   '매니저',
#   '역활',
#   '분이',
#   '남주인공',
#   '좋',
#   '생각',
#   '들',
#   '정도',
#   '영화',
#   '자체',
#   '적당히',
#   '보',
#   '하'],
#  ['딱', '액션', '스릴러', '액션', '스릴', '없'],
#  ['완전', '스토리', '엉망', '완전', '추'],
#  ['영화', '전달', '모르', '오', '글', '거리'],
#  ['좋', '영화'],
#  ['더빙', '이상', '할머니', '월래', '익숙'],
#  ['이', '나오'],
#  ['게', '씩', '다', '부족', '씩'],
#  ['정말', '말', '그대로', '쇼', '하', '영화'],
#  ['전', '보', '기억', '진개', '천카이거', '감독', '이름', '기억', '두'],
#  ['정은지', '언니', '연기', '잘', '노래', '잘', '부르', '마지막', '웃', '즐겁', '보', '트로트의 연인'],
#  ['이'],
#  ['망하'],
#  ['아이', '시선', '보', '전쟁', '보', '내내', '가슴', '먹먹'],
#  ['사람',
#   '재미없',
#   '하',
#   '레알',
#   '기대',
#   '안',
#   '생각',
#   '보',
#   '여자',
#   '애',
#   '복순이',
#   '다투',
#   '장면',
#   '굳이',
#   '없',
#   '되',
#   '생각',
#   '몰입',
#   '겁나',
#   '없애',
#   '어색',
#   '보이'],
#  ['설정', '연속극', '같', '느낌', '들', '배우', '연기', '뛰어나'],
#  ['여주인공', '인터뷰', '때', '지루', '죽', '알', '그냥저냥', '킬링타임', '스릴러'],
#  ['미',
#   '박스',
#   '오피스',
#   '그냥',
#   '몰아주',
#   '하',
#   '어떻',
#   '영화',
#   '하',
#   '옛날',
#   '90년대',
#   '우뢰',
#   '매',
#   '수준',
#   '물',
#   '폭탄',
#   '싸움',
#   '손',
#   '빔',
#   '가나',
#   '손',
#   '물',
#   '폭탄',
#   '나가',
#   '다르'],
#  ['감독', '여자', '다', '보니', '기량', '많이', '딸리'],
#  ['보'],
#  ['영화', '개연', '없', '허무', '만들', '조디', '포스터', '이쁘', '모습', '남', '영화'],
#  ['굳', '굳'],
#  ['스토리',
#   '말',
#   '안',
#   '개막',
#   '장',
#   '사랑이야',
#   '기도',
#   '아니',
#   '예',
#   '보',
#   '시간',
#   '돈',
#   '아끼',
#   '예',
#   '휴',
#   '보',
#   '호구'],
#  ['살리', '쌀', '아깝', '세기', '대사'],
#  ['평점',
#   '너무',
#   '높',
#   '전혀',
#   '재미있',
#   '쓸데없이',
#   '말',
#   '많',
#   '류',
#   '영화',
#   '조연',
#   '뒷받침',
#   '중요',
#   '조연',
#   '내용',
#   '자체',
#   '전혀',
#   '없',
#   '여배우',
#   '별로',
#   '매력',
#   '없',
#   '이틀',
#   '전',
#   '저스트',
#   '고위',
#   '드',
#   '잇',
#   '애니',
#   '스톤',
#   '보',
#   '영화',
#   '보',
#   '그렇',
#   '실망'],
#  ['맛깔', '드라마'],
#  ['시베리아', '인가', '가', '훈련', '때', '나오', '작살'],
#  ['이건',
#   '시종일관',
#   '왜',
#   '제목',
#   '야경꾼 일지',
#   '냐',
#   '지금',
#   '넘어가',
#   '달',
#   '넘어가',
#   '앞',
#   '누',
#   '군가',
#   '얘기',
#   '하',
#   '더',
#   '그렇',
#   '순간',
#   '훅',
#   '진짜',
#   '지루함',
#   '지존'],
#  ['나이', '들', '이해', '가', '영화'],
#  ['슬픔'],
#  ['장면',
#   '개연',
#   '없',
#   '아역',
#   '연기',
#   '추노',
#   '나오',
#   '민폐',
#   '언',
#   '외국',
#   '판',
#   '인줄',
#   '초반',
#   '그럴싸',
#   '저급',
#   '영화'],
#  ['영화', '정말', '별루', '예', '결말', '이상'],
#  ['딱히', '재미', '없'],
#  ['송강호', '정말', '연기', '하', '위하', '태어나', '인하', '즐거움', '느끼', '송강호', '연기', '파다'],
#  ['일본', '영화', '수입', '금지', '시절', '비디오', '테이프', '돌리', '불후의 명작', '그립'],
#  ['살인',
#   '소재',
#   '영화',
#   '이토록',
#   '재밌',
#   '살인',
#   '대하',
#   '감독',
#   '해석',
#   '정말',
#   '재치',
#   '있',
#   '배우',
#   '여',
#   '전',
#   '모습',
#   '정말',
#   '유쾌',
#   '재밌'],
#  ['누', '미', '라파스', '신봉선', '닮', '안', '보'],
#  ['케이블', '그만', '좀', '재탕'],
#  ['멋지', '정말', '멋지', '말', '이외', '하', '말', '없'],
#  ['어떻', '영화', '만들', '의문', '당대', '최고', '영화', '지금', '보', '결코', '떨어지'],
#  ['지금', '티', '비', '돈', '내', '보', '한심'],
#  ['쓰레기', '연예인', '재기', '장'],
#  ['굿', '좋'],
#  ['많', '감동', '드라마'],
#  ['발로',
#   '만들',
#   '영화',
#   '지진',
#   '나서',
#   '주인공',
#   '넘어지',
#   '뒤',
#   '사람',
#   '유유히',
#   '걷',
#   '다니',
#   '있',
#   '발',
#   'CG',
#   '발',
#   '연기',
#   '발',
#   '시나리오',
#   '내용',
#   '정말',
#   '같'],
#  ['적당히', '하', '언제', '끝나'],
#  ['잊', '없', '안개', '끼', '워터', '다리', '마스코트'],
#  ['곤',
#   '사토시',
#   '감독',
#   '안타깝',
#   '돌아가',
#   '가슴',
#   '먹먹',
#   '정말',
#   '천재',
#   '감독',
#   '암',
#   '가',
#   '이제',
#   '와서',
#   '다시',
#   '보',
#   '작품',
#   '대작'],
#  ['많', '생각', '하', '되', '예', '뼈', '지', '맘', '과', '독'],
#  ['없', '줄'],
#  ['어리',
#   '때',
#   '영화로',
#   '알',
#   '나이',
#   '들',
#   '이',
#   '인생',
#   '하',
#   '뭉클',
#   '영화',
#   '세상',
#   '살아가',
#   '갈수록',
#   '오',
#   '닿',
#   '많',
#   '세상',
#   '비정',
#   '비정',
#   '함마',
#   '지',
#   '따뜻',
#   '친구'],
#  ['영상', '너무나', '멋지'],
#  ['비디오', '있', '보', '1997년', '도인', '줄', '모르', '정도', '잘', '만들', '긴장감', '있'],
#  ['처'],
#  ['만들',
#   '재밌',
#   '영화',
#   '길',
#   '좀',
#   '다듬',
#   '소재',
#   '좋',
#   '몰입',
#   '감',
#   '기대',
#   '이상',
#   '매끄럽',
#   '부분',
#   '있',
#   '연기',
#   '다',
#   '잘'],
#  ['철',
#   '지나',
#   '코미디',
#   '뼈대',
#   '있',
#   '가문',
#   '이야기',
#   '섞',
#   '다',
#   '지루',
#   '박정아',
#   '비롯',
#   '배우',
#   '보',
#   '민망',
#   '연기',
#   '펼치',
#   '기억',
#   '남',
#   '없'],
#  ['군더더기', '없이', '잘', '진행', '재미', '없', '문제'],
#  ['심심', '재밌', '탑', '연기', '알', '배우', '포스', '잘'],
#  ['다', '미', '괜찮'],
#  ['지대', '짜증', '아빠', '보', '앗', '민망', '죽'],
#  ['못', '주'],
#  ['빠', '순이', '영화'],
#  ['최악', '애니메이션', '지루', '재미없', '스토리', '진부'],
#  ['좋', '의도', '다르', '불쾌', '표현법'],
#  ['줄리아', '로버츠', '귀엽', '연인', '5년', '전'],
#  ['신선'],
#  ['예술가', '사람', '인생', '당시', '시대', '상황', '느끼', '명작'],
#  ['관객', '너무', '아쉽', '영화', '베테랑', '더', '류승완', '감독', '역작', '더', '강하', '악역'],
#  ['한창', '핵', '펭귄', '남북', '거짓', '평화로', '전', '국민', '속', '때', '만들', '영화'],
#  ['지금', '티', '비', '못', '보'],
#  ['여자', '애', '못', '해서', '죽', '답', '없'],
#  ['성룡', '단연', '최', '고지'],
#  ['안', '습'],
#  ['감독', '의도', '전혀', '알아차리'],
#  ['하나님',
#   '이',
#   '가정',
#   '을',
#   '온전히',
#   '만들',
#   '진리',
#   '이신',
#   '분이',
#   '만들',
#   '영화',
#   '눈',
#   '보',
#   '마음',
#   '보'],
#  ['흥미진진', '피', '헤드', '죽', '좀', '아쉽'],
#  ['국산', '코미디', '영화', '나', '신라', '달밤', '제일', '좋', '뭐', '푸근', '따뜻'],
#  ['최악', '영화', '잠', '오기', '첨', '지루', '해', '둑', '을'],
#  ['탄탄', '배우', '되', '걸'],
#  ['영화', '점점', '끝', '달려가', '몰입', '도가', '더', '높', '영화', '이번', '처음'],
#  ['결국',
#   '감독',
#   '자신',
#   '하',
#   '의견',
#   '지존파',
#   '핑계',
#   '삼',
#   '하',
#   '지존파',
#   '살인',
#   '정당화',
#   '정부',
#   '탓',
#   '사회',
#   '탓'],
#  ['사실',
#   '여부',
#   '떠나',
#   '알',
#   '아더',
#   '너무',
#   '안',
#   '덜',
#   '원탁',
#   '기사',
#   '실제',
#   '검술',
#   '최고',
#   '랜스',
#   '롯',
#   '알',
#   '있',
#   '트리스탄',
#   '싸우',
#   '검술',
#   '마치',
#   '중국',
#   '검술',
#   '흉내',
#   '내',
#   '같',
#   '란슬롯',
#   '실제',
#   '쌍',
#   '검',
#   '너무',
#   '안대',
#   '하트',
#   '기',
#   '비',
#   '어역',
#   '미스'],
#  ['대한민국', '영화', '수준', '평균', '하락', '충분', '급', '영상물'],
#  ['없'],
#  ['재밌'],
#  ['재미없', '기대', '완전', '하', '완전', '실망'],
#  ['종착역', '없', '인생', '대유', '트레비', '슬', '단지', '흘러가'],
#  ['돈', '시간', '아깝', '영화'],
#  ['없', '예쁘', '음악', '동영상', '취미', '영화', '만들', '끝나', '잘', '음악', '올인', '하기'],
#  ['배우', '연기', '좋', '말', '하', '걸'],
#  ['학위',
#   '위조',
#   '성범죄',
#   '문제',
#   '자',
#   '모으',
#   '영화',
#   '찍',
#   '왜',
#   '그러',
#   '으',
#   '까',
#   '제작비',
#   '아끼',
#   '패자부활전',
#   '하'],
#  ['솔직히'],
#  ['완전', '재미있', '애', '보', '알맞'],
#  ['잔인', '하', '무섭', '탑', '멋있'],
#  ['무섭', '기분', '나쁘'],
#  ['군더더기', '없', '깔끔', '강하', '메세지', '전달', '뜻밖', '참', '좋', '영화'],
#  ['영화', '최고', '그냥', '최고', '알'],
#  ['그랜드 부다페스트 호텔', '시리즈', '같', '캐스팅', '아깝'],
#  ['빨리', '감기', '보', '투자비', '많이', '들', '같', '영화사', '망하'],
#  ['도대체',
#   '재밌',
#   '건지',
#   '모르',
#   '아이언맨',
#   '시리즈',
#   '개그',
#   '뛰어넘',
#   '하',
#   '웃',
#   '모르',
#   '내용',
#   '뜨',
#   '금',
#   '없',
#   '히어로',
#   '놀이',
#   '왜',
#   '이렇',
#   '평점',
#   '높',
#   '모르'],
#  ['왜',
#   '극',
#   '끌어가',
#   '중심',
#   '있',
#   '캐릭터',
#   '있',
#   '하',
#   '알',
#   '되',
#   '영화',
#   '살인마',
#   '대적',
#   '사건',
#   '해결',
#   '인물',
#   '없',
#   '왜',
#   '마지막',
#   '다',
#   '탈출',
#   '하',
#   '나서',
#   '잡히',
#   '죽이',
#   '당하',
#   '이해',
#   '없',
#   '대체',
#   '조달환',
#   '정유미',
#   '왜',
#   '나오'],
#  ['짜', '리얼', '쓰레기', '영화', '다', '보', '나', '정말', '영화', '절대', '보'],
#  ['비록',
#   '로봇',
#   '점차',
#   '인간',
#   '감정',
#   '가지',
#   '자신',
#   '대하',
#   '고민',
#   '결국',
#   '인간',
#   '되',
#   '죽',
#   '앤드',
#   '류',
#   '모습',
#   '보',
#   '영화',
#   '최고',
#   '감동',
#   '선사',
#   '영화'],
#  ['영구', '땡칠이', '시리즈', '레전드', '영화'],
#  ['초딩',
#   '때',
#   '친척',
#   '비디오',
#   '빌리',
#   '보',
#   '기억',
#   '나',
#   '너무',
#   '재미',
#   '없',
#   '나중',
#   '우연히',
#   '다시',
#   '보니',
#   '재밌',
#   '때',
#   '왜',
#   '그렇',
#   '재미',
#   '없',
#   '초등학교',
#   '학년',
#   '때',
#   '사촌',
#   '당시',
#   '최신',
#   '비디오',
#   '빌리',
#   '같'],
#  ['지루', '고요', '서글프', '선속', '머물', '깊', '성찰', '사색'],
#  ['영화', '진짜', '보', '펑펑', '울', '너무', '슬프', '같'],
#  ['더', '혀', '짧', '내기', '박빙', '일', '같'],
#  ['애', '딸리', '심은하', '눈부시', '미모', '아름답', '영상', '메인 주', '제가'],
#  ['나오',
#   '아직',
#   '안',
#   '풀리',
#   '이야기',
#   '많',
#   '극장판',
#   '정말',
#   '시간',
#   '가',
#   '모르',
#   '보',
#   '싸',
#   '패'],
#  ['노', '재', '스토리', '부족', '다', '이상', '진짜'],
#  ['답', '없', '뭐'],
#  ['절망', '슬픔', '속', '자신', '챙기', '삶', '잔인', '거부', '비참', '대하'],
#  ['페이스', '허', '같'],
#  ['시간', '흐르', '퇴색', '맛', '있', '영화'],
#  ['진짜', '어마어마', '여운', '멜로', '영화'],
#  ['소피',
#   '마르',
#   '소',
#   '말',
#   '같',
#   '불륜',
#   '내용',
#   '다',
#   '망치',
#   '물론',
#   '실제',
#   '역사',
#   '똥',
#   '같',
#   '이야기',
#   '전혀',
#   '없',
#   '주인공',
#   '죽',
#   '때',
#   '공주',
#   '한마디',
#   '만약',
#   '미국인',
#   '맞서',
#   '싸우',
#   '아메리칸',
#   '원주민',
#   '자유',
#   '투쟁기',
#   '절대',
#   '아카데미상',
#   '못',
#   '받'],
#  ['훈훈', '따뜻', '부정', '느끼', '잇'],
#  ['재'],
#  ['정말', '재미있', '보'],
#  ['일어나',
#   '일',
#   '같',
#   '느낌',
#   '강하',
#   '우',
#   '베',
#   '볼',
#   '영화',
#   '만들',
#   '이유',
#   '누',
#   '군가',
#   '실제로',
#   '따르',
#   '하',
#   '하',
#   '바라',
#   '같',
#   '정장',
#   '있',
#   '애',
#   '보',
#   '웃'],
#  ['개봉', '당시', '극장', '보', '영화', '내내', '오우삼', '쥑이'],
#  ['견자단', '대박', '엽문', '시리즈', '계속'],
#  ['정말',
#   '오월',
#   '멜로',
#   '정말로',
#   '보',
#   '또',
#   '보',
#   '계속',
#   '보',
#   '영화',
#   '순위',
#   '순위',
#   '다',
#   '하',
#   '늦',
#   '밤',
#   '그런지',
#   '야릇',
#   '느낌',
#   '들'],
#  ['흥미', '보', '여배우들', '이쁘', '반하'],
#  ['스토리', '액션', '그래픽', '건지', '없', '망', '작', '그냥', '게임'],
#  ['그냥', '레전드', '레전드'],
#  ['평론가',
#   '명치',
#   '겁나',
#   '때리',
#   '정말',
#   '영화',
#   '재미없',
#   '생각',
#   '재미',
#   '있',
#   '인생',
#   '도움',
#   '가장',
#   '크',
#   '영화',
#   '본인',
#   '깨닫',
#   '꼭',
#   '보',
#   '인생',
#   '바꾸'],
#  ['키아누 리브스', '최고', '액션 영화'],
#  ['소재',
#   '아름답',
#   '영화',
#   '다소',
#   '아쉽',
#   '부분',
#   '있',
#   '이유',
#   '영화',
#   '영화',
#   '극',
#   '로맨스',
#   '좀',
#   '더',
#   '사실',
#   '남자',
#   '마음',
#   '시선',
#   '말'],
#  ['영화', '평론가', '좋', '한번', '보', '영화', '울림', '있', '영화'],
#  ['효', '느', '재밌', '재탕'],
#  ['4대강'],
#  ['간첩', '색', '휘', '애쓰', '밥', '먹', '다니'],
#  ['좀', '검증', '애', '좀', '출현', '라', '이탈리아', '특집', '장난'],
#  ['정말', '짜증', '절', '때', '보지', '말', '욕', '나오'],
#  ['슬프'],
#  ['최', '악의', '환경', '속', '만화', '만들', '사람', '경의', '보내'],
#  [],
#  ['여운', '엄청', '길', '남', '영화', '이이경', '사랑', '영화'],
#  ['한국', '영화'],
#  ['짜', '이'],
#  ['굿', '이상', '가나', '다라'],
#  ['짱',
#   '혼자',
#   '자식',
#   '키우',
#   '살아오',
#   '엄마',
#   '아들',
#   '힘들',
#   '살아오',
#   '서로',
#   '예민',
#   '날카롭',
#   '때',
#   '잇',
#   '결국',
#   '가족',
#   '아빠',
#   '사람',
#   '생각',
#   '최악',
#   '여자',
#   '확실히',
#   '요구',
#   '도와주',
#   '말',
#   '왠지',
#   '짜',
#   '하',
#   '닿',
#   '혼자',
#   '괜히',
#   '끙끙거리',
#   '단순',
#   '생각',
#   '이든'],
#  ['별로', '전개도', '별로', '연기', '별로', '한마디', '재미없'],
#  ['지수', '잃', '갈팡질팡'],
#  [],
#  ['너무', '사랑', '감동', '영화', '정말', '좋'],
#  ['최', '고의', '영화'],
#  ['13년',
#   '전',
#   '영화',
#   '다시',
#   '보니',
#   '공효진',
#   '코',
#   '평수',
#   '줄이',
#   '콧대',
#   '높이',
#   '완전',
#   '못',
#   '생기',
#   '권상우',
#   '화산고',
#   '때',
#   '왼쪽',
#   '팔자',
#   '심하',
#   '지금',
#   '사라지',
#   '더',
#   '잘',
#   '생기',
#   '장혁',
#   '멋지',
#   '늙',
#   '다시',
#   '보니'],
#  ['말랑말랑'],
#  ['공부', '열심히', '하', '공부', '안', '인생', '사'],
#  ['그냥', '최고'],
#  ['전쟁',
#   '이후',
#   '아픔',
#   '잘',
#   '그린',
#   '영화',
#   '마지막',
#   '장면',
#   '압권',
#   '유대인',
#   '알',
#   '더럽',
#   '도움',
#   '필요',
#   '하니',
#   '동행',
#   '토마스',
#   '더럽',
#   '유태인',
#   '말',
#   '장면',
#   '유대인',
#   '인척',
#   '한',
#   '사실',
#   '유대인',
#   '가족사진',
#   '보',
#   '미묘',
#   '감정',
#   '사슴',
#   '인형',
#   '밟',
#   '까',
#   '변한',
#   '다',
#   '므',
#   '찌',
#   '영화'],
#  ['오랜만', '동화', '다운', '동화', '보', '기분'],
#  ['감사', '정말로', '감사'],
#  ['변태'],
#  ['샤넬', '인생', '성공', '샤넬', '남자들'],
#  ['영화', '내용', '없'],
#  ['십수',
#   '세월',
#   '찰나',
#   '순간',
#   '찰나',
#   '순간',
#   '영원',
#   '기억',
#   '남기',
#   '시간',
#   '상대',
#   '이론',
#   '관하'],
#  ['니노', '이중', '인격', '연기', '두근거리'],
#  ['보', '울컥', '핫', '영화', '재미', '있', '멀', '감동'],
#  ['열정', '돌진', '만들', '영화'],
#  ['연기력', '유혹'],
#  ['난감', '재미', '없', '세상', '깜짝', '놀라', '하', '센세이션', '없'],
#  ['아무리', '노력', '차이나타운', '을', '대놓고', '베끼', '용서', '안', '되'],
#  ['신화', '화이팅', '에릭', '화이팅', '모두', '힘내'],
#  ['엔', '딩', '넘', '슬프'],
#  ['영화관', '가', '보', '더', '좋', '어리', '시절', '돌아가', '느낌', '들', '만감'],
#  ['정말', '최고', '이민정', '신하균', '연기', '너무', '좋'],
#  ['안', '재밌', '보', '영화'],
#  ['교양',
#   '시간',
#   '보',
#   '좀',
#   '충격',
#   '먹',
#   '영화',
#   '마지막',
#   '너무',
#   '슬프',
#   '빨갱이',
#   '소리',
#   '지르',
#   '몰',
#   '초가',
#   '갑자기',
#   '단어',
#   '말',
#   '선생님',
#   '대하',
#   '그리움',
#   '미안',
#   '슬픔',
#   '몰',
#   '초가',
#   '마지막',
#   '좀',
#   '울먹이',
#   '같',
#   '하'],
#  ['잘', '보'],
#  ['안', '무섭', '귀신', '애기', '건지', '그냥', '까', '놀', '하기'],
#  ['뭐', '쥐', '다', '어설프'],
#  ['배우', '따뜻', '연기', '일상', '힘겹', '그리', '현실감', '다', '좋'],
#  ['남자',
#   '배우',
#   '정말',
#   '미스',
#   '캐스팅',
#   '연기력',
#   '안',
#   '습',
#   '조은숙',
#   '김유미',
#   '연기',
#   '참',
#   '보'],
#  ['세계',
#   '대전',
#   '피고',
#   '청춘',
#   '무기',
#   '기술력',
#   '세기',
#   '전쟁',
#   '일으키',
#   '정치인',
#   '전쟁',
#   '지휘',
#   '고위',
#   '장교',
#   '생각',
#   '19세기'],
#  ['책', '분명히', '시선', '괜찮'],
#  ['왜', '보', '한예슬', '이랑', '김태희', '나오', '보', '월도'],
#  ['솔직히', '때', '약간', '더럽', '장면', '빼', '정', '도다'],
#  ['오', '연서', '신인', '연기력', '잘', '보', '다음', '작품', '뵙', '바라'],
#  ['반전', '전부', '영화', '몇 번을', '보', '보', '영화'],
#  ['피해자', '있', '피의자', '없'],
#  ['개',
#   '답답',
#   '멀',
#   '주인공',
#   '지',
#   '혼자',
#   '복수',
#   '주변',
#   '해주',
#   '길',
#   '바라',
#   '민폐',
#   '녀',
#   '아직',
#   '끌리',
#   '다니'],
#  ['신선', '소재', '화끈', '액션', '스피디', '전개'],
#  ['영화',
#   '박자',
#   '디테일',
#   '정말',
#   '시가전',
#   '완벽',
#   '남자',
#   '사랑',
#   '대하',
#   '묘사',
#   '작중',
#   '한석규',
#   '누',
#   '군가',
#   '사랑',
#   '마음',
#   '정말',
#   '디테일',
#   '대단',
#   '마지막',
#   '얘기',
#   '완급',
#   '조절',
#   '완벽',
#   '영화',
#   '정말',
#   '멋지'],
#  ['탕웨이', '찡', '주기', '충분'],
#  ['감동', '영화'],
#  ['당시', '대박', '치', '영화', '괜찮'],
#  ['억지',
#   '시나리오',
#   '지루',
#   '전개',
#   '보다',
#   '구성',
#   '안',
#   '나오',
#   '나',
#   '망',
#   '작',
#   '배우',
#   '영화',
#   '보',
#   '눈',
#   '없',
#   '안타깝'],
#  ['반도', '안', '영화'],
#  ['영화', '평점', '높', '이유', '모르'],
#  ['평생', '기억', '영화', '정상', '소재'],
#  ['요즘', '상황', '보', '영화', '생각나'],
#  ['많', '생각', '만들', '영화', '마지막', '사람', '짐승', '보이', '아수라', '사람', '같', '보이'],
#  ['진짜', '재미', '없', '영화', '공통점', '스포츠', '영화', '군대', '영화', '자막', '나오', '영화'],
#  ['로버트', '드니', '광기', '복수', '연기', '만끽', '있', '수작', '서스펜스', '스릴러', '물'],
#  ['감동', '감동', '감동', '도가니탕'],
#  ['세계',
#   '정치',
#   '경제',
#   '문화',
#   '사회',
#   '전반',
#   '걸치',
#   '변화',
#   '절실',
#   '상황',
#   '변화',
#   '가져오',
#   '방법',
#   '없',
#   '함정',
#   '같'],
#  ['귀엽', '벤지', '똑똑', '벤지', '예쁘', '귀엽', '친구'],
#  ['당시', '개봉', '날', '보', '울', '나오', '돈', '아깝'],
#  ['정말', '최고', '영화'],
#  ['잔잔',
#   '숨',
#   '막히',
#   '영화',
#   '연출',
#   '대단',
#   '곳곳',
#   '숨',
#   '복선',
#   '치밀',
#   '정도',
#   '섬세',
#   '감정',
#   '표현',
#   '김영애',
#   '연기'],
#  [],
#  ['시나리오', '연출', '연기', '갖추', '시간', '넘', '아깝', '억지', '싸구려', '중국', '신파', '경극'],
#  ['거부', '몸짓', '하늘'],
#  ['그만',
#   '빙빙',
#   '돌리',
#   '밝히',
#   '안되',
#   '보',
#   '아직',
#   '질질',
#   '끌',
#   '짜증',
#   '안',
#   '봄',
#   '또',
#   '사',
#   '터지',
#   '질질',
#   '끌',
#   '진짜',
#   '짜증',
#   '날',
#   '빨리빨리',
#   '밝히',
#   '밝히',
#   '반전',
#   '있',
#   '작가',
#   '드라마',
#   '사랑',
#   '재',
#   '있',
#   '넘',
#   '끌',
#   '짜증',
#   '요'],
#  ['졸',
#   '보',
#   '왜',
#   '이리',
#   '평정',
#   '높',
#   '겨',
#   '내용',
#   '별거',
#   '없',
#   '아',
#   '오',
#   '감수성',
#   '영화',
#   '냐'],
#  ['기대', '영화', '아름답', '밀려오', '꽤', '괜찮', '영화'],
#  ['진짜', '더', '영화', '상영', '용서', '다', '지금', '영화', '보', '카', '톡', '잇', '놓', '진짜'],
#  ['살', '있', '생동감', '잃', '박물관'],
#  ['노', '땅', '한심', '추억', '미화'],
#  ['어리', '눈물', '흘리', '웃', '기억', '간신히', '찾', '다시', '보'],
#  ['인종', '차별', '유괴', '주제', '불협화음'],
#  ['고명환', '연기', '돈이 없어', '쓰', '후자', '라면', '보', '가치', '없', '영화'],
#  ['속편',
#   '주인공',
#   '이',
#   '전작',
#   '애',
#   '빈',
#   '밴드',
#   '좋',
#   '같',
#   '캐릭터',
#   '추가',
#   '로더',
#   '이상',
#   '해진'],
#  ['혼자', '보', '너무', '아깝', '올해', '영화'],
#  ['마지막', '결투', '최고', '폭풍', '눈물', '팝핀현준', '할아버지'],
#  [],
#  ['좋', '상술', '최고', '아니', '선거', '술', '최고'],
#  ['쓰레기', '함부로'],
#  ['나오', '안', '맞', '성향', '영화', '들'],
#  [],
#  ['막장',
#   '재미',
#   '있',
#   '재미',
#   '없',
#   '짜증',
#   '남',
#   '남녀',
#   '주인공',
#   '어울리',
#   '참',
#   '진짜',
#   '안',
#   '울',
#   '리',
#   '웬만',
#   '다',
#   '재밌',
#   '보',
#   '진짜',
#   '보',
#   '중',
#   '제일',
#   '최악',
#   '이',
#   '무트',
#   '주인공',
#   '시작',
#   '성격',
#   '이상',
#   '조기',
#   '종영',
#   '답'],
#  ['줄리', '델피', '나이', '들', '멋지'],
#  ['보', '드'],
#  ['명작', '명작'],
#  ['영화', '제목', '잘못', '보', '착각', '잘못'],
#  ['그냥', '기독교', '영화', '좀', '더', '깊이', '있', '내용', '기대', '실망', '영화', '엉성'],
#  ['그냥',
#   '책',
#   '읽',
#   '더',
#   '절절',
#   '다가오',
#   '영화',
#   '내용',
#   '너무',
#   '비약',
#   '삭제',
#   '행간',
#   '잃어버리',
#   '책',
#   '꽉',
#   '차',
#   '느낌',
#   '반대',
#   '엉성'],
#  ['너무나', '감동', '영화'],
#  ['스킨헤드', '영화', '싫어하'],
#  ['자동차', '매니아', '평점', '이하', '속', '아', '오'],
#  ['보', '인형', '절대', '안', '삼'],
#  ['정체성', '사치'],
#  ['나이',
#   '먹',
#   '아저씨',
#   '일',
#   '찌',
#   '놀이',
#   '영화',
#   '역겹',
#   '알바',
#   '풀',
#   '현실감',
#   '개',
#   '진짜',
#   '제로'],
#  ['남극', '그만', '길', '잃', '오르', '곳', '오르'],
#  ['재밌', '귀엽', '남'],
#  ['포스터', '진심', '개', '엑소시스트', '능가', '공포물', '같', '실상', '처키', '영화'],
#  ['시청률',
#   '늘',
#   '개뿔',
#   '존',
#   '11',
#   '재미없',
#   '이제',
#   '보니 M',
#   'BC',
#   '사극',
#   '너무',
#   '못',
#   '만들'],
#  ['요즘', '방', '보', '넘', '재밌', '왜', '시청률', '저조', '귀', '요미'],
#  ['연출',
#   '연기',
#   '영상',
#   '아름답',
#   '영화',
#   '예산',
#   '영화',
#   '관계',
#   '스펙',
#   '타',
#   '크',
#   '은',
#   '부족',
#   '한국',
#   '영화',
#   '새롭',
#   '바람',
#   '희망',
#   '다크호스',
#   '되',
#   '믿',
#   '많',
#   '응원',
#   '부탁',
#   '드리',
#   '벌써',
#   '일찍',
#   '관람',
#   '해주',
#   '신분',
#   '진심',
#   '감사'],
#  ['평점',
#   '왜',
#   '이렇',
#   '낮',
#   '나',
#   '또',
#   '다운',
#   '받',
#   '정말',
#   '재',
#   '있',
#   '끝',
#   '견자단',
#   '빵',
#   '싸우',
#   '때',
#   '정말',
#   '가슴',
#   '뜨거워지',
#   '난정',
#   '말로',
#   '재',
#   '있',
#   '최근',
#   '댓글',
#   '알바',
#   '아니',
#   '줄',
#   '알'],
#  ['이', '어떻', '평점', '낮', '있'],
#  ['블랙',
#   '코미디',
#   '조롱',
#   '대상',
#   '우리',
#   '기분',
#   '드럽',
#   '점수',
#   '성기',
#   '노출',
#   '어그',
#   '로나',
#   '끌'],
#  ['촌', '동네', '조', '폭', '삼류', '영화', '가끔', '툭툭', '미', '유머', '하'],
#  ['만들'],
#  ['스타', '데', '형님', '얼굴', '먹칠', '영화'],
#  ['허', '남자', '몸매', '보', '기분', '좋'],
#  ['안', '보', '별점', '영화', '같', '심형래', '아저씨', '동급', '감독'],
#  ['정말', '완벽', '최고', '영화', '꼽히', '영화'],
#  ['조잡', '유치', '예산', 'B급 영화', '스토리', '깊이', '감', '없', '전체', '루즈'],
#  ['진짜',
#   '민국',
#   '지아',
#   '더빙',
#   '더',
#   '이상',
#   '안되',
#   '더빙',
#   '얼마나',
#   '중요',
#   '애',
#   '시키',
#   '데뷔',
#   '도안',
#   '한',
#   '애',
#   '연예인',
#   '이해도',
#   '판'],
#  ['그냥', '재미', '없'],
#  ['쇼', '하', '쇼'],
#  ['중심', '약하', '언저리', '가지', '무리', '승부수', '띄우'],
#  ['주연', '배우', '이름', '기억', '남'],
#  ['그냥', '안보', '이득'],
#  ['키', '기키', '기키', '기키', '기키'],
#  ['빠', '죄다', '없'],
#  ['진짜', '짜증', '영화'],
#  ['불',
#   '잘',
#   '보이',
#   '사람',
#   '죽',
#   '때',
#   '엄청나',
#   '웅장',
#   '음악',
#   '나오',
#   '전혀',
#   '마음',
#   '오',
#   '닿',
#   '설정'],
#  ['망', '작'],
#  ['상당히', '재밌', '보'],
#  ['코끼리', '내놓', '더', '재밌'],
#  ['코믹', '코믹', '보', '패러디', '카메오', '들보', '재미', '있'],
#  ['유치', '짬뽕', '딱', '초등', '학년', '영화', '초등학교', '자녀', '있', '가족', '추천'],
#  ['후속', '지금', '나오', '한국', '애니', '좀', '살리'],
#  ['통하', '보', '정말', '재밌', '잘', '보', '근래', '보', '영화', '최고'],
#  ['기대', '보', '찰지', '만들', '토종', '느와르', '흥미진진'],
#  ['성인영화', '가족', '영화로', '만들', '멍청', '자막', '제작자', '마음', '안'],
#  ['일본인', '특유', '어색', '연기', '여주인공', '연기', '너무'],
#  ['전반',
#   '무겁',
#   '느낌',
#   '영화',
#   '가비',
#   '의향',
#   '과',
#   '맛',
#   '씁쓸',
#   '느끼',
#   '장윤현',
#   '감독',
#   '커피',
#   '부분',
#   '관하',
#   '신경',
#   '쓰',
#   '연출',
#   '부분',
#   '있',
#   '좀',
#   '미흡',
#   '배우',
#   '연기력',
#   '괜찮'],
#  ['전작', '재밌', '배우', '내용', '모두', '세련'],
#  ['진지', '무겁', '소재', '경쾌', '재미있', '만들'],
#  ['유럽', '작품', '한', '유럽', '중요', '얘기', '픽션'],
#  ['풍', '정정', '어', '되', '거지', '과도', '압축', '개연', '없', '배우', '호화'],
#  ['이영화',
#   '구성',
#   '좋',
#   '아마',
#   '친구',
#   '같이',
#   '영화',
#   '님',
#   '영화',
#   '좋',
#   '재밌',
#   '같이',
#   '보',
#   '친구',
#   '이해',
#   '겁',
#   '니다',
#   '진짜',
#   '최악',
#   '최저',
#   '스토리',
#   '주인공',
#   '행동',
#   '이해관계',
#   '최악',
#   '이렇',
#   '허',
#   '접하',
#   '표현',
#   '영화',
#   '간만',
#   '능'],
#  ['이제', '그만', '보', '막', '스토리텔링'],
#  ['말', '필요', '없', '로맨스', '싫어하', '보', '때', '기절', '같'],
#  ['취향', '이고', '우울', '마음', '완전히', '날리', '슬프', '내용', '뒤', '마음', '정화'],
#  ['영상미', '최고'],
#  [],
#  ['한국', '영화', '보', '되'],
#  ['괜찮', '영화'],
#  ['요즘', '재밌'],
#  ['소재',
#   '참',
#   '좋아서',
#   '제작',
#   '영화',
#   '공포',
#   '스릴러',
#   '본분',
#   '잊',
#   '드라마',
#   '드라마',
#   '같',
#   '느낌',
#   '연기',
#   '연출',
#   '괜찮',
#   '시작',
#   '끝',
#   '지루',
#   '장면',
#   '살짝',
#   '유치'],
#  ['남자', '보', '울', '딸', '낳', '잘'],
#  ['안타깝', '안타깝'],
#  ['영웅', '사람', '원하', '만들', '희생', '자'],
#  ['그냥', '평', '작', '욕', '안', '나오'],
#  ['극장가', '안보', '머리', '깨', '인생', '최고', '영화', '키이', '라', '작품', '최고', '일'],
#  ['고생', '마마', '추', '포르노'],
#  ['비디오', '물', '동시', '상영', '물', '넌', '정체', '몰'],
#  ['이건', '말', '설명', '없', '유치', '진짜', '필름', '아깝'],
#  ['이승연', '강렬', '묻어나', '영화', '홍경인', '너무', '불쌍', '나오'],
#  ['뿜'],
#  ['부족',
#   '영화',
#   '부족',
#   '영화',
#   '감동',
#   '있',
#   '참',
#   '끝',
#   '다',
#   '보',
#   '진심',
#   '이렇',
#   '재미없',
#   '느끼',
#   '처음'],
#  ['계몽영화', '한계', '고스', '란', '답습'],
#  ['우', '정말', '오랜만', '통쾌', '웃', '내일', '기대'],
#  ['청춘', '마침표', '없'],
#  ['얼간이', '아줌마', '나오', '본건', '실망', '신선', '반전', '보', '개연', '없', '이렇'],
#  ['좋', '소재', '만족', '연출'],
#  ['심혜진', '나오', '겨우', '정도', '실망'],
#  ['아들놈',
#   '끝',
#   '아빠',
#   '미안',
#   '감정',
#   '없',
#   '소재',
#   '신선',
#   '영화',
#   '자체',
#   '메시지',
#   '모호',
#   '스토리',
#   '짜임새',
#   '있',
#   '같'],
#  ['창업',
#   '꿈꾸',
#   '좋',
#   '아이템',
#   '있',
#   '사업',
#   '하',
#   '그렇',
#   '기',
#   '쓰',
#   '영화',
#   '보',
#   '바라',
#   '멀',
#   '험하',
#   '여정',
#   '스승',
#   '되',
#   '지침서',
#   '되',
#   '단념',
#   '도움',
#   '되',
#   '참',
#   '오랜만',
#   '박장대소',
#   '보',
#   '독립',
#   '영화'],
#  ['슬프', '액션', '영화', '실망', '크', '부자', '간의', '배신', '과', '원망', '끝나', '너무', '허무'],
#  ['명화', '진짜', '감동'],
#  ['티',
#   '프리미엄',
#   '인간',
#   '면',
#   '쪼',
#   '맘',
#   '들',
#   '진짜',
#   '이선균',
#   '정재영',
#   '김상중',
#   '연기파',
#   '배우',
#   '러',
#   '노',
#   '코',
#   '쓰레기',
#   '영화',
#   '찍',
#   '진짜',
#   '영화',
#   '보',
#   '계',
#   '쇠',
#   '지루',
#   '괴롭'],
#  ['너무나', '따뜻', '감동', '영화'],
#  ['급', '영화', '안', '일', '아깝', '네이버', '마이너스', '점수', '만들', '다르'],
#  ['스토리', '부진', '액션', '재미', '반감'],
#  ['끼', '느', '덕', '영화', '굿'],
#  ['시종일관', '오락가락', '말', '모르', '감독', '자기', '세계', '빠지', '만들', '같', '영화'],
#  ['왠지', '모르', '색다르', '감동', '영화'],
#  ['전주',
#   '영화제',
#   '보',
#   '데넘',
#   '늦',
#   '개봉',
#   '종',
#   '교와',
#   '업',
#   '대하',
#   '더',
#   '생각',
#   '만들',
#   '영화',
#   '예산',
#   '만들',
#   '감독',
#   '노력',
#   '느끼',
#   '크',
#   '박수',
#   '보내',
#   '화이팅'],
#  ['보', '웃', '재밌'],
#  [],
#  ['사랑', '상처', '받', '다시', '치유', '있', '하', '생각', '들', '영화'],
#  ['극장가', '보', '영화', '쓰디쓰', '아픔', '처음', '느끼', '퍼스트'],
#  ['최고', '더', '평가', '필요', '탑'],
#  ['자신', '삶', '대하', '다시', '생각', '영화'],
#  ['알바', '양심', '없', '멀', '주'],
#  ['돌아가', '하'],
#  ['끼우', '맞추', '개', '반전', '보', '오', '하', '인간', '이해', '불가'],
#  ['짓', '하', '후세', '태어나', '일본', '진짜', '정신', '상태', '이상'],
#  [],
#  ['영화', '보', '흐뭇', '영화', '한국', '더', '잘', '만들', '걸', '느끼', '되'],
#  ['지', '대우', '깔'],
#  ['재밌', '짜', '하', '매력'],
#  ['오',
#   '머릿속',
#   '지우개',
#   '이후',
#   '진짜',
#   '슬프',
#   '영화',
#   '마지막',
#   '눈물',
#   '폭발',
#   '오늘이',
#   '후에',
#   '또',
#   '보'],
#  ['요', '커플', '짱', '짱', '덕분', '아주', '재미있', '보'],
#  ['터키',
#   '특집',
#   '액션',
#   '스키',
#   '추격',
#   '기억',
#   '남',
#   '소피',
#   '소피',
#   '의하',
#   '소피',
#   '위하',
#   '시리즈',
#   '로저',
#   '무어',
#   '시절',
#   '재미',
#   '조금',
#   '떨어지'],
#  ['수많', '최루', '멜로'],
#  ['평생', '최고', '걸작', '현실', '건너편', '세계', '잠시', '엿보', '느낌'],
#  ['인생', '최고', '영화'],
#  ['진짜', '추천'],
#  ['포스터',
#   '사기',
#   '너무',
#   '현실',
#   '배우',
#   '심각',
#   '빵빵',
#   '터지',
#   '화성',
#   '남',
#   '금성',
#   '녀',
#   '혼자',
#   '내리',
#   '본전생각',
#   '담배',
#   '피',
#   '남편'],
#  ['마술', '죽', '기전', '외계인', '만나', '볼', '있'],
#  ['참', '재밌는 영화'],
#  ['빨리', '좀', '끝나', '으', '이그', '처음', '엔', '재밌', '알', '이리', '재미없'],
#  ['극', '전혀', '몰입', '안', '장면', '이어', '붙이', '단순', '진행', '연출력', '형편없'],
#  ['자막', '제작자', '쓰', '막', '장임'],
#  ['그리', '무섭', '도승', '물', '쉽', '떠내려가'],
#  ['이',
#   '왜',
#   '주온',
#   '평점',
#   '높',
#   '이해',
#   '알',
#   '간다',
#   '이영화',
#   '처음',
#   '여배우',
#   '물대포',
#   '쏘',
#   '때',
#   '포스터',
#   '더',
#   '무섭',
#   '영화',
#   '상영',
#   '시간',
#   '내내',
#   '포스터',
#   '보이',
#   '충분히',
#   '지리'],
#  ['진짜', '신기', '말', '안나'],
#  ['좋', '배우', '데리', '작품', '부족'],
#  ['아니',
#   '왜',
#   '근래',
#   '보',
#   '다크',
#   '히어로',
#   '무비',
#   '최고',
#   '아주',
#   '그냥',
#   '고스트',
#   '라이',
#   '더',
#   '걸리',
#   '스치',
#   '사망'],
#  ['묵직', '시작', '우습', '끝나'],
#  ['내용', '전개', '엉성', '지루', '정도'],
#  ['돈뭉치', '싸대', '명장면'],
#  ['고고', '하자'],
#  ['쓰레기', '영화'],
#  ['너무',
#   '일찍',
#   '슬픔',
#   '알',
#   '되',
#   '제제',
#   '안쓰럽',
#   '책',
#   '읽',
#   '눈물',
#   '나',
#   '영화',
#   '도마',
#   '찬가',
#   '지다',
#   '어',
#   '린나이',
#   '의제',
#   '슬픔',
#   '을',
#   '너무',
#   '일찍',
#   '알'],
#  ['정말', '비디오', '돈', '주', '보', '아깝', '최악'],
#  ['말', '그대로', '뚝방', '보', '영화'],
#  ['인생', '최고', '영화', '다', '되', '가', '아직', '아련', '애틋', '기억'],
#  ['감독', '다신', '영화', '찍'],
#  ['육감', '섹시', '여인', '존재', '자체', '영화', '전부'],
#  ['영화', '입부', '카메라', '각도', '화질', '겁나', '구림', '영화', '알'],
#  ['진정',
#   '좋',
#   '영화',
#   '볼',
#   '때',
#   '당시',
#   '재',
#   '있',
#   '도',
#   '두고두고',
#   '기억나',
#   '생각나',
#   '한번쯤',
#   '보',
#   '영화'],
#  ['박사', '아들', '정시', '현', '정말', '멋지'],
#  ['너무', '좋', '너무', '묻히'],
#  ['하', '말', '없'],
#  ['나', '별로', '덜'],
#  ['영화', '참', '좋'],
#  ['곳곳', '번뜩이', '아이디어', '아기자기', '구성', '돋보이', '수작'],
#  ['우아', '새벽', '에보니', '까', '무섭', '미스터리', '에로스', '스릴러', '겸비', '영화'],
#  ['짧', '정말', '재밌', '잘', '보', '윤계상', '능청', '연기', '좋', '하', '생각', '계속', '하'],
#  ['에린', '초반', '타', '차', '현대자동차', '프레스토', '보', '추억', '이세', '록', '록'],
#  ['남', '철학', '영화', '단순', '액션', '보', '정도', '점수', '나오', '되'],
#  [],
#  ['효과음', '기가', '막히', '영화'],
#  ['솔직히', '평점', '이상', '되', '되', '같'],
#  ['나', '강혜정', '일본', '가', '찍', '하', '닮', '같', '생각', '들'],
#  ['일본', '영화', '좋아하', '꼭', '보', '영화'],
#  ['진짜',
#   '이건',
#   '액션',
#   '영화',
#   '좋아하',
#   '액션',
#   '영화',
#   '다운',
#   '받',
#   '꾸준히',
#   '보',
#   '벌써',
#   '사람',
#   '이건',
#   '아무리',
#   '점수',
#   '잘',
#   '만점',
#   '돈',
#   '주',
#   '너무',
#   '아깝',
#   '진짜',
#   '대체',
#   '왜',
#   '13구역',
#   '타이틀',
#   '달',
#   '나오',
#   '모르',
#   '실망'],
#  ['가슴', '먹먹', '왜', '이제서야', '알', '되'],
#  ['커스', '티', '좋'],
#  ['보', '영화', '끝나', '나서', '불쾌', '중년', '남성', '이렇', '추잡', '보이'],
#  ['진짜', '퀵', '이유', '이렇', '어이없', '재미없', '영화', '처음', '진짜', '돈아', '까운'],
#  ['진짜',
#   '재미없',
#   '영화관',
#   '에',
#   '정도',
#   '늦',
#   '들어가',
#   '사람',
#   '이한',
#   '명도',
#   '없',
#   '이유',
#   '왜',
#   '알',
#   '같',
#   '완전',
#   '비추'],
#  ['보', '영화', '인대', '솜', '이랑', '키', '작', '남자', '살', '나가'],
#  ['조금', '유치', '왕조현', '주윤발', '충분히', '볼', '하'],
#  ['나', '솔직히', '재미없', '코믹', '요소', '없'],
#  ['싸구려', '왜색', '영화', '키', '작', '교활', '일본원숭이', '망상', '사무라이', '정신', '토', '나오'],
#  ['재미있', '감동'],
#  ['아니', '찍', '모니터링', '안', '어떻', '염치', '업', '이렇', '극장', '걸', '있'],
#  ['영화 산업',
#   '하',
#   '홍보',
#   '하',
#   '속',
#   '팔',
#   '게',
#   '소비자',
#   '입장',
#   '짜증',
#   '나',
#   '그나마',
#   '다행',
#   '아주',
#   '싸구려',
#   '상급',
#   '품',
#   '속',
#   '여파',
#   '게',
#   '차라리',
#   '열',
#   '상호',
#   '감독',
#   '작품',
#   '홍보',
#   '되',
#   '비슷',
#   '하'],
#  ['완전', '감동', '박신혜'],
#  ['절망', '속', '결국', '빠져나오', '눈물겹', '실화'],
#  ['국민학교', '다니', '때', '동생', '이랑', '보', '눈물'],
#  ['욕망이라는 이름의 전차'],
#  ['디', '랑', '같', '부류', '예산', '저렴', '마구잡이', '연출'],
#  ['무기', '잘', '있', '보', '내내', '손', '땀', '쥐', '애니'],
#  ['배우', '연기력', '아깝', '아깝'],
#  ['딱', '90년대', '코미디', '영화'],
#  ['어리', '때', '진짜', '재미있', '보'],
#  ['정말',
#   '최',
#   '고의',
#   '영화',
#   '마지막',
#   '아이들',
#   '노래',
#   '비행기',
#   '정말',
#   '잊',
#   '없',
#   '여운',
#   '남기',
#   '영화',
#   '이제',
#   '알',
#   '되',
#   '자체',
#   '후회',
#   '정도',
#   '잔잔',
#   '깊',
#   '여운',
#   '남',
#   '영화'],
#  ['보', '어이없', '웃음', '나'],
#  ['악역', '금단비', '더', '주목', '받', '주연', '여배우들', '미스', '캐스팅', '의미'],
#  [],
#  ['보', '나서', '내내', '여운', '남', '영화'],
#  ['절대로', '보지', '마라', '보', '후회', '걸', '영화', '만들', '볼', '사람', '뇌'],
#  ['내용', '도통', '모르', '쓸데없이', '특별', '보이', '시도', '열중', '영화'],
#  ['기쁨',
#   '슬픔',
#   '생명',
#   '죽음',
#   '인간',
#   '역사',
#   '속',
#   '거대',
#   '하나님',
#   '우주',
#   '섭리',
#   '느끼',
#   '영화',
#   '특별히',
#   '어머니',
#   '역',
#   '맡',
#   '여배우',
#   '여성',
#   '미와',
#   '자애',
#   '인상',
#   '인생',
#   '살',
#   '존재',
#   '되',
#   '영상미',
#   '예술'],
#  ['게', '가요', '내용', '없'],
#  ['평점', '어마어마', '높', '빨리', '낮추', '하', '적당', '영화'],
#  ['이야기',
#   '도',
#   '보통',
#   '재미있',
#   '정도',
#   '정도',
#   '고릴라',
#   '제작',
#   '거도',
#   '잘',
#   '하',
#   '하지',
#   '감동',
#   '보통',
#   '아쉽',
#   '결말'],
#  ['솔직히',
#   '웬만',
#   '공포',
#   '영화',
#   '다',
#   '섭렵',
#   '매니아',
#   '주온',
#   '정말',
#   '무섭',
#   '아직',
#   '샤워',
#   '머리',
#   '감',
#   '때',
#   '공포',
#   '느끼',
#   '쳐다보',
#   '있',
#   '느낌',
#   '느낌',
#   '나말',
#   '고도',
#   '겪',
#   '사람',
#   '있',
#   '그만큼',
#   '당시',
#   '대단',
#   '영화'],
#  ['아름답', '영화'],
#  ['정말', '광', '해', '비슷'],
#  ['쉬', '하트', '넷', '특유', '여성', '자극', '나약', '남성', '이미지', '작', '부각'],
#  ['정말', '속', '느낌'],
#  ['몸매', '베드', '신', '보', '좋', '사람', '영화', '안', '보', '사람'],
#  ['잘', '보', '외모', '따지', '사랑', '빠지', '하', '하', '요즘', '사람', '좋', '영화인', '같'],
#  ['최악', '쓰레기', '어설프', '정말', '노력'],
#  ['콜린', '파레'],
#  ['난', '제일', '재밌'],
#  ['나', '좋', '괜찮'],
#  ['영화', '댓글', '더', '재밌'],
#  ['에', '라이', '미치', '사이코', '드라마'],
#  ['일본', '문화', '들어가', '있', '하', '있', '최고', '사극'],
#  ['엄청나', '기대', '하', '보', '괜찮'],
#  ['더빙', '똥'],
#  ['안타깝', '이해', '사람', '속출', '불교', '철학', '작품'],
#  ['진짜',
#   '같',
#   '영화',
#   '시간',
#   '낭비',
#   '의미',
#   '없',
#   '무섭',
#   '왜',
#   '하',
#   '공포',
#   '영화',
#   '즐기',
#   '이건',
#   '진짜',
#   '같'],
#  ['색다르', '재밌는 영화', '실제로', '일', '있', '참', '재밌', '같', '막장', '막장'],
#  ['어', '캐', '꼬옥'],
#  ['정말', '식상'],
#  ['종교', '분위기', '물씬', '풍기', '최루', '가족', '영화'],
#  ['재밌'],
#  ['그냥', '살', '그렇', '이성재', '멋지'],
#  ['음악', '영화', '취향저격', '비긴', '어게인', '대중', '흥행', '힘들', '영화', '여주', '너무', '매력'],
#  ['선택', '왜', '없', '솔직히', '반개', '아깝'],
#  ['돈', '미치', '남편', '아기', '미치', '돈', '있', '남자', '속', '갈등', '하', '여자'],
#  ['어린이', '시점', '볼', '하', '오로지', '어린이', '시점'],
#  ['잠', '청하'],
#  ['좋아하', '사람', '뇌', '완전', '난해', '결말', '왕', '실망', '임'],
#  ['전작', '비하', '왠지', '허탈', '카이사르', '전작', '더', '멋있', '하'],
#  ['김민종', '최고', '더', '잘'],
#  ['공격', '재미', '유순', '여성성', '일기토', '지략', '삼국지', '맞짱'],
#  ['점수', '이정', '밖', '못', '만들', '충격'],
#  ['비디오', '테잎', '감', '보', '영화', '가장', '슬프', '영화'],
#  ['도입',
#   '부',
#   '제외',
#   '따분',
#   '헬기',
#   '민간인',
#   '마구',
#   '쏘',
#   '죽이',
#   '미군',
#   '베',
#   '트',
#   '공',
#   '여성',
#   '슬',
#   '푸',
#   '현실감',
#   '없',
#   '극단',
#   '설정',
#   '라이언',
#   '일병',
#   '업',
#   '햄',
#   '영화',
#   '주인공',
#   '조커',
#   '넘',
#   '모두',
#   '싫어하',
#   '캐릭터',
#   '착하',
#   '하',
#   '주위',
#   '피해',
#   '넘'],
#  ['재밌',
#   '그렇',
#   '참고',
#   '우리나라',
#   '까',
#   '하',
#   '안',
#   '나오',
#   '그냥',
#   '지',
#   '소설',
#   '쓰',
#   '지',
#   '자위',
#   '자위대',
#   '등장',
#   '사람',
#   '자위',
#   '하',
#   '있',
#   '일본',
#   '감정',
#   '다',
#   '떠나',
#   '과학도',
#   '과학',
#   '보',
#   '영화',
#   '신선'],
#  ['취향'],
#  ['평점', '조절'],
#  ['아깝', '쓰레기', '영화', '전작', '아깝'],
#  ['일편',
#   '비하',
#   '삽질',
#   '브리',
#   '짓',
#   '쪼',
#   '끄',
#   '짜증',
#   '날',
#   '때',
#   '여전히',
#   '사랑',
#   '콜린 퍼스',
#   '휴 그랜트',
#   '한자리',
#   '모으'],
#  ['지금',
#   '보',
#   '아이리스',
#   '리즈중',
#   '최악',
#   '이거',
#   '해도',
#   '너무',
#   '수치',
#   '연기',
#   '고자',
#   '다',
#   '떠나',
#   '너무',
#   '도',
#   '허',
#   '접합'],
#  ['연기력',
#   '하',
#   '말이',
#   '없',
#   '정우성',
#   '고소영',
#   '왜',
#   '그토록',
#   '흥행',
#   '작',
#   '없',
#   '알',
#   '비트',
#   '연기'],
#  ['전라도', '노예', '업주', '처벌', '안받', '슈가', '안', '그렇'],
#  ['배우', '아깝'],
#  ['볼', '하'],
#  ['결말',
#   '의미',
#   '공자',
#   '자연',
#   '숨',
#   '살',
#   '노자',
#   '말',
#   '짐승',
#   '끼리끼리',
#   '살',
#   '사람',
#   '따로',
#   '살',
#   '진정',
#   '순수',
#   '더럽',
#   '사이에서',
#   '빛',
#   '유지'],
#  ['크리스 터커', '짱'],
#  ['믿', '데', '젤', '싱', '턴', '왜', '이렇', '후덕'],
#  ['나오코', '진짜', '집중', '안'],
#  ['감독', '밥', '먹', '다니', '궁금', '배틀로얄', '이후', '최고', '쓰'],
#  ['재미', '너무', '없', '시간', '아깝'],
#  ['나', '재', '있'],
#  ['어떻',
#   '상류층',
#   '속물근성',
#   '정당화',
#   '미화',
#   '모르',
#   '감독',
#   '국회의원',
#   '사회',
#   '강자',
#   '아부',
#   '가',
#   '얼굴',
#   '예쁘',
#   '왕',
#   '맞',
#   '드라마',
#   '도덕',
#   '표현',
#   '좀',
#   '하',
#   '되',
#   '감독',
#   '정신',
#   '차리'],
#  ['가만히', '보', '있', '씨익', '웃음', '행복', '가족', '이야기'],
#  ['사고', '후', '잠시', '정상인', '되', '일탈'],
#  ['좋', '영화'],
#  ['이거', '예전', '나오', '같', '재미'],
#  [],
#  ['감독', '옹졸', '치졸', '묻어나', '영화'],
#  ['팔', '빠다'],
#  ['재미없'],
#  ['생각', '만들'],
#  ['스토리', '흥미', '배우', '연기', '인상', '충분히', '보'],
#  ['인생', '최고', '미드'],
#  ['영화',
#   '보',
#   '사랑하고 싶다',
#   '생각',
#   '하',
#   '청소년',
#   '관람',
#   '불가',
#   '선정',
#   '장면',
#   '나오',
#   '연인',
#   '솔로',
#   '이신',
#   '추천'],
#  ['일본', '공포', '영화', '링', '주온', '이후', '망하'],
#  ['지루', '지루'],
#  ['직접',
#   '겪',
#   '어르신',
#   '얘기',
#   '들',
#   '당시',
#   '잔인',
#   '학살',
#   '대부분',
#   '주민',
#   '서로',
#   '주로',
#   '하층민',
#   '복수심',
#   '비롯',
#   '군',
#   '경이',
#   '빨치산',
#   '학살',
#   '벌이',
#   '살인',
#   '정작',
#   '북한군',
#   '민간인',
#   '잘',
#   '하'],
#  ['그냥', '다', '큐', '일'],
#  ['영화', '개인', '평균', '평점', '정도', '가치', '하', '보', '스타일', '쉬', '영화'],
#  ['정말',
#   '질질',
#   '끌',
#   '작가',
#   '님',
#   '제발',
#   '좀',
#   '적당히',
#   '희',
#   '수역',
#   '맡',
#   '사람',
#   '그만',
#   '나쁘',
#   '만들',
#   '아침',
#   '드라마',
#   '막장'],
#  ['으', '괴물', '그래픽', '좀', '다듬', '머니', '다', '티나', '게', '공포', '영화', '웃', '첨'],
#  ['대표', '쓰레기', '김치', '드라마'],
#  ['네이버', '별점', '꽤', '신뢰도', '높', '이하', '안보', '좋'],
#  ['남', '주', '헤어', '스타일', '왜', '저러'],
#  ['영화', '보', '안다', '작', '일', '크', '화', '만들', '나라', '국민', '인상', '깊'],
#  ['김명민', '구하', '타', '때', '진짜', '설마', '설마', '하'],
#  ['보', '재미있', '재미없', '진짜', '기분', '들', '울', '영화', '공포', '영화', '싸이코', '영화'],
#  [],
#  ['시청률', '너무', '낮', '명작'],
#  ['현실감',
#   '제로',
#   '지만',
#   '배우',
#   '너무',
#   '좋',
#   '특히',
#   '다니엘',
#   '헤',
#   '많이',
#   '보',
#   '있',
#   '좋',
#   '같',
#   '남자',
#   '게이',
#   '다니엘',
#   '헤',
#   '최고',
#   '설경구',
#   '최고'],
#  ['프레디', '모욕감', '프레디'],
#  ['재', '없', '넘'],
#  ['평점',
#   '너무',
#   '높',
#   '원작',
#   '보심',
#   '나',
#   '짧',
#   '러닝',
#   '타임',
#   '감사',
#   '하',
#   '주인공',
#   '썰매',
#   '타',
#   '목적지',
#   '가니',
#   '사람',
#   '기억',
#   '돌아오',
#   '황당',
#   '설정',
#   '인간',
#   '감정',
#   '통제',
#   '데몰리셔',
#   '매',
#   '보',
#   '신선',
#   '없'],
#  ['막장 드라마', '원조', '영화', '영화', '확실히', '로즈', '살리'],
#  ['해군', '출신', '관심', '있', '보', '영화'],
#  ['파란색', '슬픔', '영화'],
#  ['액션', '완전', '차라리', '유오성', '나오', '챔프', '보'],
#  ['폭풍', '오열'],
#  ['착하', '영화', '재미없'],
#  ['사소', '이야기', '눈', '떼', '없', '만들', '거장', '솜씨', '예전', '장이', '모우', '그립'],
#  ['보', '영화', '베스트', '안', '진짜', '꼭', '보'],
#  ['지금', '보', '페이크', '다', '큐', '영화', '제일', '별로'],
#  ['재미', '있', '공감', '되', '즐기', '독립', '영화'],
#  ['시미즈', '레이', '코', '만화책', '비밀', '영향', '받', '아냐'],
#  ['기존', '한국', '영화', '느끼', '색다르', '느낌', '상업', '보', '새롭', '도전'],
#  ['장난', '반전', '같', '있', '알', '끝', '다', '보', '진짜', '시간', '아깝'],
#  ['예고편',
#   '왜',
#   '하',
#   '건지',
#   '모르',
#   '예고편',
#   '나오',
#   '안',
#   '나오',
#   '예고편',
#   '대판',
#   '쌈지',
#   '하',
#   '나오',
#   '하',
#   '끝나',
#   '예고편',
#   '뜻',
#   '인지',
#   '모르',
#   '시청자',
#   '호구',
#   '보',
#   '낚시',
#   '질',
#   '좀',
#   '그만',
#   '차라리',
#   '시청률',
#   '걱정',
#   '폐지'],
#  ['나', '프랑스', '영화', '이렇', '좋'],
#  ['쓰레기', '쓰레기', '쓰레기', '쓰레기', '쓰레기', '쓰레기', '쓰레기', '쓰레기'],
#  ['참', '재밌', '보', '귀엽', '지미'],
#  ['시간', '지나', '보', '정말', '가슴', '애', '린', '드라마'],
#  ['사촌', '동생', '같이', '보', '하', '정말', '사촌', '동생', '재미없', '하'],
#  ['설득력', '없', '꼴통', '페미니즘', '페미나치', '마인드'],
#  ['급', '지향', '급', '작품'],
#  ['음', '잘', '모르', '보', '하', '걸', '소녀', '가장', '이야기'],
#  ['틀리', '생각', '장애인', '틀리', '알리'],
#  ['재밌', '감각', '있', '쿠', '하', '영화', '마지막', '결말', '약간', '아쉽'],
#  ['그냥',
#   '재미없',
#   '보',
#   '마저',
#   '보',
#   '이렇',
#   '갑자기',
#   '원주민',
#   '생활',
#   '진짜',
#   '어처구니',
#   '없',
#   '그냥',
#   '영화'],
#  ['진짜',
#   '언제',
#   '90분',
#   '지나',
#   '모르',
#   '정도',
#   '몰입',
#   '정말',
#   '너무',
#   '재미있',
#   '봄',
#   '너무',
#   '아련',
#   '영화',
#   '정말',
#   '처음',
#   '남기',
#   '진짜',
#   '나이',
#   '애니',
#   '보',
#   '밤중',
#   '이렇',
#   '울',
#   '에',
#   '몽'],
#  ['사과'],
#  ['골목', '상권', '들어오', '대형', '슈퍼마켓', '생각나'],
#  ['평점', '조절', '필요', '생각', '들'],
#  ['무협', '멜로', '걸작', '말', '모'],
#  ['너무', '재미있', '보', '다시', '보', '없'],
#  ['오', '글', '거리', '유치', '완전', '최악'],
#  ['절', '대비', '추'],
#  ['한국', '껀', '알', '앗', '일본'],
#  ['꽃', '한송이', '가'],
#  ['삶',
#   '가장',
#   '의미',
#   '있',
#   '라면',
#   '바로',
#   '영화',
#   '보',
#   '살',
#   '죽',
#   '전',
#   '꼭',
#   '보',
#   '하',
#   '영화'],
#  ['생각', '볼', '하', '여주인공', '연기', '좋'],
#  ['자꾸',
#   '설득',
#   '설교',
#   '보기',
#   '거북',
#   '리',
#   '고',
#   '결혼반지',
#   '위하',
#   '범죄',
#   '가담',
#   '개역',
#   '설정'],
#  ['오'],
#  ['제발', '문성우', '쓰'],
#  ['살',
#   '처음',
#   '접하',
#   '장르',
#   '조금',
#   '당황',
#   '솔직히',
#   '영화',
#   '자체',
#   '자신',
#   '색깔',
#   '충실',
#   '완성',
#   '뛰어나',
#   '좋아하',
#   '이해'],
#  ['오늘', '아이', '데리', '보', '아이', '좋아하', '미', '취학', '초등', '어린이', '추천'],
#  ['끝', '참', '보', '제일', '자랑'],
#  [],
#  ['안', '보', '되', '영화'],
#  ['원작', '망치'],
#  ['그냥'],
#  ['나쁘', '개인', '지루'],
#  ['어의', '없', '스토리', '여자', '죽', '때', '웃음', '나오', '로맨스', '영화', '냐'],
#  ['순수', '두그', '걸', '좋', '감독', '관객', '원하', '잘', '알', '여운', '많이', '남'],
#  ['기', '방', '난동', '사건', '이후', '최악', '영화', '사람', '믿', '보', '다', '알바'],
#  ['로맨스', '스릴러', '짬뽕', '놓', '말', '스토리', '허황', '느낌'],
#  ['이건', '좀'],
#  ['윤아', '안', '원작자', '캐스팅', '참여', '해주', '요', '작품', '망치', '안'],
#  ['지금', '생각', '보', '영화', '이영화', '생애', '최고', '영화', '같'],
#  ['천녀유혼', '비하', '표현', '힘들', '퀭', '영화'],
#  ['불륜',
#   '미화',
#   '영화',
#   '남은',
#   '사람',
#   '어쩌라고',
#   '돈',
#   '걱정',
#   '안',
#   '사람',
#   '이야기',
#   '공감',
#   '강요',
#   '영화 음악',
#   '이랑',
#   '영상미'],
#  ['최고', '이란', '노래', '곡', '영화', '속', '노래', '얼씬', '좋'],
#  ['소재', '굉장히', '신선'],
#  ['내사랑', '키', '아누', '리브스'],
#  ['두말',
#   '없이',
#   '최고',
#   '작품',
#   '인생',
#   '대하',
#   '생각',
#   '하',
#   '깊이',
#   '있',
#   '영화',
#   '전',
#   '출연진',
#   '제작진',
#   '크',
#   '박수',
#   '보내'],
#  ['솔직히', '산', '하', '하'],
#  ['말', '이', '필요', '없', '성룡', '영화', '에선', '무어', '가르', '다르', '느끼', '있다'],
#  ['화학',
#   '하',
#   '그런지',
#   '재',
#   '잇',
#   '옆',
#   '친구',
#   '중간',
#   '중간',
#   '노',
#   '이해',
#   '나중',
#   '해석',
#   '재',
#   '잇'],
#  ['아직', '준비', '젊', '영화인', '함부로', '장편', '손대', '마라', '천천히', '공부', '나오'],
#  ['으',
#   '엉',
#   '간만',
#   '추억',
#   '돋',
#   '보',
#   '사실',
#   '원작',
#   '자체',
#   '두서없이',
#   '전개',
#   '영화감독',
#   '내용',
#   '앞뒤',
#   '없이',
#   '막',
#   '자르',
#   '정신없',
#   '배우',
#   '책',
#   '읽',
#   '특히',
#   '대사',
#   '그대로',
#   '살리',
#   '리오',
#   '링',
#   '간만',
#   '소설',
#   '읽'],
#  ['쓰레기', '같', '감히', '팔아먹'],
#  ['기억', '조작', '마련', '사람', '하', '부러', '말'],
#  ['재밌',
#   '보',
#   '그저',
#   '문헌',
#   '적히',
#   '문란',
#   '사도',
#   '세자',
#   '정조',
#   '아버지',
#   '그릇',
#   '정도',
#   '잘',
#   '보이',
#   '작품',
#   '시나리오',
#   '시나리오',
#   '지만',
#   '배우',
#   '연기',
#   '일품'],
#  ['휴일',
#   '낮',
#   '침대',
#   '눕',
#   '티',
#   '비보',
#   '영화',
#   '채널',
#   '틀',
#   '어쩌',
#   '없이',
#   '보',
#   '나중',
#   '벌떡',
#   '앉',
#   '보',
#   '영화',
#   '완전',
#   '몰입',
#   '스토리',
#   '치밀',
#   '해리슨 포드',
#   '다운',
#   '액션',
#   '좋',
#   '영화',
#   '광도',
#   '영화 평론',
#   '가도',
#   '영화',
#   '자주',
#   '보',
#   '일반',
#   '남자',
#   '사람'],
#  ['절제', '미학', '지루함', '극치', '되', '안타', '갑'],
#  ['영화관', '보', '돈', '아깝', '솔직히', '재미없'],
#  ['인간', '솔직', '보이', '방법', '말', '고도', '방법', '충분', '있', '텐'],
#  ['정말', '사랑', '대하', '다시', '생각', '같', '감동'],
#  ['내용', '교육', '정말', '지루', '해서'],
#  ['꿀', '재', '특히', '소유', '서인영', '매력', '터지'],
#  ['태어나', '보', '영화', '제일', '재미없'],
#  ['화면', '흑백', '바꾸', '하', '50년대', '작'],
#  ['쇼핑몰', '안', '찍', '너무', '재미없', '답답', '내용', '없'],
#  ['진짜', '쓰레기', '영화', '돈', '아깝', '죽', '알', '여러분', '보', '마'],
#  ['두근두근', '익스트림', '자체'],
#  ['폭력', '영화', '자극', '실험', '예술'],
#  ['일본',
#   '영',
#   '화랑',
#   '비슷',
#   '느끼',
#   '가요',
#   '수트',
#   '입',
#   '미남',
#   '변하',
#   '마지막',
#   '평생',
#   '입',
#   '권유',
#   '받',
#   '창조',
#   '이렇',
#   '중복',
#   '걸',
#   '잘',
#   '모르'],
#  ['진짜',
#   '이렇',
#   '재미',
#   '없',
#   '감동',
#   '없',
#   '영화',
#   '처음',
#   '특히',
#   '박사',
#   '나발',
#   '인물',
#   '컴퓨터',
#   '하',
#   '때',
#   '손',
#   '찍',
#   '키보드',
#   '누르',
#   '컴퓨터',
#   '화면',
#   '똑같',
#   '파트',
#   '무한',
#   '반복',
#   '허',
#   '접하',
#   '너무',
#   '허',
#   '접하',
#   '배우',
#   '연기',
#   '개떡'],
#  ['최고', '농촌', '드라마'],
#  ['독립',
#   '영화',
#   '실력자',
#   '스타',
#   '리그',
#   '옴니버스',
#   '피로감',
#   '극복',
#   '수준',
#   '얼음',
#   '강',
#   '은',
#   '단독',
#   '장편',
#   '만들',
#   '좋',
#   '주인공',
#   '혹',
#   '소라면',
#   '도',
#   '공감',
#   '안',
#   '여호와의 증인',
#   '납득',
#   '되',
#   '정도',
#   '감정',
#   '설득',
#   '솜씨',
#   '탁월'],
#  ['좀비', '좀비', '그렇', '좀비', '아니', '우주', '아름답', '미치', '인간', '일', '충분히', '가능'],
#  ['재미없', '막장', '스토리', '어거지'],
#  ['흠잡', '없', '최고'],
#  ['좋', '영화'],
#  ['탁재훈', '나오', '재밌', '스토리', '중반', '너무', '치', '약', '해약', '해약'],
#  ['서스펜스', '없', '스릴', '없'],
#  ['우리나라', '정서', '안', '맞'],
#  ['서', '많이', '보', '흔하', '스토리'],
#  ['최고', '드라마'],
#  ['모두', '누', '군가', '섬'],
#  ['힘', '알', '없', '주인공', '맥', '다', '빠지'],
#  ['너무너무', '귀엽', '영화'],
#  ['전형', '일본', '엽기', '괴짜', '코', '메', '특이', '끌리', '왜'],
#  ['오', '이상', '사람', '나루토', '극장판', '가장', '쓰'],
#  ['정당', '노력', '보상', '받', '마련', '일정', '성취', '있', '좋', '결실', '거두', '작품'],
#  ['아씨', '울'],
#  ['기적', '이미', '일어나'],
#  ['아이들', '함께', '보', '좋', '그냥'],
#  ['전율', '느끼'],
#  ['여기저기',
#   '지저분',
#   '내용',
#   '이기',
#   '사람',
#   '역겹',
#   '연애',
#   '사',
#   '마지막',
#   '갈수록',
#   '시청률',
#   '안',
#   '나오',
#   '막',
#   '가',
#   '겨',
#   '쓰',
#   '내용'],
#  ['별로', '완전', '마지막', '빼', '넘', '유치', '재미없'],
#  ['세월', '지나', '다시', '보니', '먹먹', '다르', '공감', '사람', '가슴속', '명작', '남'],
#  ['아이들', '보', '좋'],
#  ['보', '선정', '좀', '같', '액션', '좋'],
#  ['카타르시스', '느끼', '충분', '값', '진영화'],
#  ['여주', '린제이 로한', '닮', '전체', '분위기', '배경', '좋', '내용', '지루'],
#  ['솔로', '영화', '보'],
#  ['남이',
#   '안',
#   '전화',
#   '통화',
#   '하',
#   '90분',
#   '가까이',
#   '구경',
#   '있',
#   '폰부스',
#   '명작',
#   '생각',
#   '영화',
#   '진짜',
#   '장난'],
#  ['전형', '저질', '영화'],
#  ['답', '알', '하'],
#  ['재미', '잇', '매우'],
#  ['진짜', '잘', '만들', '수작'],
#  ['제발', '좀', '찍', '현기증', '나', '말'],
#  ['너무나', '따뜻', '마음', '따뜻', '한번쯤', '자신', '되돌아보', '만들', '영화'],
#  ['조금', '부족', '영화', '놀', '키', '확', '놀', '키', '어정쩡'],
#  ['소재',
#   '참',
#   '좋',
#   '내용',
#   '전개',
#   '개판',
#   '사람',
#   '수도',
#   '많',
#   '총',
#   '있',
#   '지',
#   '서로',
#   '다',
#   '흩어지',
#   '일방',
#   '밀리',
#   '식인종',
#   '표현',
#   '좀비',
#   '하',
#   '어쩌',
#   '식인',
#   '인해',
#   '인성',
#   '말살',
#   '짐승',
#   '되',
#   '표현',
#   '있'],
#  ['포스터',
#   '그럴싸',
#   '13구역',
#   '이름',
#   '가지',
#   '쓰',
#   '영화',
#   '완전',
#   '졸',
#   '작',
#   '액션',
#   '신도',
#   '개',
#   '허술',
#   '스토리',
#   '이상'],
#  ['대체', '왜', '재미없', '거지', '나', '존', '재밌'],
#  ['늑대들', '여정', '너무', '낭만', '애니', '스토리', '좋', '음악', '일본', '애니', '탑', '뛰어나'],
#  ['미국', '흑인', '민권운동', '사', '완벽', '요약'],
#  ['뛰어내리', '어떻', '되'],
#  ['나오',
#   '그냥',
#   '단순',
#   '액션',
#   '공포물',
#   '긴장감',
#   '공포감',
#   '연출',
#   '고',
#   '음악',
#   '좋',
#   '지나',
#   '기억나',
#   '인상',
#   '좀비',
#   '물',
#   '평점',
#   '너무',
#   '짜',
#   '줌'],
#  ['아역', '연기', '좋', '내용', '쓰레기'],
#  ['진짜',
#   '재미없',
#   '극장',
#   '보',
#   '없',
#   '스릴러',
#   '라',
#   '웃음',
#   '안',
#   '나오',
#   '혹시나',
#   '절대',
#   '보지',
#   '마라',
#   '진짜',
#   '제발'],
#  ['평점', '믿', '재밌'],
#  ['좋', '뭐'],
#  ['이', '영화', '냐', '영화', '냐', '쓰', '들'],
#  ['믿'],
#  ['너무', '구식', '웃기', '하', '보', '내내', '지겹'],
#  ['좋아하', '사람', '정신 세계', '궁금'],
#  ['연예', '현실', '알리', '하', '마음', '알', '영화', '재미', '없', '지루', '죽', '하'],
#  ['아주', '재미있', '책', '보', '정말', '재미', '있다'],
#  ['끝내', '재밌'],
#  ['돈', '내', '보', '낫', '생각', '들', '영화'],
#  ['아쉽', '있', '스토리', '맞', '분위기', '배경', '지하철', '기관사', '삶', '잘', '묘사'],
#  ['스타워즈',
#   '맞아떨어지',
#   '잘',
#   '만들',
#   '영화',
#   '최고',
#   '에피소드',
#   '다스',
#   '베이',
#   '더',
#   '탄생',
#   '루',
#   '크',
#   '레이어',
#   '운명',
#   '알',
#   '레전드'],
#  ['소희', '귀엽', '귀엽', '졸', '귀'],
#  ['소문나', '잔치', '호화', '캐스팅', '먹', '없'],
#  ['주성치', '영화', '최고', '졸', '작'],
#  ['굽', '웃'],
#  ['딱히', '흠잡', '두근거리', '없', '교과서', '플레이'],
#  ['영화', '중심', '스토리', '반전', '반전', '너무', '재미있'],
#  ['이'],
#  ['참', '재미있', '연기', '발', '하', '삼류', '배우', '얼굴', '보'],
#  ['재밌'],
#  ['재밌'],
#  ['아깝', '평', '쓰', '귀찮', '보', '내내', '오', '글', '걸', '손발', '사라지', '알'],
#  ['기대', '안', '보', '영화', '보', '내내', '몰입', '재미있', '보'],
#  ['유쾌',
#   '스릴러',
#   '요소',
#   '잘',
#   '어울리',
#   '명작',
#   '후속작',
#   '보다',
#   '훨씬',
#   '매력',
#   '있',
#   '두',
#   '두',
#   '간직',
#   '꺼내',
#   '영화'],
#  ['좋', '괜찮'],
#  ['명작', '너무', '좋', '드라마', '스토리', '캐스팅', '연기', '음악', '연출', '모두', '완벽'],
#  ['괜찮', '영화', '영화', '괜찮'],
#  ['일단',
#   '재미있',
#   '고래',
#   '마리',
#   '국가',
#   '호들갑',
#   '떨',
#   '오버',
#   '모습',
#   '모두',
#   '돕',
#   '살',
#   '지구의',
#   '생명',
#   '메세지',
#   '참으로',
#   '감동'],
#  ['지금', '첨', '보', '보', '보', '주말', '밤새', '완주', '여운', '많이', '남', '드라마'],
#  ['애니메이션', '뮬란', '아쉽', '전쟁', '그렇', '연기', '그렇', '이야기', '그렇', '그저', '그러'],
#  ['기대', '않', '하', '보', '앗', '진짜', '내용', '좋', '재미', '있'],
#  ['좋'],
#  ['슬프', '맑', '파문', '주목'],
#  ['김윤진', '좋아하'],
#  [],
#  ['무리수', '되', '코미디', '기획', '상품'],
#  ['나', '홀로', '집', '더불', '고의', '영화'],
#  ['떠오르', '옛날', '국산', '애니', '아마겟돈', '의', '악몽'],
#  ['완전', '역겹', '쓰레기', '영화', '기술', '수준', '떠나', '각본', '개념'],
#  ['고결', '신사', '짓', '하', '시'],
#  ['개안', '음'],
#  ['보', '너무너무', '재미있'],
#  ['김소현', '재밌'],
#  ['삐', '흑인', '남자', '싸우', '때', '재미있', '아웃', '겨'],
#  ['유럽',
#   '영화',
#   '이번',
#   '정부',
#   '많이',
#   '들어오',
#   '즐겁',
#   '하',
#   '내용',
#   '왜',
#   '이리',
#   '진부',
#   '유럽',
#   '영화',
#   '욕',
#   '하',
#   '소리'],
#  ['왜', '하', '허', '접영', '화도', '재미있', '이건', '도', '넘', '서'],
#  ['삶', '죽음', '대하', '왈가왈부', '하', '없'],
#  ['굿', '굿', '굿', '또', '또', '제발'],
#  ['주님', '부르', '제가'],
#  ['미성년자',
#   '돈',
#   '많',
#   '아저씨',
#   '순결',
#   '바치',
#   '인후',
#   '결국',
#   '정신',
#   '차리',
#   '공부',
#   '명문대',
#   '진부',
#   '결말'],
#  ['정말', '재밌', '보', '빈센트', '꼬마', '연기', '너무', '잘'],
#  ['솔직히', '원작', '훨씬', '낫', '원작', '인간', '말', '설정'],
#  ['말', '필요', '없', '진심', '재밌'],
#  ['보', '양반', '다', '세포', '소녀', '감독'],
#  ['굿', '잡', '친구', '보'],
#  ['재미', '진짜', '흥하', '새끼', '관', '종'],
#  ['야경', '엉망', '지루함'],
#  ['예원', '찡', '그만', '울'],
#  ['5년',
#   '동안',
#   '보',
#   '영화',
#   '통틀',
#   '최',
#   '악의',
#   '영화',
#   '시간',
#   '남아돌',
#   '때',
#   '보',
#   '시간',
#   '아깝',
#   '역대',
#   '급',
#   '쓰레기',
#   '영화'],
#  ['감동',
#   '참고',
#   '영화',
#   '보',
#   '신분',
#   '마지막',
#   '엔',
#   '딩',
#   '부분',
#   '자막',
#   '나오',
#   '부분',
#   '잇',
#   '이',
#   '영화상',
#   '실화',
#   '거지',
#   '진짜',
#   '레알',
#   '현재',
#   '실제로',
#   '실화',
#   '전지현',
#   '피디',
#   '잔',
#   '아',
#   '다',
#   '큐',
#   '찍',
#   '다',
#   '큐',
#   '딩',
#   '장면',
#   '진짜',
#   '실',
#   '제가',
#   '아니'],
#  ['달',
#   '기지',
#   '미',
#   '니어',
#   '치',
#   '티',
#   '팍팍',
#   '보',
#   '알',
#   '혹시',
#   '특수',
#   '효과',
#   '감독',
#   '심형래'],
#  ['재미', '드럽', '없'],
#  ['르', '게이', '작은 고추', '매운맛', '보이'],
#  ['정여립',
#   '정철',
#   '기축옥사',
#   '스토리',
#   '탄탄',
#   '좋',
#   '배우',
#   '연기',
#   '참',
#   '잘',
#   '남녀',
#   '주인공',
#   '케미',
#   '좋',
#   '챙기',
#   '보',
#   '밖',
#   '없',
#   '드라마'],
#  ['OO', '영화', '내용', '없', '심심', '만들', '영화'],
#  ['줄', '하', '알바', '많', '아', '후', '보', '없', '채널', '돌리', '다시', '돌리', '만들'],
#  ['왜', '없'],
#  ['영화사', '남', '작품', '실험', '영화', '완성', '보'],
#  ['자식', '그렇', '때리'],
#  ['이', '대체', '내용'],
#  ['이', '급', '이건', '내용', '결말', '살', '살'],
#  ['감동', '좋'],
#  ['초반', '재미없', '보', '점점', '재밌', '외계인', '알', '에일리언', '나오', '외계인'],
#  ['쇼핑백', '잊히'],
#  ['의도', '좋', '너무', '몰입', '안', '어', '떡'],
#  ['유치', '가볍', '보'],
#  ['화려',
#   '색채',
#   '눈',
#   '아프',
#   '화려',
#   '연예',
#   '여자',
#   '욕망',
#   '대하',
#   '표현',
#   '같',
#   '보',
#   '진짜',
#   '리코',
#   '심정',
#   '연예',
#   '있',
#   '같',
#   '나르',
#   '한',
#   '보',
#   '알',
#   '사람',
#   '이날',
#   '어떻',
#   '사랑',
#   '그러',
#   '대사',
#   '나오',
#   '때',
#   '소름',
#   '돋',
#   '연예인',
#   '많',
#   '사랑',
#   '받',
#   '참',
#   '허전'],
#  ['보', 'OO', '이', '지나', '아직', '생생', '고양이', '귀신', '복수', '진짜', '무섭'],
#  ['영상', '대학교', '졸업', '작품', '같', '그렇', '꽤', '많', '담', '영화', '분명'],
#  ['최강', '전차', '부대'],
#  [],
#  ['진짜', '어이없', '소재', '생각', '보', '남자', '솔직히', '조금', '부럽', '수도', '있'],
#  ['전기세', '아깝'],
#  ['초등학교',
#   '때',
#   '선생님',
#   '보이',
#   '영화',
#   '시간',
#   '흐르',
#   '기억나',
#   '에이즈',
#   '걸리',
#   '남자',
#   '아이와',
#   '운동화',
#   '그때',
#   '보',
#   '영화',
#   '궁금',
#   '영화',
#   '바로',
#   '굿바',
#   '이마이',
#   '프렌드',
#   '12년',
#   '전',
#   '12년',
#   '후',
#   '명작',
#   '시간',
#   '흐르',
#   '명작'],
#  ['넘', '재밌'],
#  ['설리', '영화', '어떻', '나'],
#  ['샷', '연결', '충돌', '거룩', '제목', '인상'],
#  ['오오',
#   '나',
#   '여태',
#   '매',
#   '최',
#   '고의',
#   '영화',
#   '본 얼티메이텀',
#   '라이언',
#   '일병',
#   '구하기',
#   '알',
#   '굿',
#   '위',
#   '헌팅',
#   '당'],
#  ['이야기', '자체', '흥미', '끌'],
#  ['날', '로그인', '만들', '청춘', '이여', '영원'],
#  ['현정', '언니', '짱', '완전', '재', '잇'],
#  ['영상미',
#   '예쁘',
#   '좋',
#   '러닝',
#   '타임',
#   '시간',
#   '넘',
#   '초반',
#   '줄거리',
#   '다',
#   '나가',
#   '엄청',
#   '지루',
#   '화보집',
#   '보',
#   '기분',
#   '일본',
#   '영화',
#   '특유',
#   '이해',
#   '못하',
#   '희한',
#   '있'],
#  ['스토리', '연결', '전혀', '안', '편집', '끼우', '맞추', '드라마', '말아먹', '작품'],
#  ['여자', '주인공', '예뻐서', '끝', '보'],
#  ['지구를 지켜라', '혹', '작품', '보', '만들'],
#  ['저렇', '힘들', '영화', '만들', '왜', '한국', '영화', '다', '쓰레기', '냐'],
#  ['살',
#   '미장센',
#   '훌륭',
#   '이야기',
#   '몰입',
#   '불필요',
#   '샷',
#   '존재',
#   '노인',
#   '위하',
#   '나라',
#   '없',
#   '먼저',
#   '보',
#   '코',
#   '감독',
#   '매력',
#   '영화',
#   '만들',
#   '멋있',
#   '사람'],
#  ['마지막', '좀', '황당', '좋', '영화'],
#  ['우연히', '돌리', '사로잡히', '최근', '10년', '보', '코미디 영화', '최고'],
#  ['열', '기', '굿', '화이팅', '해', '요', '누나'],
#  ['마이클',
#   '베이',
#   '최근작',
#   '볼',
#   '때',
#   '느끼',
#   '블록버스터',
#   '액션',
#   '장르',
#   '탄탄',
#   '시나리오',
#   '영화',
#   '필수',
#   '기대',
#   '메',
#   '폭스',
#   '늙'],
#  ['없', '너무', '후', '하네'],
#  ['미달', '연예', '바라보', '태도', '고치'],
#  ['파괴', '관객'],
#  ['알콜', '중독자', '덕', '평점', '낮'],
#  ['중견', '배우', '만들', '긴장감', '긴장감', '있', '싸우', '도술', '사', '의하', '웃음', '나오'],
#  ['남자',
#   '주인공',
#   '늑대',
#   '인간',
#   '변하',
#   '끝나',
#   '유',
#   '평점',
#   '보',
#   '안',
#   '보',
#   '하',
#   '보',
#   '재밌',
#   '유',
#   '실물',
#   '특수 효과',
#   '더',
#   '보',
#   '재미',
#   '웃기',
#   '하네',
#   '유',
#   '디',
#   '제목',
#   '번역',
#   '바보',
#   '그냥',
#   '늑대',
#   '인간'],
#  ['정말', '최고', '명작', '성인', '되', '보', '이집트', '왕자', '감동', '자체']]

# %%
# 토큰화된 tokens_list 에서 단어들의 출현 횟수를 확인
freq = Counter( word for toks in tokens_list for word in toks )
freq
# Out:
# Counter({'영화': 364,
#          '보': 262,
#          '하': 131,
#          '없': 113,
#          '있': 86,
#          '좋': 73,
#          '진짜': 68,
#          '정말': 67,
#          '안': 66,
#          '너무': 61,
#          '연기': 58,
#          '재밌': 57,
#          '같': 56,
#          '나오': 52,
#          '만들': 51,
#          '잘': 47,
#          '최고': 47,
#          '다': 46,
#          '사람': 44,
#          '왜': 43,
#          '되': 41,
#          '알': 38,
#          '내용': 36,
#          '때': 34,
#          '감동': 34,
#          '말': 34,
#          '더': 33,
#          '재미없': 32,
#          '재미': 31,
#          '아깝': 31,
#          '배우': 31,
#          '재미있': 30,
#          '생각': 30,
#          '시간': 29,
#          '드라마': 28,
#          '그냥': 28,
#          '좀': 28,
#          '평점': 27,
#          '스토리': 27,
#          '감독': 27,
#          '나': 26,
#          '이': 26,
#          '쓰레기': 26,
#          '작품': 25,
#          '모르': 24,
#          '완전': 23,
#          '지루': 22,
#          '들': 22,
#          '느낌': 21,
#          '보이': 20,
#          '남': 20,
#          '정도': 20,
#          '다시': 19,
#          '액션': 18,
#          '이렇': 18,
#          '주인공': 18,
#          '느끼': 18,
#          '재': 17,
#          '참': 17,
#          '작': 17,
#          '사랑': 17,
#          '마지막': 17,
#          '짜증': 16,
#          '이건': 16,
#          '기대': 16,
#          '인생': 16,
#          '오': 16,
#          '돈': 16,
#          '가': 16,
#          '속': 16,
#          '일본': 16,
#          '쓰': 16,
#          '넘': 15,
#          '그렇': 15,
#          '대하': 15,
#          '명작': 15,
#          '살': 15,
#          '이야기': 14,
#          '솔직히': 14,
#          '죽': 14,
#          '받': 14,
#          '많': 14,
#          '소재': 14,
#          '괜찮': 14,
#          '남자': 14,
#          '별로': 13,
#          '무섭': 13,
#          '이상': 13,
#          '볼': 12,
#          '멋지': 12,
#          '음악': 12,
#          '자체': 12,
#          '어떻': 12,
#          '장면': 12,
#          '최악': 12,
#          '기억': 12,
#          '이해': 11,
#          '걸': 11,
#          '아쉽': 11,
#          '일': 11,
#          '끝나': 11,
#          '전개': 11,
#          '슬프': 11,
#          '몰입': 11,
#          '실망': 11,
#          '전': 11,
#          '애': 11,
#          '지금': 11,
#          '인간': 11,
#          '까': 10,
#          '절대': 10,
#          '웃': 10,
#          '아직': 10,
#          '조금': 10,
#          '유치': 10,
#          '한국': 10,
#          '좋아하': 10,
#          '처음': 10,
#          '끌': 10,
#          '허': 10,
#          '당시': 10,
#          '그만': 10,
#          '찍': 10,
#          '연출': 10,
#          '높': 10,
#          '마음': 10,
#          '굿': 10,
#          '울': 9,
#          '캐스팅': 9,
#          '매력': 9,
#          '웃음': 9,
#          '감정': 9,
#          '설정': 9,
#          '진심': 9,
#          '많이': 9,
#          '짱': 9,
#          '못': 9,
#          '물': 9,
#          '잇': 9,
#          '포스터': 8,
#          '막': 8,
#          '낮': 8,
#          '꽤': 8,
#          '위하': 8,
#          '졸': 8,
#          '한': 8,
#          '크': 8,
#          '신선': 8,
#          '제일': 8,
#          '연기력': 8,
#          '결말': 8,
#          '냐': 8,
#          '따뜻': 8,
#          '지나': 8,
#          '아니': 8,
#          '전혀': 8,
#          '믿': 8,
#          '여운': 8,
#          '지': 8,
#          '표현': 8,
#          '스릴러': 8,
#          '내내': 8,
#          '여자': 8,
#          '귀엽': 8,
#          '끝': 8,
#          '너무나': 7,
#          '욕': 7,
#          '가장': 7,
#          '정신': 7,
#          '알바': 7,
#          '기분': 7,
#          '노력': 7,
#          '먹': 7,
#          '시청률': 7,
#          '눈': 7,
#          '최': 7,
#          '인상': 7,
#          '미': 7,
#          '빠지': 7,
#          '아주': 7,
#          '힘들': 7,
#          '나이': 7,
#          '자신': 7,
#          '어리': 7,
#          '요즘': 7,
#          '코미디': 7,
#          '이유': 7,
#          '아름답': 7,
#          '티': 7,
#          '필요': 7,
#          '책': 7,
#          '부족': 7,
#          '애니': 7,
#          '슬픔': 7,
#          '비디오': 7,
#          '반전': 7,
#          '공포': 7,
#          '원작': 6,
#          '긴장감': 6,
#          '가족': 6,
#          '눈물': 6,
#          '나서': 6,
#          '멜로': 6,
#          '노': 6,
#          '코': 6,
#          '발': 6,
#          '나가': 6,
#          '단순': 6,
#          '잔잔': 6,
#          '길': 6,
#          '공감': 6,
#          '초반': 6,
#          '수준': 6,
#          '누': 6,
#          '이랑': 6,
#          '다니': 6,
#          '가슴': 6,
#          '혼자': 6,
#          '대단': 6,
#          '이제': 6,
#          '가요': 6,
#          '로맨스': 6,
#          '삶': 6,
#          '다르': 6,
#          '막장': 6,
#          '주': 6,
#          '날': 6,
#          '짜': 6,
#          '시절': 6,
#          '시리즈': 6,
#          '개': 6,
#          '현실': 6,
#          '더럽': 6,
#          '게': 6,
#          '전쟁': 6,
#          '제발': 6,
#          '시나리오': 6,
#          '친구': 6,
#          '부분': 6,
#          '급': 6,
#          '또': 6,
#          '모두': 6,
#          '키': 6,
#          '더빙': 5,
#          '살리': 5,
#          '화려': 5,
#          '자극': 5,
#          '웃기': 5,
#          '갈수록': 5,
#          '구성': 5,
#          '수작': 5,
#          '꼭': 5,
#          '별점': 5,
#          '대체': 5,
#          '관객': 5,
#          '캐릭터': 5,
#          '조절': 5,
#          '딱': 5,
#          '잊': 5,
#          '깊': 5,
#          '그저': 5,
#          '중간': 5,
#          '모습': 5,
#          '예': 5,
#          '큐': 5,
#          '살인': 5,
#          '노래': 5,
#          '맞': 5,
#          '어이없': 5,
#          '매': 5,
#          '추': 5,
#          '대박': 5,
#          '흥미': 5,
#          '현실감': 5,
#          '후': 5,
#          '남기': 5,
#          '뭐': 5,
#          '건지': 5,
#          '답': 5,
#          '손': 5,
#          '충분히': 5,
#          '어린이': 5,
#          '화이팅': 5,
#          '예산': 5,
#          '읽': 5,
#          '내': 5,
#          '어': 5,
#          '추억': 5,
#          '이영화': 5,
#          '없이': 5,
#          '추천': 5,
#          '개봉': 5,
#          '접하': 5,
#          '순간': 5,
#          '으': 5,
#          '예쁘': 5,
#          '의미': 5,
#          '요': 5,
#          '세계': 5,
#          '을': 5,
#          '미치': 5,
#          '아': 5,
#          '기': 5,
#          '보니': 5,
#          '돌리': 5,
#          '안타깝': 5,
#          '결국': 5,
#          '싸우': 5,
#          '사': 5,
#          '이후': 5,
#          '완벽': 5,
#          '전작': 5,
#          '점수': 5,
#          '도': 5,
#          '좀비': 5,
#          '초등학교': 4,
#          '드럽': 4,
#          '극장': 4,
#          '고': 4,
#          '이리': 4,
#          '작가': 4,
#          '방법': 4,
#          '낭비': 4,
#          '뛰어나': 4,
#          '극': 4,
#          '소설': 4,
#          '라': 4,
#          '게이': 4,
#          '어쩌': 4,
#          '그대로': 4,
#          '악역': 4,
#          '계속': 4,
#          '우리나라': 4,
#          '깊이': 4,
#          '예전': 4,
#          '비슷': 4,
#          '안보': 4,
#          '억지': 4,
#          '어설프': 4,
#          '흥행': 4,
#          '갈등': 4,
#          '에': 4,
#          '시작': 4,
#          '유': 4,
#          '영화인': 4,
#          '태어나': 4,
#          '짬뽕': 4,
#          '거지': 4,
#          '망치': 4,
#          '보지': 4,
#          '마라': 4,
#          '특유': 4,
#          '전부': 4,
#          '쇼': 4,
#          '문제': 4,
#          '어울리': 4,
#          '나라': 4,
#          '가지': 4,
#          '상황': 4,
#          '한석규': 4,
#          '잔인': 4,
#          '뜨': 4,
#          '에선': 4,
#          '오랜만': 4,
#          '왠지': 4,
#          '한마디': 4,
#          '존': 4,
#          '치': 4,
#          '배경': 4,
#          '진부': 4,
#          '나쁘': 4,
#          '짓': 4,
#          '달': 4,
#          '알리': 4,
#          '그때': 4,
#          '대사': 4,
#          '닿': 4,
#          '코믹': 4,
#          '색다르': 4,
#          '짧': 4,
#          '먹먹': 4,
#          '개연': 4,
#          '제목': 4,
#          '군가': 4,
#          '얘기': 4,
#          '줄': 4,
#          '영상': 4,
#          '감': 4,
#          '탑': 4,
#          '사실': 4,
#          '떠나': 4,
#          '충분': 4,
#          '레전드': 4,
#          '소피': 4,
#          '바라': 4,
#          '고의': 4,
#          '공부': 4,
#          '다운': 4,
#          '감사': 4,
#          '멀': 4,
#          '자막': 4,
#          '타': 4,
#          '기키': 4,
#          '유럽': 4,
#          '영상미': 4,
#          '특히': 4,
#          '예고편': 4,
#          '연예': 4,
#          '초딩': 3,
#          '오버': 3,
#          '가볍': 3,
#          '돋보이': 3,
#          '늙': 3,
#          '떼': 3,
#          '학년': 3,
#          '반개': 3,
#          '반복': 3,
#          '못하': 3,
#          '감성': 3,
#          '절제': 3,
#          '보다': 3,
#          '취향': 3,
#          '어거지': 3,
#          '이기': 3,
#          '난': 3,
#          '뒤': 3,
#          '드': 3,
#          '착하': 3,
#          '음식': 3,
#          '평범': 3,
#          '주제': 3,
#          '중반': 3,
#          '끄': 3,
#          '연출력': 3,
#          '90년대': 3,
#          '장애': 3,
#          '거도': 3,
#          '맘': 3,
#          '불가': 3,
#          '데': 3,
#          '메': 3,
#          '잠시': 3,
#          '동화': 3,
#          '행복': 3,
#          '콩': 3,
#          '충격': 3,
#          '완전히': 3,
#          '무겁': 3,
#          '심심': 3,
#          '언제': 3,
#          '바로': 3,
#          '듣': 3,
#          '민간인': 3,
#          '학살': 3,
#          '이정': 3,
#          '에피소드': 3,
#          '재탕': 3,
#          '신': 3,
#          '실력': 3,
#          '조작': 3,
#          '열리': 3,
#          '들어가': 3,
#          '걸리': 3,
#          '매우': 3,
#          '아햏햏': 3,
#          '진정': 3,
#          '별루': 3,
#          '성룡': 3,
#          '때리': 3,
#          '이쁘': 3,
#          '새롭': 3,
#          '쪼': 3,
#          '불륜': 3,
#          '왕': 3,
#          '덜': 3,
#          '떨어지': 3,
#          '도대체': 3,
#          '미국': 3,
#          '순수': 3,
#          '아들': 3,
#          '베': 3,
#          '리': 3,
#          '여': 3,
#          '마': 3,
#          '개인': 3,
#          '국산': 3,
#          '아끼': 3,
#          '지겹': 3,
#          '죽이': 3,
#          '낫': 3,
#          '인': 3,
#          '종': 3,
#          '방': 3,
#          '오늘': 3,
#          '그리': 3,
#          '사극': 3,
#          '의하': 3,
#          '유쾌': 3,
#          '엉망': 3,
#          '절': 3,
#          '시종일관': 3,
#          '상당히': 3,
#          '얼마나': 3,
#          '밖': 3,
#          '피': 3,
#          '잠': 3,
#          '판타지': 3,
#          '옛날': 3,
#          '후회': 3,
#          '생명': 3,
#          '너무너무': 3,
#          '네이버': 3,
#          '장': 3,
#          '제로': 3,
#          '허무': 3,
#          '조연': 3,
#          '특집': 3,
#          '판': 3,
#          '서스펜스': 3,
#          '귀신': 3,
#          '댓글': 3,
#          '한번쯤': 3,
#          '답답': 3,
#          '묘사': 3,
#          '극장판': 3,
#          '역사': 3,
#          '가치': 3,
#          '시키': 3,
#          '흑인': 3,
#          '범죄': 3,
#          '느와르': 3,
#          '놓': 3,
#          '습': 3,
#          '소리': 3,
#          '적당히': 3,
#          '글': 3,
#          '이름': 3,
#          '두': 3,
#          '망하': 3,
#          '아이': 3,
#          '시선': 3,
#          '겁나': 3,
#          '여주인공': 3,
#          '중요': 3,
#          '여배우': 3,
#          '지루함': 3,
#          '닮': 3,
#          '비': 3,
#          '연예인': 3,
#          '돌아가': 3,
#          '과': 3,
#          '세상': 3,
#          '아빠': 3,
#          '앗': 3,
#          '의도': 3,
#          '강하': 3,
#          '첨': 3,
#          '해': 3,
#          '탄탄': 3,
#          '사회': 3,
#          '실제': 3,
#          '검술': 3,
#          '미스': 3,
#          '그러': 3,
#          '멋있': 3,
#          '빨리': 3,
#          '중심': 3,
#          '나중': 3,
#          '사촌': 3,
#          '제가': 3,
#          '흐르': 3,
#          '실제로': 3,
#          '늦': 3,
#          '망': 3,
#          '도움': 3,
#          '장난': 3,
#          '보내': 3,
#          '서로': 3,
#          '잃': 3,
#          '유대인': 3,
#          '엔': 3,
#          '딩': 3,
#          '영화관': 3,
#          '몰': 3,
#          '놀': 3,
#          '청춘': 3,
#          '복수': 3,
#          '해주': 3,
#          '평생': 3,
#          '생각나': 3,
#          '짐승': 3,
#          '숨': 3,
#          '싸구려': 3,
#          '밝히': 3,
#          '질질': 3,
#          '터지': 3,
#          '겨': 3,
#          '상영': 3,
#          '미화': 3,
#          '엉성': 3,
#          '싫어하': 3,
#          '아저씨': 3,
#          '역겹': 3,
#          '일찍': 3,
#          '얼굴': 3,
#          '같이': 3,
#          '간만': 3,
#          '독립': 3,
#          '업': 3,
#          '외계인': 3,
#          '주온': 3,
#          '존재': 3,
#          '기억나': 3,
#          '차라리': 3,
#          '실화': 3,
#          '동생': 3,
#          '아이들': 3,
#          '여성': 3,
#          '분위기': 3,
#          '비하': 3,
#          '궁금': 3,
#          '목소리': 2,
#          '용': 2,
#          '별': 2,
#          '제대로': 2,
#          '생활': 2,
#          '발로': 2,
#          '헐리우드': 2,
#          '향수': 2,
#          '담백': 2,
#          '깔끔': 2,
#          '기사': 2,
#          '자꾸': 2,
#          '깔': 2,
#          '깨알': 2,
#          '러': 2,
#          '뜻': 2,
#          '가능': 2,
#          '만찬': 2,
#          '드리': 2,
#          '납득': 2,
#          '고추': 2,
#          '센스': 2,
#          '탁월': 2,
#          '포스': 2,
#          '깨닫': 2,
#          '꽃': 2,
#          '죄인': 2,
#          '열정': 2,
#          '안나': 2,
#          '평가': 2,
#          '은은': 2,
#          '서리': 2,
#          '일탈': 2,
#          '이민기': 2,
#          '패': 2,
#          '물건': 2,
#          '상태': 2,
#          '마이너스': 2,
#          '가르': 2,
#          '르': 2,
#          '매운맛': 2,
#          '간다': 2,
#          '꼬마': 2,
#          '일본인': 2,
#          '당황': 2,
#          '일상': 2,
#          '전개도': 2,
#          '느리': 2,
#          '맨날': 2,
#          '빨리빨리': 2,
#          '가슴속': 2,
#          '살인자': 2,
#          '산': 2,
#          '이틀': 2,
#          '집': 2,
#          '온몸': 2,
#          '폭': 2,
#          '계': 2,
#          '뻔하': 2,
#          '사진': 2,
#          '단연': 2,
#          '우뢰': 2,
#          '내일': 2,
#          '골': 2,
#          '공주': 2,
#          '강': 2,
#          '술': 2,
#          '킬링타임': 2,
#          '떠오르': 2,
#          '허풍': 2,
#          '거북': 2,
#          '스스로': 2,
#          '텐': 2,
#          '생애': 2,
#          '연기자': 2,
#          '상대': 2,
#          '따로': 2,
#          '젤': 2,
#          '교훈': 2,
#          '케이블': 2,
#          '그릇': 2,
#          '면': 2,
#          '살짝': 2,
#          '떨': 2,
#          '이제서야': 2,
#          '감히': 2,
#          '고민': 2,
#          '여전히': 2,
#          '섹시': 2,
#          '혹시나': 2,
#          '상업': 2,
#          '노출': 2,
#          '화끈': 2,
#          '끝내': 2,
#          '드니': 2,
#          '일품': 2,
#          '껀': 2,
#          '총': 2,
#          '외국': 2,
#          '상상': 2,
#          '심하': 2,
#          '의': 2,
#          '순정': 2,
#          '앉': 2,
#          '일반': 2,
#          '통하': 2,
#          '게임': 2,
#          '거슬리': 2,
#          '인줄': 2,
#          '익숙': 2,
#          '뻑': 2,
#          '당하': 2,
#          '극치': 2,
#          '굉장히': 2,
#          '싫': 2,
#          '따지': 2,
#          '인격': 2,
#          '기존': 2,
#          '쏙': 2,
#          '도안': 2,
#          '남은': 2,
#          '싸이코': 2,
#          '돌아오': 2,
#          '무한': 2,
#          '후세': 2,
#          '시노': 2,
#          '출현': 2,
#          '새벽': 2,
#          '정': 2,
#          '미묘': 2,
#          '훈훈': 2,
#          '가져오': 2,
#          '오우삼': 2,
#          '인지': 2,
#          '꿈': 2,
#          '훌륭': 2,
#          '동급': 2,
#          '소': 2,
#          '하지': 2,
#          '짜임새': 2,
#          '허술': 2,
#          '일단': 2,
#          '괴물': 2,
#          '죽기': 2,
#          '직전': 2,
#          '란': 2,
#          '보기': 2,
#          '역': 2,
#          '이그': 2,
#          '기도': 2,
#          '정치인': 2,
#          '모순': 2,
#          '인가': 2,
#          '하니': 2,
#          '전화': 2,
#          '개그': 2,
#          '없애': 2,
#          '푸': 2,
#          '감각': 2,
#          '바라보': 2,
#          '엄마': 2,
#          '딸': 2,
#          '화': 2,
#          '생생': 2,
#          '제맛': 2,
#          '말이': 2,
#          '본인': 2,
#          '피해자': 2,
#          '필름': 2,
#          '값': 2,
#          '남주인공': 2,
#          '혀': 2,
#          '분이': 2,
#          '스릴': 2,
#          '전달': 2,
#          '거리': 2,
#          '씩': 2,
#          '언니': 2,
#          '부르': 2,
#          '즐겁': 2,
#          '레알': 2,
#          '어색': 2,
#          '폭탄': 2,
#          '가나': 2,
#          '딸리': 2,
#          '굳': 2,
#          '호구': 2,
#          '세기': 2,
#          '쓸데없이': 2,
#          '류': 2,
#          '고위': 2,
#          '넘어가': 2,
#          '아역': 2,
#          '민폐': 2,
#          '그럴싸': 2,
#          '딱히': 2,
#          '송강호': 2,
#          '그립': 2,
#          '해석': 2,
#          '한심': 2,
#          '끼': 2,
#          '영화로': 2,
#          '비정': 2,
#          '다듬': 2,
#          '비롯': 2,
#          '민망': 2,
#          '군더더기': 2,
#          '진행': 2,
#          '빠': 2,
#          '애니메이션': 2,
#          '불쾌': 2,
#          '연인': 2,
#          '5년': 2,
#          '국민': 2,
#          '해서': 2,
#          '하나님': 2,
#          '이신': 2,
#          '흥미진진': 2,
#          '점점': 2,
#          '이번': 2,
#          '지존파': 2,
#          '삼': 2,
#          '정당화': 2,
#          '정부': 2,
#          '탓': 2,
#          '중국': 2,
#          '하트': 2,
#          '평균': 2,
#          '슬': 2,
#          '하기': 2,
#          '자': 2,
#          '모으': 2,
#          '메세지': 2,
#          '영화사': 2,
#          '히어로': 2,
#          '놀이': 2,
#          '사건': 2,
#          '인물': 2,
#          '빌리': 2,
#          '우연히': 2,
#          '절망': 2,
#          '챙기': 2,
#          '거부': 2,
#          '맛': 2,
#          '어마어마': 2,
#          '똥': 2,
#          '원주민': 2,
#          '일어나': 2,
#          '우': 2,
#          '견자단': 2,
#          '정말로': 2,
#          '순위': 2,
#          '그런지': 2,
#          '여배우들': 2,
#          '그래픽': 2,
#          '평론가': 2,
#          '바꾸': 2,
#          '느': 2,
#          '밥': 2,
#          '악의': 2,
#          '엄청': 2,
#          '자식': 2,
#          '살아오': 2,
#          '확실히': 2,
#          '생기': 2,
#          '사라지': 2,
#          '아픔': 2,
#          '인형': 2,
#          '찌': 2,
#          '샤넬': 2,
#          '세월': 2,
#          '찰나': 2,
#          '영원': 2,
#          '관하': 2,
#          '두근거리': 2,
#          '아무리': 2,
#          '용서': 2,
#          '초가': 2,
#          '갑자기': 2,
#          '선생님': 2,
#          '미안': 2,
#          '쥐': 2,
#          '무기': 2,
#          '약간': 2,
#          '빼': 2,
#          '녀': 2,
#          '끌리': 2,
#          '디테일': 2,
#          '찡': 2,
#          '문화': 2,
#          '전반': 2,
#          '변화': 2,
#          '벤지': 2,
#          '막히': 2,
#          '곳곳': 2,
#          '치밀': 2,
#          '안되': 2,
#          '봄': 2,
#          '라면': 2,
#          '폭풍': 2,
#          '함부로': 2,
#          '남녀': 2,
#          '웬만': 2,
#          '잘못': 2,
#          '차': 2,
#          '매니아': 2,
#          '이하': 2,
#          '오르': 2,
#          '공포물': 2,
#          '귀': 2,
#          '은': 2,
#          '벌써': 2,
#          '관람': 2,
#          '신분': 2,
#          '최근': 2,
#          '삼류': 2,
#          '스타': 2,
#          '몸매': 2,
#          '심형래': 2,
#          '전체': 2,
#          '주연': 2,
#          '엄청나': 2,
#          '초등': 2,
#          '근래': 2,
#          '제작자': 2,
#          '호화': 2,
#          '님': 2,
#          '제작': 2,
#          '원하': 2,
#          '평': 2,
#          '극장가': 2,
#          '머리': 2,
#          '묻어나': 2,
#          '여정': 2,
#          '덕': 2,
#          '박수': 2,
#          '끼우': 2,
#          '맞추': 2,
#          '무어': 2,
#          '최루': 2,
#          '걸작': 2,
#          '남편': 2,
#          '재밌는 영화': 2,
#          '쏘': 2,
#          '데리': 2,
#          '라이': 2,
#          '아련': 2,
#          '박사': 2,
#          '록': 2,
#          '철학': 2,
#          '13구역': 2,
#          '남성': 2,
#          '요소': 2,
#          '홍보': 2,
#          '팔': 2,
#          '열': 2,
#          '디': 2,
#          '주목': 2,
#          '뇌': 2,
#          '죽음': 2,
#          '우주': 2,
#          '맡': 2,
#          '예술': 2,
#          '보통': 2,
#          '고도': 2,
#          '겪': 2,
#          '쉬': 2,
#          '즐기': 2,
#          '여주': 2,
#          '시점': 2,
#          '라이언': 2,
#          '일병': 2,
#          '참고': 2,
#          '자위': 2,
#          '이거': 2,
#          '차리': 2,
#          '선정': 2,
#          '솔로': 2,
#          '링': 2,
#          ...})

# %%
# 참고
# Counter 사용한 코드를 풀어서 쓰면 아래와 같다.
# tokens_list에 있는 token들을 하나의 변수에 대입
t_s = []
for toks in tokens_list:
    for word in toks:
        t_s.append(word)
Counter(t_s)
# Out:
# Counter({'영화': 364,
#          '보': 262,
#          '하': 131,
#          '없': 113,
#          '있': 86,
#          '좋': 73,
#          '진짜': 68,
#          '정말': 67,
#          '안': 66,
#          '너무': 61,
#          '연기': 58,
#          '재밌': 57,
#          '같': 56,
#          '나오': 52,
#          '만들': 51,
#          '잘': 47,
#          '최고': 47,
#          '다': 46,
#          '사람': 44,
#          '왜': 43,
#          '되': 41,
#          '알': 38,
#          '내용': 36,
#          '때': 34,
#          '감동': 34,
#          '말': 34,
#          '더': 33,
#          '재미없': 32,
#          '재미': 31,
#          '아깝': 31,
#          '배우': 31,
#          '재미있': 30,
#          '생각': 30,
#          '시간': 29,
#          '드라마': 28,
#          '그냥': 28,
#          '좀': 28,
#          '평점': 27,
#          '스토리': 27,
#          '감독': 27,
#          '나': 26,
#          '이': 26,
#          '쓰레기': 26,
#          '작품': 25,
#          '모르': 24,
#          '완전': 23,
#          '지루': 22,
#          '들': 22,
#          '느낌': 21,
#          '보이': 20,
#          '남': 20,
#          '정도': 20,
#          '다시': 19,
#          '액션': 18,
#          '이렇': 18,
#          '주인공': 18,
#          '느끼': 18,
#          '재': 17,
#          '참': 17,
#          '작': 17,
#          '사랑': 17,
#          '마지막': 17,
#          '짜증': 16,
#          '이건': 16,
#          '기대': 16,
#          '인생': 16,
#          '오': 16,
#          '돈': 16,
#          '가': 16,
#          '속': 16,
#          '일본': 16,
#          '쓰': 16,
#          '넘': 15,
#          '그렇': 15,
#          '대하': 15,
#          '명작': 15,
#          '살': 15,
#          '이야기': 14,
#          '솔직히': 14,
#          '죽': 14,
#          '받': 14,
#          '많': 14,
#          '소재': 14,
#          '괜찮': 14,
#          '남자': 14,
#          '별로': 13,
#          '무섭': 13,
#          '이상': 13,
#          '볼': 12,
#          '멋지': 12,
#          '음악': 12,
#          '자체': 12,
#          '어떻': 12,
#          '장면': 12,
#          '최악': 12,
#          '기억': 12,
#          '이해': 11,
#          '걸': 11,
#          '아쉽': 11,
#          '일': 11,
#          '끝나': 11,
#          '전개': 11,
#          '슬프': 11,
#          '몰입': 11,
#          '실망': 11,
#          '전': 11,
#          '애': 11,
#          '지금': 11,
#          '인간': 11,
#          '까': 10,
#          '절대': 10,
#          '웃': 10,
#          '아직': 10,
#          '조금': 10,
#          '유치': 10,
#          '한국': 10,
#          '좋아하': 10,
#          '처음': 10,
#          '끌': 10,
#          '허': 10,
#          '당시': 10,
#          '그만': 10,
#          '찍': 10,
#          '연출': 10,
#          '높': 10,
#          '마음': 10,
#          '굿': 10,
#          '울': 9,
#          '캐스팅': 9,
#          '매력': 9,
#          '웃음': 9,
#          '감정': 9,
#          '설정': 9,
#          '진심': 9,
#          '많이': 9,
#          '짱': 9,
#          '못': 9,
#          '물': 9,
#          '잇': 9,
#          '포스터': 8,
#          '막': 8,
#          '낮': 8,
#          '꽤': 8,
#          '위하': 8,
#          '졸': 8,
#          '한': 8,
#          '크': 8,
#          '신선': 8,
#          '제일': 8,
#          '연기력': 8,
#          '결말': 8,
#          '냐': 8,
#          '따뜻': 8,
#          '지나': 8,
#          '아니': 8,
#          '전혀': 8,
#          '믿': 8,
#          '여운': 8,
#          '지': 8,
#          '표현': 8,
#          '스릴러': 8,
#          '내내': 8,
#          '여자': 8,
#          '귀엽': 8,
#          '끝': 8,
#          '너무나': 7,
#          '욕': 7,
#          '가장': 7,
#          '정신': 7,
#          '알바': 7,
#          '기분': 7,
#          '노력': 7,
#          '먹': 7,
#          '시청률': 7,
#          '눈': 7,
#          '최': 7,
#          '인상': 7,
#          '미': 7,
#          '빠지': 7,
#          '아주': 7,
#          '힘들': 7,
#          '나이': 7,
#          '자신': 7,
#          '어리': 7,
#          '요즘': 7,
#          '코미디': 7,
#          '이유': 7,
#          '아름답': 7,
#          '티': 7,
#          '필요': 7,
#          '책': 7,
#          '부족': 7,
#          '애니': 7,
#          '슬픔': 7,
#          '비디오': 7,
#          '반전': 7,
#          '공포': 7,
#          '원작': 6,
#          '긴장감': 6,
#          '가족': 6,
#          '눈물': 6,
#          '나서': 6,
#          '멜로': 6,
#          '노': 6,
#          '코': 6,
#          '발': 6,
#          '나가': 6,
#          '단순': 6,
#          '잔잔': 6,
#          '길': 6,
#          '공감': 6,
#          '초반': 6,
#          '수준': 6,
#          '누': 6,
#          '이랑': 6,
#          '다니': 6,
#          '가슴': 6,
#          '혼자': 6,
#          '대단': 6,
#          '이제': 6,
#          '가요': 6,
#          '로맨스': 6,
#          '삶': 6,
#          '다르': 6,
#          '막장': 6,
#          '주': 6,
#          '날': 6,
#          '짜': 6,
#          '시절': 6,
#          '시리즈': 6,
#          '개': 6,
#          '현실': 6,
#          '더럽': 6,
#          '게': 6,
#          '전쟁': 6,
#          '제발': 6,
#          '시나리오': 6,
#          '친구': 6,
#          '부분': 6,
#          '급': 6,
#          '또': 6,
#          '모두': 6,
#          '키': 6,
#          '더빙': 5,
#          '살리': 5,
#          '화려': 5,
#          '자극': 5,
#          '웃기': 5,
#          '갈수록': 5,
#          '구성': 5,
#          '수작': 5,
#          '꼭': 5,
#          '별점': 5,
#          '대체': 5,
#          '관객': 5,
#          '캐릭터': 5,
#          '조절': 5,
#          '딱': 5,
#          '잊': 5,
#          '깊': 5,
#          '그저': 5,
#          '중간': 5,
#          '모습': 5,
#          '예': 5,
#          '큐': 5,
#          '살인': 5,
#          '노래': 5,
#          '맞': 5,
#          '어이없': 5,
#          '매': 5,
#          '추': 5,
#          '대박': 5,
#          '흥미': 5,
#          '현실감': 5,
#          '후': 5,
#          '남기': 5,
#          '뭐': 5,
#          '건지': 5,
#          '답': 5,
#          '손': 5,
#          '충분히': 5,
#          '어린이': 5,
#          '화이팅': 5,
#          '예산': 5,
#          '읽': 5,
#          '내': 5,
#          '어': 5,
#          '추억': 5,
#          '이영화': 5,
#          '없이': 5,
#          '추천': 5,
#          '개봉': 5,
#          '접하': 5,
#          '순간': 5,
#          '으': 5,
#          '예쁘': 5,
#          '의미': 5,
#          '요': 5,
#          '세계': 5,
#          '을': 5,
#          '미치': 5,
#          '아': 5,
#          '기': 5,
#          '보니': 5,
#          '돌리': 5,
#          '안타깝': 5,
#          '결국': 5,
#          '싸우': 5,
#          '사': 5,
#          '이후': 5,
#          '완벽': 5,
#          '전작': 5,
#          '점수': 5,
#          '도': 5,
#          '좀비': 5,
#          '초등학교': 4,
#          '드럽': 4,
#          '극장': 4,
#          '고': 4,
#          '이리': 4,
#          '작가': 4,
#          '방법': 4,
#          '낭비': 4,
#          '뛰어나': 4,
#          '극': 4,
#          '소설': 4,
#          '라': 4,
#          '게이': 4,
#          '어쩌': 4,
#          '그대로': 4,
#          '악역': 4,
#          '계속': 4,
#          '우리나라': 4,
#          '깊이': 4,
#          '예전': 4,
#          '비슷': 4,
#          '안보': 4,
#          '억지': 4,
#          '어설프': 4,
#          '흥행': 4,
#          '갈등': 4,
#          '에': 4,
#          '시작': 4,
#          '유': 4,
#          '영화인': 4,
#          '태어나': 4,
#          '짬뽕': 4,
#          '거지': 4,
#          '망치': 4,
#          '보지': 4,
#          '마라': 4,
#          '특유': 4,
#          '전부': 4,
#          '쇼': 4,
#          '문제': 4,
#          '어울리': 4,
#          '나라': 4,
#          '가지': 4,
#          '상황': 4,
#          '한석규': 4,
#          '잔인': 4,
#          '뜨': 4,
#          '에선': 4,
#          '오랜만': 4,
#          '왠지': 4,
#          '한마디': 4,
#          '존': 4,
#          '치': 4,
#          '배경': 4,
#          '진부': 4,
#          '나쁘': 4,
#          '짓': 4,
#          '달': 4,
#          '알리': 4,
#          '그때': 4,
#          '대사': 4,
#          '닿': 4,
#          '코믹': 4,
#          '색다르': 4,
#          '짧': 4,
#          '먹먹': 4,
#          '개연': 4,
#          '제목': 4,
#          '군가': 4,
#          '얘기': 4,
#          '줄': 4,
#          '영상': 4,
#          '감': 4,
#          '탑': 4,
#          '사실': 4,
#          '떠나': 4,
#          '충분': 4,
#          '레전드': 4,
#          '소피': 4,
#          '바라': 4,
#          '고의': 4,
#          '공부': 4,
#          '다운': 4,
#          '감사': 4,
#          '멀': 4,
#          '자막': 4,
#          '타': 4,
#          '기키': 4,
#          '유럽': 4,
#          '영상미': 4,
#          '특히': 4,
#          '예고편': 4,
#          '연예': 4,
#          '초딩': 3,
#          '오버': 3,
#          '가볍': 3,
#          '돋보이': 3,
#          '늙': 3,
#          '떼': 3,
#          '학년': 3,
#          '반개': 3,
#          '반복': 3,
#          '못하': 3,
#          '감성': 3,
#          '절제': 3,
#          '보다': 3,
#          '취향': 3,
#          '어거지': 3,
#          '이기': 3,
#          '난': 3,
#          '뒤': 3,
#          '드': 3,
#          '착하': 3,
#          '음식': 3,
#          '평범': 3,
#          '주제': 3,
#          '중반': 3,
#          '끄': 3,
#          '연출력': 3,
#          '90년대': 3,
#          '장애': 3,
#          '거도': 3,
#          '맘': 3,
#          '불가': 3,
#          '데': 3,
#          '메': 3,
#          '잠시': 3,
#          '동화': 3,
#          '행복': 3,
#          '콩': 3,
#          '충격': 3,
#          '완전히': 3,
#          '무겁': 3,
#          '심심': 3,
#          '언제': 3,
#          '바로': 3,
#          '듣': 3,
#          '민간인': 3,
#          '학살': 3,
#          '이정': 3,
#          '에피소드': 3,
#          '재탕': 3,
#          '신': 3,
#          '실력': 3,
#          '조작': 3,
#          '열리': 3,
#          '들어가': 3,
#          '걸리': 3,
#          '매우': 3,
#          '아햏햏': 3,
#          '진정': 3,
#          '별루': 3,
#          '성룡': 3,
#          '때리': 3,
#          '이쁘': 3,
#          '새롭': 3,
#          '쪼': 3,
#          '불륜': 3,
#          '왕': 3,
#          '덜': 3,
#          '떨어지': 3,
#          '도대체': 3,
#          '미국': 3,
#          '순수': 3,
#          '아들': 3,
#          '베': 3,
#          '리': 3,
#          '여': 3,
#          '마': 3,
#          '개인': 3,
#          '국산': 3,
#          '아끼': 3,
#          '지겹': 3,
#          '죽이': 3,
#          '낫': 3,
#          '인': 3,
#          '종': 3,
#          '방': 3,
#          '오늘': 3,
#          '그리': 3,
#          '사극': 3,
#          '의하': 3,
#          '유쾌': 3,
#          '엉망': 3,
#          '절': 3,
#          '시종일관': 3,
#          '상당히': 3,
#          '얼마나': 3,
#          '밖': 3,
#          '피': 3,
#          '잠': 3,
#          '판타지': 3,
#          '옛날': 3,
#          '후회': 3,
#          '생명': 3,
#          '너무너무': 3,
#          '네이버': 3,
#          '장': 3,
#          '제로': 3,
#          '허무': 3,
#          '조연': 3,
#          '특집': 3,
#          '판': 3,
#          '서스펜스': 3,
#          '귀신': 3,
#          '댓글': 3,
#          '한번쯤': 3,
#          '답답': 3,
#          '묘사': 3,
#          '극장판': 3,
#          '역사': 3,
#          '가치': 3,
#          '시키': 3,
#          '흑인': 3,
#          '범죄': 3,
#          '느와르': 3,
#          '놓': 3,
#          '습': 3,
#          '소리': 3,
#          '적당히': 3,
#          '글': 3,
#          '이름': 3,
#          '두': 3,
#          '망하': 3,
#          '아이': 3,
#          '시선': 3,
#          '겁나': 3,
#          '여주인공': 3,
#          '중요': 3,
#          '여배우': 3,
#          '지루함': 3,
#          '닮': 3,
#          '비': 3,
#          '연예인': 3,
#          '돌아가': 3,
#          '과': 3,
#          '세상': 3,
#          '아빠': 3,
#          '앗': 3,
#          '의도': 3,
#          '강하': 3,
#          '첨': 3,
#          '해': 3,
#          '탄탄': 3,
#          '사회': 3,
#          '실제': 3,
#          '검술': 3,
#          '미스': 3,
#          '그러': 3,
#          '멋있': 3,
#          '빨리': 3,
#          '중심': 3,
#          '나중': 3,
#          '사촌': 3,
#          '제가': 3,
#          '흐르': 3,
#          '실제로': 3,
#          '늦': 3,
#          '망': 3,
#          '도움': 3,
#          '장난': 3,
#          '보내': 3,
#          '서로': 3,
#          '잃': 3,
#          '유대인': 3,
#          '엔': 3,
#          '딩': 3,
#          '영화관': 3,
#          '몰': 3,
#          '놀': 3,
#          '청춘': 3,
#          '복수': 3,
#          '해주': 3,
#          '평생': 3,
#          '생각나': 3,
#          '짐승': 3,
#          '숨': 3,
#          '싸구려': 3,
#          '밝히': 3,
#          '질질': 3,
#          '터지': 3,
#          '겨': 3,
#          '상영': 3,
#          '미화': 3,
#          '엉성': 3,
#          '싫어하': 3,
#          '아저씨': 3,
#          '역겹': 3,
#          '일찍': 3,
#          '얼굴': 3,
#          '같이': 3,
#          '간만': 3,
#          '독립': 3,
#          '업': 3,
#          '외계인': 3,
#          '주온': 3,
#          '존재': 3,
#          '기억나': 3,
#          '차라리': 3,
#          '실화': 3,
#          '동생': 3,
#          '아이들': 3,
#          '여성': 3,
#          '분위기': 3,
#          '비하': 3,
#          '궁금': 3,
#          '목소리': 2,
#          '용': 2,
#          '별': 2,
#          '제대로': 2,
#          '생활': 2,
#          '발로': 2,
#          '헐리우드': 2,
#          '향수': 2,
#          '담백': 2,
#          '깔끔': 2,
#          '기사': 2,
#          '자꾸': 2,
#          '깔': 2,
#          '깨알': 2,
#          '러': 2,
#          '뜻': 2,
#          '가능': 2,
#          '만찬': 2,
#          '드리': 2,
#          '납득': 2,
#          '고추': 2,
#          '센스': 2,
#          '탁월': 2,
#          '포스': 2,
#          '깨닫': 2,
#          '꽃': 2,
#          '죄인': 2,
#          '열정': 2,
#          '안나': 2,
#          '평가': 2,
#          '은은': 2,
#          '서리': 2,
#          '일탈': 2,
#          '이민기': 2,
#          '패': 2,
#          '물건': 2,
#          '상태': 2,
#          '마이너스': 2,
#          '가르': 2,
#          '르': 2,
#          '매운맛': 2,
#          '간다': 2,
#          '꼬마': 2,
#          '일본인': 2,
#          '당황': 2,
#          '일상': 2,
#          '전개도': 2,
#          '느리': 2,
#          '맨날': 2,
#          '빨리빨리': 2,
#          '가슴속': 2,
#          '살인자': 2,
#          '산': 2,
#          '이틀': 2,
#          '집': 2,
#          '온몸': 2,
#          '폭': 2,
#          '계': 2,
#          '뻔하': 2,
#          '사진': 2,
#          '단연': 2,
#          '우뢰': 2,
#          '내일': 2,
#          '골': 2,
#          '공주': 2,
#          '강': 2,
#          '술': 2,
#          '킬링타임': 2,
#          '떠오르': 2,
#          '허풍': 2,
#          '거북': 2,
#          '스스로': 2,
#          '텐': 2,
#          '생애': 2,
#          '연기자': 2,
#          '상대': 2,
#          '따로': 2,
#          '젤': 2,
#          '교훈': 2,
#          '케이블': 2,
#          '그릇': 2,
#          '면': 2,
#          '살짝': 2,
#          '떨': 2,
#          '이제서야': 2,
#          '감히': 2,
#          '고민': 2,
#          '여전히': 2,
#          '섹시': 2,
#          '혹시나': 2,
#          '상업': 2,
#          '노출': 2,
#          '화끈': 2,
#          '끝내': 2,
#          '드니': 2,
#          '일품': 2,
#          '껀': 2,
#          '총': 2,
#          '외국': 2,
#          '상상': 2,
#          '심하': 2,
#          '의': 2,
#          '순정': 2,
#          '앉': 2,
#          '일반': 2,
#          '통하': 2,
#          '게임': 2,
#          '거슬리': 2,
#          '인줄': 2,
#          '익숙': 2,
#          '뻑': 2,
#          '당하': 2,
#          '극치': 2,
#          '굉장히': 2,
#          '싫': 2,
#          '따지': 2,
#          '인격': 2,
#          '기존': 2,
#          '쏙': 2,
#          '도안': 2,
#          '남은': 2,
#          '싸이코': 2,
#          '돌아오': 2,
#          '무한': 2,
#          '후세': 2,
#          '시노': 2,
#          '출현': 2,
#          '새벽': 2,
#          '정': 2,
#          '미묘': 2,
#          '훈훈': 2,
#          '가져오': 2,
#          '오우삼': 2,
#          '인지': 2,
#          '꿈': 2,
#          '훌륭': 2,
#          '동급': 2,
#          '소': 2,
#          '하지': 2,
#          '짜임새': 2,
#          '허술': 2,
#          '일단': 2,
#          '괴물': 2,
#          '죽기': 2,
#          '직전': 2,
#          '란': 2,
#          '보기': 2,
#          '역': 2,
#          '이그': 2,
#          '기도': 2,
#          '정치인': 2,
#          '모순': 2,
#          '인가': 2,
#          '하니': 2,
#          '전화': 2,
#          '개그': 2,
#          '없애': 2,
#          '푸': 2,
#          '감각': 2,
#          '바라보': 2,
#          '엄마': 2,
#          '딸': 2,
#          '화': 2,
#          '생생': 2,
#          '제맛': 2,
#          '말이': 2,
#          '본인': 2,
#          '피해자': 2,
#          '필름': 2,
#          '값': 2,
#          '남주인공': 2,
#          '혀': 2,
#          '분이': 2,
#          '스릴': 2,
#          '전달': 2,
#          '거리': 2,
#          '씩': 2,
#          '언니': 2,
#          '부르': 2,
#          '즐겁': 2,
#          '레알': 2,
#          '어색': 2,
#          '폭탄': 2,
#          '가나': 2,
#          '딸리': 2,
#          '굳': 2,
#          '호구': 2,
#          '세기': 2,
#          '쓸데없이': 2,
#          '류': 2,
#          '고위': 2,
#          '넘어가': 2,
#          '아역': 2,
#          '민폐': 2,
#          '그럴싸': 2,
#          '딱히': 2,
#          '송강호': 2,
#          '그립': 2,
#          '해석': 2,
#          '한심': 2,
#          '끼': 2,
#          '영화로': 2,
#          '비정': 2,
#          '다듬': 2,
#          '비롯': 2,
#          '민망': 2,
#          '군더더기': 2,
#          '진행': 2,
#          '빠': 2,
#          '애니메이션': 2,
#          '불쾌': 2,
#          '연인': 2,
#          '5년': 2,
#          '국민': 2,
#          '해서': 2,
#          '하나님': 2,
#          '이신': 2,
#          '흥미진진': 2,
#          '점점': 2,
#          '이번': 2,
#          '지존파': 2,
#          '삼': 2,
#          '정당화': 2,
#          '정부': 2,
#          '탓': 2,
#          '중국': 2,
#          '하트': 2,
#          '평균': 2,
#          '슬': 2,
#          '하기': 2,
#          '자': 2,
#          '모으': 2,
#          '메세지': 2,
#          '영화사': 2,
#          '히어로': 2,
#          '놀이': 2,
#          '사건': 2,
#          '인물': 2,
#          '빌리': 2,
#          '우연히': 2,
#          '절망': 2,
#          '챙기': 2,
#          '거부': 2,
#          '맛': 2,
#          '어마어마': 2,
#          '똥': 2,
#          '원주민': 2,
#          '일어나': 2,
#          '우': 2,
#          '견자단': 2,
#          '정말로': 2,
#          '순위': 2,
#          '그런지': 2,
#          '여배우들': 2,
#          '그래픽': 2,
#          '평론가': 2,
#          '바꾸': 2,
#          '느': 2,
#          '밥': 2,
#          '악의': 2,
#          '엄청': 2,
#          '자식': 2,
#          '살아오': 2,
#          '확실히': 2,
#          '생기': 2,
#          '사라지': 2,
#          '아픔': 2,
#          '인형': 2,
#          '찌': 2,
#          '샤넬': 2,
#          '세월': 2,
#          '찰나': 2,
#          '영원': 2,
#          '관하': 2,
#          '두근거리': 2,
#          '아무리': 2,
#          '용서': 2,
#          '초가': 2,
#          '갑자기': 2,
#          '선생님': 2,
#          '미안': 2,
#          '쥐': 2,
#          '무기': 2,
#          '약간': 2,
#          '빼': 2,
#          '녀': 2,
#          '끌리': 2,
#          '디테일': 2,
#          '찡': 2,
#          '문화': 2,
#          '전반': 2,
#          '변화': 2,
#          '벤지': 2,
#          '막히': 2,
#          '곳곳': 2,
#          '치밀': 2,
#          '안되': 2,
#          '봄': 2,
#          '라면': 2,
#          '폭풍': 2,
#          '함부로': 2,
#          '남녀': 2,
#          '웬만': 2,
#          '잘못': 2,
#          '차': 2,
#          '매니아': 2,
#          '이하': 2,
#          '오르': 2,
#          '공포물': 2,
#          '귀': 2,
#          '은': 2,
#          '벌써': 2,
#          '관람': 2,
#          '신분': 2,
#          '최근': 2,
#          '삼류': 2,
#          '스타': 2,
#          '몸매': 2,
#          '심형래': 2,
#          '전체': 2,
#          '주연': 2,
#          '엄청나': 2,
#          '초등': 2,
#          '근래': 2,
#          '제작자': 2,
#          '호화': 2,
#          '님': 2,
#          '제작': 2,
#          '원하': 2,
#          '평': 2,
#          '극장가': 2,
#          '머리': 2,
#          '묻어나': 2,
#          '여정': 2,
#          '덕': 2,
#          '박수': 2,
#          '끼우': 2,
#          '맞추': 2,
#          '무어': 2,
#          '최루': 2,
#          '걸작': 2,
#          '남편': 2,
#          '재밌는 영화': 2,
#          '쏘': 2,
#          '데리': 2,
#          '라이': 2,
#          '아련': 2,
#          '박사': 2,
#          '록': 2,
#          '철학': 2,
#          '13구역': 2,
#          '남성': 2,
#          '요소': 2,
#          '홍보': 2,
#          '팔': 2,
#          '열': 2,
#          '디': 2,
#          '주목': 2,
#          '뇌': 2,
#          '죽음': 2,
#          '우주': 2,
#          '맡': 2,
#          '예술': 2,
#          '보통': 2,
#          '고도': 2,
#          '겪': 2,
#          '쉬': 2,
#          '즐기': 2,
#          '여주': 2,
#          '시점': 2,
#          '라이언': 2,
#          '일병': 2,
#          '참고': 2,
#          '자위': 2,
#          '이거': 2,
#          '차리': 2,
#          '선정': 2,
#          '솔로': 2,
#          '링': 2,
#          ...})

# %% [markdown]
# 단어 사전 생성
# - 사전 이름 vocab
# - 단어들의 최소 출현 횟수 2회
# - 단어 사전 생성 시 \<PAD>, \<UNK>를 가장 앞에 지정

# %%
# 단어 사전 생성
min_count = 2

# 특수 토큰 2개를 먼저 대입
f_vocab = ["<PAD>", "<UNK>"]
b_vocab = []

# 방법 1
for word, cnt in freq.items():
    # cnt(출현 횟수)가 min_count(최소 출현 횟수)보다 크거나 같은 경우
    if cnt >= min_count:
        b_vocab.append(word)

f_vocab + b_vocab
# Out:
# ['<PAD>',
#  '<UNK>',
#  '더빙',
#  '진짜',
#  '짜증',
#  '나',
#  '목소리',
#  '포스터',
#  '초딩',
#  '영화',
#  '오버',
#  '연기',
#  '가볍',
#  '이야기',
#  '솔직히',
#  '재미',
#  '없',
#  '평점',
#  '돋보이',
#  '늙',
#  '보이',
#  '하',
#  '너무나',
#  '막',
#  '떼',
#  '초등학교',
#  '학년',
#  '용',
#  '별',
#  '반개',
#  '아깝',
#  '원작',
#  '긴장감',
#  '제대로',
#  '살리',
#  '욕',
#  '나오',
#  '생활',
#  '이',
#  '정말',
#  '발로',
#  '반복',
#  '드라마',
#  '가족',
#  '못하',
#  '사람',
#  '액션',
#  '있',
#  '안',
#  '왜',
#  '낮',
#  '꽤',
#  '보',
#  '헐리우드',
#  '화려',
#  '너무',
#  '볼',
#  '때',
#  '눈물',
#  '나서',
#  '죽',
#  '향수',
#  '자극',
#  '감성',
#  '절제',
#  '멜로',
#  '울',
#  '드럽',
#  '담백',
#  '깔끔',
#  '좋',
#  '기사',
#  '보다',
#  '자꾸',
#  '취향',
#  '극장',
#  '가장',
#  '노',
#  '재',
#  '감동',
#  '스토리',
#  '어거지',
#  '참',
#  '웃기',
#  '이기',
#  '코',
#  '까',
#  '고',
#  '깔',
#  '그냥',
#  '난',
#  '이해',
#  '뒤',
#  '갈수록',
#  '재미없',
#  '이건',
#  '깨알',
#  '캐스팅',
#  '내용',
#  '구성',
#  '잘',
#  '러',
#  '드',
#  '위하',
#  '착하',
#  '절대',
#  '뜻',
#  '웃',
#  '가능',
#  '지루',
#  '같',
#  '음식',
#  '만찬',
#  '넘',
#  '별로',
#  '평범',
#  '수작',
#  '드리',
#  '주제',
#  '중반',
#  '다',
#  '납득',
#  '그렇',
#  '꼭',
#  '걸',
#  '끄',
#  '고추',
#  '발',
#  '센스',
#  '연출력',
#  '탁월',
#  '90년대',
#  '포스',
#  '다시',
#  '깨닫',
#  '남',
#  '꽃',
#  '완전',
#  '졸',
#  '쓰레기',
#  '시간',
#  '재밌',
#  '별점',
#  '이리',
#  '기대',
#  '죄인',
#  '아직',
#  '인생',
#  '최고',
#  '대하',
#  '열정',
#  '안나',
#  '대체',
#  '정신',
#  '장애',
#  '작가',
#  '나가',
#  '재미있',
#  '관객',
#  '이렇',
#  '평가',
#  '받',
#  '모르',
#  '단순',
#  '은은',
#  '매력',
#  '알바',
#  '무섭',
#  '거도',
#  '오',
#  '서리',
#  '한',
#  '맘',
#  '들',
#  '방법',
#  '멋지',
#  '배우',
#  '되',
#  '일탈',
#  '잔잔',
#  '음악',
#  '조금',
#  '아쉽',
#  '길',
#  '낭비',
#  '돈',
#  '뛰어나',
#  '크',
#  '공감',
#  '가',
#  '이민기',
#  '캐릭터',
#  '조절',
#  '일',
#  '패',
#  '물건',
#  '극',
#  '초반',
#  '신선',
#  '상태',
#  '불가',
#  '마이너스',
#  '수준',
#  '딱',
#  '알',
#  '만들',
#  '데',
#  '가르',
#  '누',
#  '이랑',
#  '다니',
#  '소설',
#  '속',
#  '제일',
#  '메',
#  '라',
#  '웃음',
#  '감독',
#  '잠시',
#  '잊',
#  '동화',
#  '행복',
#  '르',
#  '게이',
#  '작',
#  '매운맛',
#  '콩',
#  '간다',
#  '가슴',
#  '자체',
#  '꼬마',
#  '깊',
#  '혼자',
#  '어쩌',
#  '충격',
#  '기분',
#  '완전히',
#  '느낌',
#  '무겁',
#  '그저',
#  '일본인',
#  '대단',
#  '생각',
#  '심심',
#  '그대로',
#  '악역',
#  '당황',
#  '중간',
#  '끝나',
#  '일상',
#  '계속',
#  '전개도',
#  '느리',
#  '주인공',
#  '모습',
#  '맨날',
#  '언제',
#  '전개',
#  '좀',
#  '빨리빨리',
#  '사랑',
#  '가슴속',
#  '감정',
#  '예',
#  '말',
#  '많',
#  '큐',
#  '우리나라',
#  '슬프',
#  '깊이',
#  '바로',
#  '노력',
#  '듣',
#  '민간인',
#  '학살',
#  '이정',
#  '살인',
#  '살인자',
#  '예전',
#  '작품',
#  '에피소드',
#  '재탕',
#  '먹',
#  '산',
#  '시청률',
#  '이제',
#  '연기력',
#  '몰입',
#  '비슷',
#  '안보',
#  '신',
#  '노래',
#  '실력',
#  '맞',
#  '일본',
#  '유치',
#  '이틀',
#  '조작',
#  '열리',
#  '집',
#  '들어가',
#  '걸리',
#  '억지',
#  '더',
#  '어설프',
#  '어이없',
#  '결말',
#  '온몸',
#  '폭',
#  '매우',
#  '실망',
#  '한국',
#  '흥행',
#  '갈등',
#  '계',
#  '에',
#  '뻔하',
#  '아햏햏',
#  '시작',
#  '사진',
#  '단연',
#  '우뢰',
#  '매',
#  '진정',
#  '별루',
#  '내일',
#  '좋아하',
#  '가요',
#  '골',
#  '눈',
#  '성룡',
#  '최',
#  '때리',
#  '이쁘',
#  '공주',
#  '인상',
#  '강',
#  '추',
#  '설정',
#  '새롭',
#  '미',
#  '유',
#  '대박',
#  '진심',
#  '영화인',
#  '쓰',
#  '술',
#  '어떻',
#  '킬링타임',
#  '떠오르',
#  '빠지',
#  '쪼',
#  '태어나',
#  '처음',
#  '불륜',
#  '로맨스',
#  '냐',
#  '왕',
#  '아주',
#  '짬뽕',
#  '덜',
#  '거지',
#  '명작',
#  '망치',
#  '소재',
#  '흥미',
#  '끌',
#  '보지',
#  '마라',
#  '특유',
#  '허풍',
#  '현실감',
#  '떨어지',
#  '거북',
#  '도대체',
#  '스스로',
#  '텐',
#  '미국',
#  '따뜻',
#  '삶',
#  '생애',
#  '전부',
#  '지나',
#  '후',
#  '남기',
#  '아니',
#  '순수',
#  '쇼',
#  '허',
#  '문제',
#  '연기자',
#  '전혀',
#  '어울리',
#  '상대',
#  '따로',
#  '아들',
#  '젤',
#  '베',
#  '나라',
#  '믿',
#  '가지',
#  '교훈',
#  '당시',
#  '상황',
#  '케이블',
#  '그만',
#  '다르',
#  '리',
#  '그릇',
#  '뭐',
#  '건지',
#  '한석규',
#  '많이',
#  '면',
#  '여',
#  '전',
#  '힘들',
#  '정도',
#  '마지막',
#  '살짝',
#  '떨',
#  '마',
#  '짱',
#  '이제서야',
#  '감히',
#  '살',
#  '고민',
#  '나이',
#  '여전히',
#  '섹시',
#  '혹시나',
#  '답',
#  '여운',
#  '손',
#  '상업',
#  '충분히',
#  '개인',
#  '잔인',
#  '노출',
#  '화끈',
#  '국산',
#  '아끼',
#  '끝내',
#  '지겹',
#  '드니',
#  '일품',
#  '죽이',
#  '괜찮',
#  '지',
#  '뜨',
#  '찍',
#  '껀',
#  '자신',
#  '어린이',
#  '어리',
#  '낫',
#  '인',
#  '총',
#  '에선',
#  '외국',
#  '상상',
#  '오랜만',
#  '종',
#  '방',
#  '오늘',
#  '요즘',
#  '막장',
#  '그리',
#  '심하',
#  '화이팅',
#  '의',
#  '순정',
#  '사극',
#  '왠지',
#  '코미디',
#  '의하',
#  '장면',
#  '한마디',
#  '존',
#  '유쾌',
#  '치',
#  '앉',
#  '이유',
#  '일반',
#  '통하',
#  '게임',
#  '배경',
#  '거슬리',
#  '엉망',
#  '주',
#  '못',
#  '예산',
#  '물',
#  '인줄',
#  '절',
#  '최악',
#  '아름답',
#  '익숙',
#  '뻑',
#  '읽',
#  '당하',
#  '극치',
#  '굉장히',
#  '남자',
#  '애',
#  '시종일관',
#  '싫',
#  '날',
#  '상당히',
#  '얼마나',
#  '진부',
#  '밖',
#  '티',
#  '짜',
#  '내',
#  '피',
#  '잠',
#  '판타지',
#  '따지',
#  '인격',
#  '어',
#  '옛날',
#  '시절',
#  '추억',
#  '나쁘',
#  '짓',
#  '기존',
#  '쏙',
#  '후회',
#  '도안',
#  '이영화',
#  '남은',
#  '없이',
#  '추천',
#  '싸이코',
#  '개봉',
#  '접하',
#  '순간',
#  '돌아오',
#  '무한',
#  '시리즈',
#  '달',
#  '후세',
#  '표현',
#  '생명',
#  '시노',
#  '출현',
#  '으',
#  '알리',
#  '새벽',
#  '개',
#  '예쁘',
#  '정',
#  '필요',
#  '미묘',
#  '너무너무',
#  '훈훈',
#  '네이버',
#  '장',
#  '가져오',
#  '오우삼',
#  '연출',
#  '인지',
#  '현실',
#  '제로',
#  '그때',
#  '느끼',
#  '대사',
#  '높',
#  '더럽',
#  '닿',
#  '허무',
#  '조연',
#  '꿈',
#  '특집',
#  '훌륭',
#  '판',
#  '의미',
#  '동급',
#  '마음',
#  '소',
#  '하지',
#  '코믹',
#  '짜임새',
#  '허술',
#  '일단',
#  '괴물',
#  '서스펜스',
#  '귀신',
#  '댓글',
#  '한번쯤',
#  '죽기',
#  '직전',
#  '란',
#  '보기',
#  '게',
#  '요',
#  '역',
#  '이그',
#  '기도',
#  '답답',
#  '정치인',
#  '모순',
#  '인가',
#  '전쟁',
#  '묘사',
#  '극장판',
#  '하니',
#  '전화',
#  '개그',
#  '없애',
#  '푸',
#  '세계',
#  '역사',
#  '가치',
#  '감각',
#  '바라보',
#  '색다르',
#  '엄마',
#  '딸',
#  '시키',
#  '제발',
#  '책',
#  '을',
#  '미치',
#  '화',
#  '흑인',
#  '생생',
#  '이상',
#  '아',
#  '굿',
#  '제맛',
#  '범죄',
#  '느와르',
#  '말이',
#  '본인',
#  '피해자',
#  '놓',
#  '기',
#  '필름',
#  '값',
#  '남주인공',
#  '습',
#  '혀',
#  '짧',
#  '소리',
#  '분이',
#  '적당히',
#  '스릴러',
#  '스릴',
#  '전달',
#  '글',
#  '거리',
#  '씩',
#  '부족',
#  '기억',
#  '이름',
#  '두',
#  '언니',
#  '부르',
#  '즐겁',
#  '망하',
#  '아이',
#  '시선',
#  '내내',
#  '먹먹',
#  '레알',
#  '여자',
#  '겁나',
#  '어색',
#  '여주인공',
#  '폭탄',
#  '가나',
#  '보니',
#  '딸리',
#  '개연',
#  '굳',
#  '호구',
#  '세기',
#  '쓸데없이',
#  '류',
#  '중요',
#  '여배우',
#  '고위',
#  '잇',
#  '애니',
#  '제목',
#  '지금',
#  '넘어가',
#  '군가',
#  '얘기',
#  '지루함',
#  '슬픔',
#  '아역',
#  '민폐',
#  '그럴싸',
#  '딱히',
#  '송강호',
#  '비디오',
#  '돌리',
#  '그립',
#  '해석',
#  '닮',
#  '비',
#  '한심',
#  '연예인',
#  '시나리오',
#  '끼',
#  '안타깝',
#  '돌아가',
#  '과',
#  '줄',
#  '영화로',
#  '세상',
#  '비정',
#  '친구',
#  '영상',
#  '다듬',
#  '감',
#  '부분',
#  '비롯',
#  '민망',
#  '군더더기',
#  '진행',
#  '탑',
#  '아빠',
#  '앗',
#  '빠',
#  '애니메이션',
#  '의도',
#  '불쾌',
#  '귀엽',
#  '연인',
#  '5년',
#  '강하',
#  '국민',
#  '해서',
#  '하나님',
#  '이신',
#  '흥미진진',
#  '첨',
#  '해',
#  '탄탄',
#  '점점',
#  '끝',
#  '이번',
#  '결국',
#  '지존파',
#  '삼',
#  '정당화',
#  '정부',
#  '탓',
#  '사회',
#  '사실',
#  '떠나',
#  '실제',
#  '검술',
#  '싸우',
#  '중국',
#  '하트',
#  '미스',
#  '평균',
#  '충분',
#  '급',
#  '슬',
#  '하기',
#  '자',
#  '모으',
#  '그러',
#  '멋있',
#  '메세지',
#  '빨리',
#  '영화사',
#  '히어로',
#  '놀이',
#  '중심',
#  '사건',
#  '인물',
#  '인간',
#  '레전드',
#  '빌리',
#  '나중',
#  '우연히',
#  '사촌',
#  '제가',
#  '절망',
#  '챙기',
#  '거부',
#  '흐르',
#  '맛',
#  '어마어마',
#  '소피',
#  '똥',
#  '원주민',
#  '일어나',
#  '우',
#  '실제로',
#  '바라',
#  '견자단',
#  '정말로',
#  '또',
#  '순위',
#  '늦',
#  '그런지',
#  '여배우들',
#  '그래픽',
#  '망',
#  '평론가',
#  '도움',
#  '바꾸',
#  '느',
#  '밥',
#  '장난',
#  '악의',
#  '보내',
#  '엄청',
#  '자식',
#  '살아오',
#  '서로',
#  '확실히',
#  '잃',
#  '고의',
#  '생기',
#  '사라지',
#  '공부',
#  '사',
#  '이후',
#  '아픔',
#  '유대인',
#  '인형',
#  '찌',
#  '다운',
#  '감사',
#  '샤넬',
#  '세월',
#  '찰나',
#  '영원',
#  '관하',
#  '두근거리',
#  '멀',
#  '아무리',
#  '용서',
#  '모두',
#  '엔',
#  '딩',
#  '영화관',
#  '몰',
#  '초가',
#  '갑자기',
#  '선생님',
#  '미안',
#  '놀',
#  '쥐',
#  '청춘',
#  '무기',
#  '약간',
#  '빼',
#  '반전',
#  '복수',
#  '해주',
#  '녀',
#  '끌리',
#  '디테일',
#  '완벽',
#  '찡',
#  '평생',
#  '생각나',
#  '짐승',
#  '자막',
#  '문화',
#  '전반',
#  '변화',
#  '벤지',
#  '숨',
#  '막히',
#  '곳곳',
#  '치밀',
#  '싸구려',
#  '밝히',
#  '안되',
#  '질질',
#  '봄',
#  '터지',
#  '겨',
#  '상영',
#  '미화',
#  '라면',
#  '전작',
#  '폭풍',
#  '함부로',
#  '남녀',
#  '웬만',
#  '잘못',
#  '엉성',
#  '차',
#  '싫어하',
#  '매니아',
#  '이하',
#  '아저씨',
#  '역겹',
#  '오르',
#  '공포물',
#  '귀',
#  '타',
#  '은',
#  '벌써',
#  '일찍',
#  '관람',
#  '신분',
#  '최근',
#  '점수',
#  '삼류',
#  '스타',
#  '얼굴',
#  '몸매',
#  '심형래',
#  '전체',
#  '주연',
#  '키',
#  '기키',
#  '엄청나',
#  '초등',
#  '근래',
#  '제작자',
#  '유럽',
#  '호화',
#  '같이',
#  '님',
#  '간만',
#  '영상미',
#  '제작',
#  '공포',
#  '원하',
#  '평',
#  '극장가',
#  '머리',
#  '묻어나',
#  '여정',
#  '독립',
#  '덕',
#  '업',
#  '박수',
#  '끼우',
#  '맞추',
#  '무어',
#  '최루',
#  '걸작',
#  '남편',
#  '외계인',
#  '재밌는 영화',
#  '주온',
#  '쏘',
#  '데리',
#  '라이',
#  '아련',
#  '존재',
#  '도',
#  '기억나',
#  '박사',
#  '록',
#  '철학',
#  '13구역',
#  '남성',
#  '요소',
#  '홍보',
#  '팔',
#  '차라리',
#  '열',
#  '실화',
#  '동생',
#  '디',
#  '아이들',
#  '주목',
#  '뇌',
#  '죽음',
#  '우주',
#  '맡',
#  '여성',
#  '예술',
#  '보통',
#  '고도',
#  '겪',
#  '쉬',
#  '즐기',
#  '분위기',
#  '여주',
#  '시점',
#  '비하',
#  '라이언',
#  '일병',
#  '참고',
#  '자위',
#  '이거',
#  '궁금',
#  '차리',
#  '선정',
#  '솔로',
#  '링',
#  '스타일',
#  '설마',
#  ...]

# %%
# 방법 2
vocab = ['<PAD>', '<UNK>'] + [ word for word, cnt in freq.items() if cnt >= min_count ]
vocab
# Out:
# ['<PAD>',
#  '<UNK>',
#  '더빙',
#  '진짜',
#  '짜증',
#  '나',
#  '목소리',
#  '포스터',
#  '초딩',
#  '영화',
#  '오버',
#  '연기',
#  '가볍',
#  '이야기',
#  '솔직히',
#  '재미',
#  '없',
#  '평점',
#  '돋보이',
#  '늙',
#  '보이',
#  '하',
#  '너무나',
#  '막',
#  '떼',
#  '초등학교',
#  '학년',
#  '용',
#  '별',
#  '반개',
#  '아깝',
#  '원작',
#  '긴장감',
#  '제대로',
#  '살리',
#  '욕',
#  '나오',
#  '생활',
#  '이',
#  '정말',
#  '발로',
#  '반복',
#  '드라마',
#  '가족',
#  '못하',
#  '사람',
#  '액션',
#  '있',
#  '안',
#  '왜',
#  '낮',
#  '꽤',
#  '보',
#  '헐리우드',
#  '화려',
#  '너무',
#  '볼',
#  '때',
#  '눈물',
#  '나서',
#  '죽',
#  '향수',
#  '자극',
#  '감성',
#  '절제',
#  '멜로',
#  '울',
#  '드럽',
#  '담백',
#  '깔끔',
#  '좋',
#  '기사',
#  '보다',
#  '자꾸',
#  '취향',
#  '극장',
#  '가장',
#  '노',
#  '재',
#  '감동',
#  '스토리',
#  '어거지',
#  '참',
#  '웃기',
#  '이기',
#  '코',
#  '까',
#  '고',
#  '깔',
#  '그냥',
#  '난',
#  '이해',
#  '뒤',
#  '갈수록',
#  '재미없',
#  '이건',
#  '깨알',
#  '캐스팅',
#  '내용',
#  '구성',
#  '잘',
#  '러',
#  '드',
#  '위하',
#  '착하',
#  '절대',
#  '뜻',
#  '웃',
#  '가능',
#  '지루',
#  '같',
#  '음식',
#  '만찬',
#  '넘',
#  '별로',
#  '평범',
#  '수작',
#  '드리',
#  '주제',
#  '중반',
#  '다',
#  '납득',
#  '그렇',
#  '꼭',
#  '걸',
#  '끄',
#  '고추',
#  '발',
#  '센스',
#  '연출력',
#  '탁월',
#  '90년대',
#  '포스',
#  '다시',
#  '깨닫',
#  '남',
#  '꽃',
#  '완전',
#  '졸',
#  '쓰레기',
#  '시간',
#  '재밌',
#  '별점',
#  '이리',
#  '기대',
#  '죄인',
#  '아직',
#  '인생',
#  '최고',
#  '대하',
#  '열정',
#  '안나',
#  '대체',
#  '정신',
#  '장애',
#  '작가',
#  '나가',
#  '재미있',
#  '관객',
#  '이렇',
#  '평가',
#  '받',
#  '모르',
#  '단순',
#  '은은',
#  '매력',
#  '알바',
#  '무섭',
#  '거도',
#  '오',
#  '서리',
#  '한',
#  '맘',
#  '들',
#  '방법',
#  '멋지',
#  '배우',
#  '되',
#  '일탈',
#  '잔잔',
#  '음악',
#  '조금',
#  '아쉽',
#  '길',
#  '낭비',
#  '돈',
#  '뛰어나',
#  '크',
#  '공감',
#  '가',
#  '이민기',
#  '캐릭터',
#  '조절',
#  '일',
#  '패',
#  '물건',
#  '극',
#  '초반',
#  '신선',
#  '상태',
#  '불가',
#  '마이너스',
#  '수준',
#  '딱',
#  '알',
#  '만들',
#  '데',
#  '가르',
#  '누',
#  '이랑',
#  '다니',
#  '소설',
#  '속',
#  '제일',
#  '메',
#  '라',
#  '웃음',
#  '감독',
#  '잠시',
#  '잊',
#  '동화',
#  '행복',
#  '르',
#  '게이',
#  '작',
#  '매운맛',
#  '콩',
#  '간다',
#  '가슴',
#  '자체',
#  '꼬마',
#  '깊',
#  '혼자',
#  '어쩌',
#  '충격',
#  '기분',
#  '완전히',
#  '느낌',
#  '무겁',
#  '그저',
#  '일본인',
#  '대단',
#  '생각',
#  '심심',
#  '그대로',
#  '악역',
#  '당황',
#  '중간',
#  '끝나',
#  '일상',
#  '계속',
#  '전개도',
#  '느리',
#  '주인공',
#  '모습',
#  '맨날',
#  '언제',
#  '전개',
#  '좀',
#  '빨리빨리',
#  '사랑',
#  '가슴속',
#  '감정',
#  '예',
#  '말',
#  '많',
#  '큐',
#  '우리나라',
#  '슬프',
#  '깊이',
#  '바로',
#  '노력',
#  '듣',
#  '민간인',
#  '학살',
#  '이정',
#  '살인',
#  '살인자',
#  '예전',
#  '작품',
#  '에피소드',
#  '재탕',
#  '먹',
#  '산',
#  '시청률',
#  '이제',
#  '연기력',
#  '몰입',
#  '비슷',
#  '안보',
#  '신',
#  '노래',
#  '실력',
#  '맞',
#  '일본',
#  '유치',
#  '이틀',
#  '조작',
#  '열리',
#  '집',
#  '들어가',
#  '걸리',
#  '억지',
#  '더',
#  '어설프',
#  '어이없',
#  '결말',
#  '온몸',
#  '폭',
#  '매우',
#  '실망',
#  '한국',
#  '흥행',
#  '갈등',
#  '계',
#  '에',
#  '뻔하',
#  '아햏햏',
#  '시작',
#  '사진',
#  '단연',
#  '우뢰',
#  '매',
#  '진정',
#  '별루',
#  '내일',
#  '좋아하',
#  '가요',
#  '골',
#  '눈',
#  '성룡',
#  '최',
#  '때리',
#  '이쁘',
#  '공주',
#  '인상',
#  '강',
#  '추',
#  '설정',
#  '새롭',
#  '미',
#  '유',
#  '대박',
#  '진심',
#  '영화인',
#  '쓰',
#  '술',
#  '어떻',
#  '킬링타임',
#  '떠오르',
#  '빠지',
#  '쪼',
#  '태어나',
#  '처음',
#  '불륜',
#  '로맨스',
#  '냐',
#  '왕',
#  '아주',
#  '짬뽕',
#  '덜',
#  '거지',
#  '명작',
#  '망치',
#  '소재',
#  '흥미',
#  '끌',
#  '보지',
#  '마라',
#  '특유',
#  '허풍',
#  '현실감',
#  '떨어지',
#  '거북',
#  '도대체',
#  '스스로',
#  '텐',
#  '미국',
#  '따뜻',
#  '삶',
#  '생애',
#  '전부',
#  '지나',
#  '후',
#  '남기',
#  '아니',
#  '순수',
#  '쇼',
#  '허',
#  '문제',
#  '연기자',
#  '전혀',
#  '어울리',
#  '상대',
#  '따로',
#  '아들',
#  '젤',
#  '베',
#  '나라',
#  '믿',
#  '가지',
#  '교훈',
#  '당시',
#  '상황',
#  '케이블',
#  '그만',
#  '다르',
#  '리',
#  '그릇',
#  '뭐',
#  '건지',
#  '한석규',
#  '많이',
#  '면',
#  '여',
#  '전',
#  '힘들',
#  '정도',
#  '마지막',
#  '살짝',
#  '떨',
#  '마',
#  '짱',
#  '이제서야',
#  '감히',
#  '살',
#  '고민',
#  '나이',
#  '여전히',
#  '섹시',
#  '혹시나',
#  '답',
#  '여운',
#  '손',
#  '상업',
#  '충분히',
#  '개인',
#  '잔인',
#  '노출',
#  '화끈',
#  '국산',
#  '아끼',
#  '끝내',
#  '지겹',
#  '드니',
#  '일품',
#  '죽이',
#  '괜찮',
#  '지',
#  '뜨',
#  '찍',
#  '껀',
#  '자신',
#  '어린이',
#  '어리',
#  '낫',
#  '인',
#  '총',
#  '에선',
#  '외국',
#  '상상',
#  '오랜만',
#  '종',
#  '방',
#  '오늘',
#  '요즘',
#  '막장',
#  '그리',
#  '심하',
#  '화이팅',
#  '의',
#  '순정',
#  '사극',
#  '왠지',
#  '코미디',
#  '의하',
#  '장면',
#  '한마디',
#  '존',
#  '유쾌',
#  '치',
#  '앉',
#  '이유',
#  '일반',
#  '통하',
#  '게임',
#  '배경',
#  '거슬리',
#  '엉망',
#  '주',
#  '못',
#  '예산',
#  '물',
#  '인줄',
#  '절',
#  '최악',
#  '아름답',
#  '익숙',
#  '뻑',
#  '읽',
#  '당하',
#  '극치',
#  '굉장히',
#  '남자',
#  '애',
#  '시종일관',
#  '싫',
#  '날',
#  '상당히',
#  '얼마나',
#  '진부',
#  '밖',
#  '티',
#  '짜',
#  '내',
#  '피',
#  '잠',
#  '판타지',
#  '따지',
#  '인격',
#  '어',
#  '옛날',
#  '시절',
#  '추억',
#  '나쁘',
#  '짓',
#  '기존',
#  '쏙',
#  '후회',
#  '도안',
#  '이영화',
#  '남은',
#  '없이',
#  '추천',
#  '싸이코',
#  '개봉',
#  '접하',
#  '순간',
#  '돌아오',
#  '무한',
#  '시리즈',
#  '달',
#  '후세',
#  '표현',
#  '생명',
#  '시노',
#  '출현',
#  '으',
#  '알리',
#  '새벽',
#  '개',
#  '예쁘',
#  '정',
#  '필요',
#  '미묘',
#  '너무너무',
#  '훈훈',
#  '네이버',
#  '장',
#  '가져오',
#  '오우삼',
#  '연출',
#  '인지',
#  '현실',
#  '제로',
#  '그때',
#  '느끼',
#  '대사',
#  '높',
#  '더럽',
#  '닿',
#  '허무',
#  '조연',
#  '꿈',
#  '특집',
#  '훌륭',
#  '판',
#  '의미',
#  '동급',
#  '마음',
#  '소',
#  '하지',
#  '코믹',
#  '짜임새',
#  '허술',
#  '일단',
#  '괴물',
#  '서스펜스',
#  '귀신',
#  '댓글',
#  '한번쯤',
#  '죽기',
#  '직전',
#  '란',
#  '보기',
#  '게',
#  '요',
#  '역',
#  '이그',
#  '기도',
#  '답답',
#  '정치인',
#  '모순',
#  '인가',
#  '전쟁',
#  '묘사',
#  '극장판',
#  '하니',
#  '전화',
#  '개그',
#  '없애',
#  '푸',
#  '세계',
#  '역사',
#  '가치',
#  '감각',
#  '바라보',
#  '색다르',
#  '엄마',
#  '딸',
#  '시키',
#  '제발',
#  '책',
#  '을',
#  '미치',
#  '화',
#  '흑인',
#  '생생',
#  '이상',
#  '아',
#  '굿',
#  '제맛',
#  '범죄',
#  '느와르',
#  '말이',
#  '본인',
#  '피해자',
#  '놓',
#  '기',
#  '필름',
#  '값',
#  '남주인공',
#  '습',
#  '혀',
#  '짧',
#  '소리',
#  '분이',
#  '적당히',
#  '스릴러',
#  '스릴',
#  '전달',
#  '글',
#  '거리',
#  '씩',
#  '부족',
#  '기억',
#  '이름',
#  '두',
#  '언니',
#  '부르',
#  '즐겁',
#  '망하',
#  '아이',
#  '시선',
#  '내내',
#  '먹먹',
#  '레알',
#  '여자',
#  '겁나',
#  '어색',
#  '여주인공',
#  '폭탄',
#  '가나',
#  '보니',
#  '딸리',
#  '개연',
#  '굳',
#  '호구',
#  '세기',
#  '쓸데없이',
#  '류',
#  '중요',
#  '여배우',
#  '고위',
#  '잇',
#  '애니',
#  '제목',
#  '지금',
#  '넘어가',
#  '군가',
#  '얘기',
#  '지루함',
#  '슬픔',
#  '아역',
#  '민폐',
#  '그럴싸',
#  '딱히',
#  '송강호',
#  '비디오',
#  '돌리',
#  '그립',
#  '해석',
#  '닮',
#  '비',
#  '한심',
#  '연예인',
#  '시나리오',
#  '끼',
#  '안타깝',
#  '돌아가',
#  '과',
#  '줄',
#  '영화로',
#  '세상',
#  '비정',
#  '친구',
#  '영상',
#  '다듬',
#  '감',
#  '부분',
#  '비롯',
#  '민망',
#  '군더더기',
#  '진행',
#  '탑',
#  '아빠',
#  '앗',
#  '빠',
#  '애니메이션',
#  '의도',
#  '불쾌',
#  '귀엽',
#  '연인',
#  '5년',
#  '강하',
#  '국민',
#  '해서',
#  '하나님',
#  '이신',
#  '흥미진진',
#  '첨',
#  '해',
#  '탄탄',
#  '점점',
#  '끝',
#  '이번',
#  '결국',
#  '지존파',
#  '삼',
#  '정당화',
#  '정부',
#  '탓',
#  '사회',
#  '사실',
#  '떠나',
#  '실제',
#  '검술',
#  '싸우',
#  '중국',
#  '하트',
#  '미스',
#  '평균',
#  '충분',
#  '급',
#  '슬',
#  '하기',
#  '자',
#  '모으',
#  '그러',
#  '멋있',
#  '메세지',
#  '빨리',
#  '영화사',
#  '히어로',
#  '놀이',
#  '중심',
#  '사건',
#  '인물',
#  '인간',
#  '레전드',
#  '빌리',
#  '나중',
#  '우연히',
#  '사촌',
#  '제가',
#  '절망',
#  '챙기',
#  '거부',
#  '흐르',
#  '맛',
#  '어마어마',
#  '소피',
#  '똥',
#  '원주민',
#  '일어나',
#  '우',
#  '실제로',
#  '바라',
#  '견자단',
#  '정말로',
#  '또',
#  '순위',
#  '늦',
#  '그런지',
#  '여배우들',
#  '그래픽',
#  '망',
#  '평론가',
#  '도움',
#  '바꾸',
#  '느',
#  '밥',
#  '장난',
#  '악의',
#  '보내',
#  '엄청',
#  '자식',
#  '살아오',
#  '서로',
#  '확실히',
#  '잃',
#  '고의',
#  '생기',
#  '사라지',
#  '공부',
#  '사',
#  '이후',
#  '아픔',
#  '유대인',
#  '인형',
#  '찌',
#  '다운',
#  '감사',
#  '샤넬',
#  '세월',
#  '찰나',
#  '영원',
#  '관하',
#  '두근거리',
#  '멀',
#  '아무리',
#  '용서',
#  '모두',
#  '엔',
#  '딩',
#  '영화관',
#  '몰',
#  '초가',
#  '갑자기',
#  '선생님',
#  '미안',
#  '놀',
#  '쥐',
#  '청춘',
#  '무기',
#  '약간',
#  '빼',
#  '반전',
#  '복수',
#  '해주',
#  '녀',
#  '끌리',
#  '디테일',
#  '완벽',
#  '찡',
#  '평생',
#  '생각나',
#  '짐승',
#  '자막',
#  '문화',
#  '전반',
#  '변화',
#  '벤지',
#  '숨',
#  '막히',
#  '곳곳',
#  '치밀',
#  '싸구려',
#  '밝히',
#  '안되',
#  '질질',
#  '봄',
#  '터지',
#  '겨',
#  '상영',
#  '미화',
#  '라면',
#  '전작',
#  '폭풍',
#  '함부로',
#  '남녀',
#  '웬만',
#  '잘못',
#  '엉성',
#  '차',
#  '싫어하',
#  '매니아',
#  '이하',
#  '아저씨',
#  '역겹',
#  '오르',
#  '공포물',
#  '귀',
#  '타',
#  '은',
#  '벌써',
#  '일찍',
#  '관람',
#  '신분',
#  '최근',
#  '점수',
#  '삼류',
#  '스타',
#  '얼굴',
#  '몸매',
#  '심형래',
#  '전체',
#  '주연',
#  '키',
#  '기키',
#  '엄청나',
#  '초등',
#  '근래',
#  '제작자',
#  '유럽',
#  '호화',
#  '같이',
#  '님',
#  '간만',
#  '영상미',
#  '제작',
#  '공포',
#  '원하',
#  '평',
#  '극장가',
#  '머리',
#  '묻어나',
#  '여정',
#  '독립',
#  '덕',
#  '업',
#  '박수',
#  '끼우',
#  '맞추',
#  '무어',
#  '최루',
#  '걸작',
#  '남편',
#  '외계인',
#  '재밌는 영화',
#  '주온',
#  '쏘',
#  '데리',
#  '라이',
#  '아련',
#  '존재',
#  '도',
#  '기억나',
#  '박사',
#  '록',
#  '철학',
#  '13구역',
#  '남성',
#  '요소',
#  '홍보',
#  '팔',
#  '차라리',
#  '열',
#  '실화',
#  '동생',
#  '디',
#  '아이들',
#  '주목',
#  '뇌',
#  '죽음',
#  '우주',
#  '맡',
#  '여성',
#  '예술',
#  '보통',
#  '고도',
#  '겪',
#  '쉬',
#  '즐기',
#  '분위기',
#  '여주',
#  '시점',
#  '비하',
#  '라이언',
#  '일병',
#  '참고',
#  '자위',
#  '이거',
#  '궁금',
#  '차리',
#  '선정',
#  '솔로',
#  '링',
#  '스타일',
#  '설마',
#  ...]

# %% [markdown]
# 토큰화된 문서들을 단어 사전의 위치값에 맞게 인코딩
# - enc_inputs 리스트에 저장

# %%
# 토큰화된 문서들을 인코딩
# 방법 1
stoi = { word:idx for idx, word in enumerate(vocab)}
stoi
# Out:
# {'<PAD>': 0,
#  '<UNK>': 1,
#  '더빙': 2,
#  '진짜': 3,
#  '짜증': 4,
#  '나': 5,
#  '목소리': 6,
#  '포스터': 7,
#  '초딩': 8,
#  '영화': 9,
#  '오버': 10,
#  '연기': 11,
#  '가볍': 12,
#  '이야기': 13,
#  '솔직히': 14,
#  '재미': 15,
#  '없': 16,
#  '평점': 17,
#  '돋보이': 18,
#  '늙': 19,
#  '보이': 20,
#  '하': 21,
#  '너무나': 22,
#  '막': 23,
#  '떼': 24,
#  '초등학교': 25,
#  '학년': 26,
#  '용': 27,
#  '별': 28,
#  '반개': 29,
#  '아깝': 30,
#  '원작': 31,
#  '긴장감': 32,
#  '제대로': 33,
#  '살리': 34,
#  '욕': 35,
#  '나오': 36,
#  '생활': 37,
#  '이': 38,
#  '정말': 39,
#  '발로': 40,
#  '반복': 41,
#  '드라마': 42,
#  '가족': 43,
#  '못하': 44,
#  '사람': 45,
#  '액션': 46,
#  '있': 47,
#  '안': 48,
#  '왜': 49,
#  '낮': 50,
#  '꽤': 51,
#  '보': 52,
#  '비하': 987,
#  '라이언': 988,
#  '일병': 989,
#  '참고': 990,
#  '자위': 991,
#  '이거': 992,
#  '궁금': 993,
#  '차리': 994,
#  '선정': 995,
#  '솔로': 996,
#  '링': 997,
#  '스타일': 998,
#  '설마': 999,
#  ...}

# %%
# 인코딩 함수 정의
def encode(toks):
    result = [ stoi.get(word, stoi['<UNK>']) for word in toks ]
    return result

enc_inputs = [ torch.tensor(encode(toks), dtype=torch.long) for toks in tokens_list]
enc_inputs
# Out:
# [tensor([2, 3, 4, 5, 6]),
#  tensor([ 7,  8,  9, 10, 11, 12]),
#  tensor([], dtype=torch.int64),
#  tensor([ 1, 13, 14, 15, 16, 17,  1]),
#  tensor([ 1, 11, 18,  9,  1, 19, 20, 21,  1, 22]),
#  tensor([23,  1, 24, 25, 26, 27,  9, 28, 29, 30]),
#  tensor([31, 32, 33, 34]),
#  tensor([29, 30, 35, 36,  1,  1, 11, 37, 38, 39, 40,  1,  1, 41, 41, 38, 42, 43,
#          16, 11, 44, 45,  1]),
#  tensor([46, 16, 15, 47, 48,  9]),
#  tensor([49, 17, 50, 51, 52, 53, 54, 55,  1, 47]),
#  tensor([], dtype=torch.int64),
#  tensor([56, 57, 58, 59, 60, 61, 62,  1, 63, 64, 65,  1]),
#  tensor([66,  1,  1,  1, 57,  1,  1, 11, 67]),
#  tensor([68, 69, 70,  1, 71,  1, 72, 52, 73,  1, 45]),
#  tensor([74,  1,  3, 75, 52,  9, 76, 77, 78, 77, 79, 80, 81, 79, 81]),
#  tensor([1, 1]),
#  tensor([82, 45, 83,  1, 84,  1, 85, 86, 87,  1, 84,  1, 88, 89, 86,  1, 90, 20]),
#  tensor([ 1,  1, 91, 49, 92, 93, 94]),
#  tensor([ 95,  39,  96,  97,   1,   1,  98,  99, 100,   1, 101,   1,  96, 102]),
#  tensor([  1, 103,   1, 104, 105]),
#  tensor([  1, 106,  47,  89,   1,   1,   1,   9, 105]),
#  tensor([ 52, 107, 108]),
#  tensor([ 94, 109, 110, 111,   9, 112, 113, 112,  13,  47, 111,  52,  15,  47,
#           95,  52,  16, 111, 114,  48,  36,   1,   1, 114,  48,  36]),
#  tensor([105, 115,   9, 116,   1, 117]),
#  tensor([118,  70, 119, 109]),
#  tensor([120,   1, 121,  16, 122, 123, 122, 124, 125]),
#  tensor([126,   1,  21]),
#  tensor([  1,   1, 127,  11]),
#  tensor([], dtype=torch.int64),
#  tensor([128,  47, 129, 130,  97, 131,  61]),
#  tensor([  1, 132,   1, 133, 134,  21, 135, 136,   1,  11,  39,  70, 137,   1,
#           42]),
#  tensor([138, 139, 140,  30]),
#  tensor([141, 142,  49, 143,  50,   1]),
#  tensor([  1, 144, 145, 145]),
#  tensor([146,  42, 147, 148]),
#  tensor([  1, 149, 150, 151,   1,   1]),
#  tensor([  1,  11,  21, 152, 153, 154,   1, 154]),
#  tensor([  1, 155, 153, 156,   1, 157]),
#  tensor([  7,  47,  20, 158]),
#  tensor([  9,  49, 159, 160, 161, 162]),
#  tensor([163, 164, 165,   9]),
# %%
# 학습 데이터셋, 검증 데이터셋으로 분할
X_train, X_val, Y_train, Y_val = train_test_split(
    enc_inputs, labels_t, test_size=0.2, random_state=42, stratify=labels_t
)

# %%
len(X_train)
# 처음 데이터가 1000개였고 계층화했으나 800개
# Out:
# 800

# %% [markdown]
# ---
# ## 파이토치를 이용해 1차원 합성곱 학습 생성

# %%
import torch.nn as nn
# 데이터셋, 데이터로더
from torch.utils.data import Dataset, DataLoader
# 패딩('<PAD>') 토큰 -> 토큰의 길이를 채워주기 위한 기능
from torch.nn.utils.rnn import pad_sequence
import math

# %%
# 딥러닝에서 사용할 데이터를 파이토치에 맞게 변경
class TextDataset(Dataset):
    def __init__(self, xs, ys):
        # 독립 변수를 객체 안에 저장
        self.xs = xs
        # 종속 변수를 객체 안에 저장
        self.ys = ys
    def __len__(self):
        return len(self.xs)
    def __getitem__(self, idx):
        return self.xs[idx], self.ys[idx]

# %%
# 최대 커널의 개수 -> 몇 개까지의 단어들을 묶어서 확인할 것인가? (n-gram의 수)
# 그에 맞춰 <PAD> 개수 결정
MAX_K = 5

# collate_fn -> Dataset에서 배치만큼 데이터를 가져온 뒤 데이터의 형태를 변경할 때 사용하는 함수
def collate_fn(batch):
    xs, ys = zip(*batch)
    pad_id = stoi['<PAD>']  # 패딩의 위치값 (여기선 0)
    
    # batch -> [ [tensor([]), label ], [ tensor ([]), label ]
    
    # 패딩 토큰 채우기 1차
    # MAX_K보다 xs[i] 길이가 작다면 MAX_K 길이로 패딩 토큰을 채워준다.
    fixed = []
    for x in xs:
        if len(x) < MAX_K:
            # 필요한 패딩 토큰 개수: MAX_K - len(x)
            need = MAX_K - len(x)
            # tensor 데이터에 <PAD>를 채워준다. (결합 함수 cat())
            x = torch.cat(
                [
                    x,
                    torch.full( (need, ), pad_id, dtype=torch.long)
                ]
            )
        fixed.append(x)
    # 패딩 토큰 채우기 2차
    # xs에서 가장 긴 길이에 맞춰 나머지 xs[i]도 패딩 토큰을 추가한다.
    xs_pad = pad_sequence(
        fixed, batch_first= True, padding_value= pad_id
    )
    lengths = torch.tensor([len(x) for x in fixed], dtype=torch.long)
    return xs_pad, torch.stack(ys), lengths

train_loader = DataLoader(
    TextDataset(X_train, Y_train),
    batch_size=8,
    shuffle=True,
    collate_fn=collate_fn
)

val_loader = DataLoader(
    TextDataset(X_val, Y_val),
    batch_size=8,
    shuffle=True,
    collate_fn=collate_fn
)

# %% [markdown]
# 학습 모델 생성 (kim CNN)
# - Embedding
# </br>$\rightarrow$ Conv1D(k = 3, 4, 5)
# </br>$\rightarrow$ max-over-time (해당 구간에서 가장 연관성이 높은 구간 선택)
# </br>$\rightarrow$ concat (kernel별 높은 구간)
# </br>$\rightarrow$ Dropout
# </br>$\rightarrow$ Linear

# %%
# 학습 모델 생성 (kim CNN)
class TextCNN(nn.Module):
    def __init__(
            self,
            vocab_size,                 # 단어 사전의 길이
            emb_dim,                    # 임베딩 벡터의 차원 수
            num_classes,                # 분류 class의 개수
            kernel_size = (3, 4, 5),    # 묶이는 단어의 개수 목록
            num_channel = 100,          # 합성곱한 결과의 차원 개수
            pad_idx = 0,                # 패딩 토큰의 위치 (인덱스)
            dropout = 0.5               # 소실되는 데이터의 비율
    ):
        super().__init__()
        self.emb = nn.Embedding(vocab_size, emb_dim, padding_idx= pad_idx)
        
        # 1차원 합성곱 모델들 --> 3개
        self.convs = nn.ModuleList(
            [
                # nn 안의 1차원 합성곱(input으로 들어가는 채널 개수, out으로 나오는 채널 개수)
                nn.Conv1d(in_channels=emb_dim, out_channels=num_channel, kernel_size= k)
                for k in kernel_size
            ]
        )
        # 100차원의 모델이 3개가 생성되고, 출력들을 단순 결합하면 300차원이 되면서 과적합 위험
        # 일부 데이터를 소실시켜 과적합 방지
        self.dropout = nn.Dropout(dropout)
        # 선형 모델에서는 분류의 형태로 0, 1의 확률이 출력됨
        self.fc = nn.Linear(num_channel * len(kernel_size), num_classes)
        # 초기화
        self.__init_weights()

    # 벡터 초기화 함수
    def __init_weights(self):
        # 자비에르 초기화
        nn.init.xavier_uniform_(self.emb.weight)
        nn.init.xavier_uniform_(self.fc.weight)
        # 합성곱 모델을 초기화
        for conv in self.convs:
            # 비선형 구조에서 사용하는 다중 퍼셉트론 Relu()를 이용하는 경우
            # 학습이 안정되도록 카이밍 초기화 사용
            nn.init.kaiming_uniform_(conv.weight, a = math.sqrt(5))

    # 순전파
    def forward(self, x):
        # x: DataLoader를 통해 들어오는 입력 데이터
        # batch가 된 데이터들을 collate_fn에 대입하여 나온 결과를 순전파에 입력
        x = self.emb(x)
        # -> 배치 크기, 시퀀스의 길이, 임베딩 벡터의 차원 수 형태의 데이터가 생김 (시퀀스 길이 = 토큰의 길이)
        # 순서 바꾸기
        x = x.transpose(1, 2)
        # -> 배치 크기, 임베딩 벡터의 차원 수, 시퀀스의 길이

        feat_maps = []
        # 다중 구조 만들기 -> conv -> Relu -> Max
        for conv in self.convs:
            h = torch.relu(conv(x))             # 사이즈의 형태가 변경됨 -> 배치의 크기, relu의 차원 수, T' = 시퀀스의 길이-커널 사이즈+1
            # h 중 T'의 최댓값
            h = torch.max( h, dim= 2 ).values   # 배치의 크기, relu의 차원 수   # values를 붙여줘야 사이즈가 변환됨. 변환되지 않으면 밑에서 Error남
            feat_maps.append(h)
        # 열을 기준으로 feat_maps 단순 결합
        z = torch.cat(feat_maps, dim=1)     # 배치의 크기, relu의 차원 수 * len(self.conv)
        # 과적합 방지를 위해 일부 데이터를 0으로 변경
        z = self.dropout(z)
        # 선형 모델에서 예측
        logits = self.fc(z)
            
        return logits

# %%
# 학습의 루프 생성

# 모델 생성
model = TextCNN(
    vocab_size= len(vocab),
    emb_dim= 120,           # 차원의 수 = 열의 수
    num_classes= 2,         # 분류 class 종류의 수 (0, 1) -> 2
    kernel_size= (3, 4, 5), # 묶을 단어 개수
    num_channel= 64,        # conv1d에서 output의 차원 수
    pad_idx= stoi['<PAD>'], # 패딩 토큰의 위치
    dropout= 0.5            # (과적합 방지용) 고차원 데이터에서 손실 데이터의 비율
)

# %%
# 옵티마이저 설정
optimizer = torch.optim.Adam(model.parameters(), lr= 3e-3)

# 손실 함수 설정 (예측값과 실젯값의 차이를 계산하는 객체)
criterion = nn.CrossEntropyLoss()

# %%
# 학습, 예측하는 함수 정의
def run_epoch(loader, train = True):
    # loader: model에서 사용할 데이터
    # train: 학습 모드, 평가 모드
    if train:
        model.train()
    else:
        model.eval()
    
    total_loss = 0.0
    correct = 0
    total = 0

    # loader에서 데이터 가져오기
    for x, y, lengths in loader:
        # train 매개변수에 따라 자동 미분을 활성화할 것인가?
        with torch.set_grad_enabled(train):
            logits = model(x)
            loss = criterion(logits, y)
            # 학습 모드라면 -> 옵티마이저, 백워드
            if train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
        total_loss += float(loss.item()) * x.size(0)
        # 예측값 -> [ 확률, 확률 ] -> 높은 확률의 위치
        preds = logits.argmax(dim=1)
        correct += int( (preds == y).sum().item() )
        total = x.size(0)
    
    mean_loss = total_loss / total
    acc = correct / total
    return mean_loss, acc

# %%
for epoch in range(10):
    tr_loss, tr_acc = run_epoch(train_loader, train= True)
    val_loss, val_acc = run_epoch(val_loader, train= False)

    print(f"epoch({epoch}): train loss({tr_loss :.4f}), train acc({tr_acc:.4f})")
    print(f"epoch({epoch}): val loss({val_loss :.4f}), val acc({val_acc:.4f})")
# Out:
# epoch(0): train loss(65.3012), train acc(61.6250)
# epoch(0): val loss(11.9733), val acc(18.7500)
# epoch(1): train loss(36.0162), train acc(83.6250)
# epoch(1): val loss(12.6987), val acc(19.2500)
# epoch(2): train loss(17.8074), train acc(91.5000)
# epoch(2): val loss(16.4387), val acc(19.3750)
# epoch(3): train loss(11.5867), train acc(95.6250)
# epoch(3): val loss(21.8193), val acc(18.3750)
# epoch(4): train loss(8.8505), train acc(95.7500)
# epoch(4): val loss(31.2440), val acc(18.6250)
# epoch(5): train loss(8.0122), train acc(95.5000)
# epoch(5): val loss(27.7343), val acc(19.1250)
# epoch(6): train loss(5.9082), train acc(97.0000)
# epoch(6): val loss(28.9553), val acc(19.3750)
# epoch(7): train loss(4.5932), train acc(97.2500)
# epoch(7): val loss(33.4508), val acc(18.8750)
# epoch(8): train loss(4.0628), train acc(97.8750)
# epoch(8): val loss(32.3298), val acc(19.7500)
# epoch(9): train loss(4.0857), train acc(97.6250)
# epoch(9): val loss(33.4917), val acc(19.6250)

# %%
# test 예측 함수

@torch.no_grad()
def predict(text):
    toks = tokenize(text)
    ids = torch.tensor(encode(toks), dtype=torch.long)
    pad_id = stoi['<PAD>']

    # 모델에서 최대 커널의 크기를 확인 
    max_k = max([m.kernel_size[0] for m in model.convs])

    if len(ids) < max_k:
        need = max_k - len(ids)
        ids  = torch.cat(
            [
                ids, 
                torch.full(
                    (need, ), pad_id, dtype=torch.long
                )
            ]
        )
    x = ids.unsqueeze(0)
    logits = model(x)
    prob = torch.softmax(logits, dim=1).squeeze(0).tolist()
    pred = int(torch.argmax(logits, dim=1).item())
    return prob, pred

p, yhat = predict( "직원의 태도가 별로였고 실망했다" )
print("예측값 : ", yhat)
print("예측 확률 : ", p)
