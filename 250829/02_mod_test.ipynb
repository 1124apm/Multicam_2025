# %% [markdown]
# ### 모듈(Module)

# %%
# 외부의 파일을 로드
# 04_mod_test.ipynb와 mod.py가 같은 위치에 있어야 함
import mod

# %%
# 모듈 안의 변수 호출
mod.test_vari
# Out:
# '모듈 안에 있는 텍스트'

# %%
mod.func_1(10, 4)
# Out:
# 14

# %%
user1 = mod.User('kim', 30)

# %%
user1.work('A')
# Out:
# 입금완료 : 잔액은 10000입니다.
