# %% [markdown]
# ### 연습
# - `ratings_train.txt` 파일 로드
# - 결측치 제거
# - `document` 컬럼의 문자 정규화 (특수문자 제거, 2칸 이상의 공백 제거, 좌우 공백 제거)
# - `document` 컬럼의 중복 제거 + 글자 수가 1개 이하인 행 제거
# - DataFrame에서 임의의 sample(`n = 10000`, `random_state = 42`) 로 데이터를 추출하여 저장
# </br> `head()` $\rightarrow$ 상위 데이터 | `tail()` $\rightarrow$ 하위 데이터 | `sample()` $\rightarrow$ 무작위 데이터
# - train, test 셋으로 8:2 분할
# - sbert 모델은 `'BM-K/KoSimCSE-roberta-multitask'` 이용
# - Dataset을 정의 (Trainer를 이용하지 않고 Dataset과 DataLoader 사용)
#     - 입력받은 document와 label을 document는 SBERT 모델을 이용하여 인코딩
#     - label 데이터를 tensor 형태로 변환
#     - `__len__` 함수는 라벨의 길이를 되돌려준다.
#     - `__getitem__` 함수는 인코딩된 데이터[idx], label[idx]를 되돌려준다
# - train, test를 이용해 Dataset를 생성
# - `DataLoader`를 이용해 `batch_size = 128`, `shuffle = True`로 구성

# %%
import pandas as pd
import numpy as np
import re
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ---
# 파일 로드

# %%
df = pd.read_csv("../data/ratings_train.txt", sep='\t')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        150000 non-null  int64
#  1   document  149995 non-null  object
#  2   label     150000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.4+ MB

# %%
df.columns
# Out:
# Index(['id', 'document', 'label'], dtype='object')

# %%
df.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
# 결측치 처리
df.isna().sum()
# Out:
# id          0
# document    5
# label       0
# dtype: int64

# %%
df.dropna(subset=['document'], inplace=True)

# %% [markdown]
# ---
# `document` 컬럼의 문자 정규화 (특수문자 제거, 2칸 이상의 공백 제거, 좌우 공백 제거)

# %%
def normalize(text):
    text = re.sub(r"[^가-힣0-9a-zA-Z\s\.]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
# Series이므로 apply 사용해도 되지만, DataFrame에는 apply 사용 불가능
df['document'] = df['document'].map(normalize)
df['document']
# Out:
# 0                                                      굳
# 1                                   GDNTOPCLASSINTHECLUB
# 2                 뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아
# 3                       지루하지는 않은데 완전 막장임... 돈주고 보기에는....
# 4        3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠
#                               ...
# 49995            오랜만에 평점 로긴했네 킹왕짱 쌈뽕한 영화를 만났습니다 강렬하게 육쾌함
# 49996       의지 박약들이나 하는거다 탈영은 일단 주인공 김대희 닮았고 이등병 찐따 OOOO
# 49997                 그림도 좋고 완성도도 높았지만... 보는 내내 불안하게 만든다
# 49998     절대 봐서는 안 될 영화.. 재미도 없고 기분만 잡치고.. 한 세트장에서 다 해먹네
# 49999                                         마무리는 또 왜이래
# Name: document, Length: 49997, dtype: object

# %% [markdown]
# ---
# `document` 컬럼의 중복 제거 + 글자 수가 1개 이하인 행 제거

# %%
df.drop_duplicates(subset=['document'], inplace=True)

# %%
flag = df['document'].str.len() > 1
df = df.loc[ flag, ].copy()

# %% [markdown]
# ---
# DataFrame에서 임의의 sample(`n = 10000`, `random_state = 42`) 로 데이터를 추출하여 저장

# %%
df_sample = df.sample(n= 10000, random_state= 42).reset_index(drop= True)
df_sample
# Out:
#             id                                           document  label
# 0      1387469                           바지의 미스터리를 남긴 작품 스판이란 말인가      1
# 1      8403336  영화보고 이렇게빡치는건처음인거같네ㅋㅋ올레티비 천원으로 반짝할인하길래 내용읽어보니까 ...      0
# 2      9805002                71년도 원작영화와 별반 차이가 없다.그리고 잔인하고 엽기적이다      0
# 3      9979651    아 ebs에서 하길래 또 봣는데 역시는 역시다 또 울고말았다 몇번을봐도 눈물 못참는다      1
# 4      2265984                                    이딴것도 드라마라고.. 아휴      0
# ...        ...                                                ...    ...
# 9995   4931303     I had so much fun in this movie !! that's good      1
# 9996   9667858  후속작은 전작과 자동 비교로 덜재미는게 당연시 하는데. 스타트랙은 예외인듯하다. 영...      1
# 9997   6703982                 춘자라던지, 조폭이라던지 하는 막장 개그씬이 꼭 필요했나 싶다      0
# 9998   9579629      아이들이 매우 좋아합니다. 처음에는 무서운듯했으나 나중에는 전혀 무섭지 않아요^^      1
# 9999  10103936                           재밌네요 ㅎㅎ 그냥 보기에는 재밌는 영화!!      1
#
# [10000 rows x 3 columns]

# %% [markdown]
# ---
# train, test 셋으로 8:2 분할

# %%
train_df, test_df = train_test_split(
    df_sample, test_size= 0.2, random_state= 42, stratify= df_sample['label']
)

# %%
train_df['label'].value_counts()
# Out:
# label
# 0    4066
# 1    3934
# Name: count, dtype: int64

# %% [markdown]
# ---
# sbert 모델은 `'BM-K/KoSimCSE-roberta-multitask'` 이용

# %%
model_name = 'BM-K/KoSimCSE-roberta-multitask'
sbert = SentenceTransformer(model_name)
# Out:
# No sentence-transformers model found with name BM-K/KoSimCSE-roberta-multitask. Creating a new one with mean pooling.

# %% [markdown]
# ---
# Dataset을 정의 (Trainer를 이용하지 않고 Dataset과 DataLoader 사용)
# - `__init__(self, document, labels)`
# - 입력받은 document와 labels를 document는 SBERT 모델을 이용하여 인코딩
# - labels 데이터를 tensor 형태로 변환
# - `__len__(self)` 함수는 라벨의 길이를 되돌려준다.
# - `__getitem__(self, idx)` 함수는 인코딩된 데이터[idx], label[idx]를 되돌려준다.

# %%
# Dataset을 상속받음
class SBERTDataset(Dataset):
    # 생성자 함수 -> document, labels를 받아와 document는 임베딩, labels는 tensor화
    def __init__(self, document, labels):
        # no_grad(): 자동 미분 일시 정지
        # inference_mode(): 추론 모드 + 미분 정지
        with torch.inference_mode():
            # 로드한 모델을 이용해 인코딩
            self.emb = sbert.encode(
                document,
                convert_to_tensor= True,    # 결괏값을 tensor 형태로 받을 것인가? (False: list 형태)
                normalize_embeddings= True  # L2 정규화할 것인가?
            )
        # labels를 tensor화
        self.labels = torch.tensor(labels, dtype= torch.long)

    def __len__(self):
        # (tensor화된 labels)의 길이를 반환
        return len(self.labels)
    
    def __getitem__(self, idx):
        return self.emb[idx], self.labels[idx]

# %% [markdown]
# ---
# train, test를 이용해 Dataset를 생성

# %%
# Dataset의 형태로 데이터프레임을 반환
train_ds = SBERTDataset( train_df['document'].tolist(), train_df['label'].tolist() )
test_ds = SBERTDataset( test_df['document'].tolist(), test_df['label'].tolist() )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 2
#       1 # Dataset의 형태로 데이터프레임을 반환
# ----> 2 train_ds = SBERTDataset( train_df['document'].tolist(), train_df['label'].tolist() )
#       3 test_ds = SBERTDataset( test_df['document'].tolist(), test_df['label'].tolist() )
#
# Cell In[63], line 9, in SBERTDataset.__init__(self, document, labels)
#       4 def __init__(self, document, labels):
#       5     # no_grad(): 자동 미분 일시 정지
#       6     # inference_mode(): 추론 모드 + 미분 정지
#       7     with torch.inference_mode():
#       8         # 로드한 모델을 이용해 인코딩
# ----> 9         self.emb = sbert.encode(
#      10             document,
#      11             convert_to_tensor= True,    # 결괏값을 tensor 형태로 받을 것인가? (False: list 형태)
#      12             normalize_embeddings= True  # L2 정규화할 것인가?
#      13         )
#      14     # labels를 tensor화
#      15     self.labels = torch.tensor(labels, dtype= torch.long)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1094, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, truncate_dim, pool, chunk_size, **kwargs)
#    1091 features.update(extra_features)
#    1093 with torch.no_grad():
# -> 1094     out_features = self.forward(features, **kwargs)
#    1095     if self.device.type == "hpu":
#    1096         out_features = copy.deepcopy(out_features)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\SentenceTransformer.py:1175, in SentenceTransformer.forward(self, input, **kwargs)
#    1169             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#    1170         module_kwargs = {
#    1171             key: value
#    1172             for key, value in kwargs.items()
#    1173             if key in module_kwarg_keys or (hasattr(module, "forward_kwargs") and key in module.forward_kwargs)
#    1174         }
# -> 1175     input = module(input, **module_kwargs)
#    1176 return input
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\sentence_transformers\models\Transformer.py:261, in Transformer.forward(self, features, **kwargs)
#     238 """
#     239 Forward pass through the transformer model.
#     240
#    (...)    257         - 'all_layer_embeddings': If the model outputs hidden states, contains embeddings from all layers
#     258 """
#     259 trans_features = {key: value for key, value in features.items() if key in self.model_forward_params}
# --> 261 outputs = self.auto_model(**trans_features, **kwargs, return_dict=True)
#     262 token_embeddings = outputs[0]
#     263 features["token_embeddings"] = token_embeddings
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:862, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     855 # Prepare head mask if needed
#     856 # 1.0 in head_mask indicate we keep the head
#     857 # attention_probs has shape bsz x n_heads x N x N
#     858 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     859 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     860 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 862 encoder_outputs = self.encoder(
#     863     embedding_output,
#     864     attention_mask=extended_attention_mask,
#     865     head_mask=head_mask,
#     866     encoder_hidden_states=encoder_hidden_states,
#     867     encoder_attention_mask=encoder_extended_attention_mask,
#     868     past_key_values=past_key_values,
#     869     use_cache=use_cache,
#     870     output_attentions=output_attentions,
#     871     output_hidden_states=output_hidden_states,
#     872     return_dict=return_dict,
#     873     cache_position=cache_position,
#     874 )
#     875 sequence_output = encoder_outputs[0]
#     876 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:606, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     602     all_hidden_states = all_hidden_states + (hidden_states,)
#     604 layer_head_mask = head_mask[i] if head_mask is not None else None
# --> 606 layer_outputs = layer_module(
#     607     hidden_states,
#     608     attention_mask,
#     609     layer_head_mask,
#     610     encoder_hidden_states,  # as a positional argument for gradient checkpointing
#     611     encoder_attention_mask=encoder_attention_mask,
#     612     past_key_values=past_key_values,
#     613     output_attentions=output_attentions,
#     614     cache_position=cache_position,
#     615 )
#     617 hidden_states = layer_outputs[0]
#     618 if output_attentions:
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:513, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, output_attentions, cache_position)
#     501 @deprecate_kwarg("past_key_value", new_name="past_key_values", version="4.58")
#     502 def forward(
#     503     self,
#    (...)    511     cache_position: Optional[torch.Tensor] = None,
#     512 ) -> tuple[torch.Tensor]:
# --> 513     self_attention_outputs = self.attention(
#     514         hidden_states,
#     515         attention_mask=attention_mask,
#     516         head_mask=head_mask,
#     517         output_attentions=output_attentions,
#     518         past_key_values=past_key_values,
#     519         cache_position=cache_position,
#     520     )
#     521     attention_output = self_attention_outputs[0]
#     522     outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:440, in RobertaAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, past_key_values, output_attentions, cache_position)
#     429 @deprecate_kwarg("past_key_value", new_name="past_key_values", version="4.58")
#     430 def forward(
#     431     self,
#    (...)    438     cache_position: Optional[torch.Tensor] = None,
#     439 ) -> tuple[torch.Tensor]:
# --> 440     self_outputs = self.self(
#     441         hidden_states,
#     442         attention_mask=attention_mask,
#     443         head_mask=head_mask,
#     444         encoder_hidden_states=encoder_hidden_states,
#     445         past_key_values=past_key_values,
#     446         output_attentions=output_attentions,
#     447         cache_position=cache_position,
#     448     )
#     449     attention_output = self.output(self_outputs[0], hidden_states)
#     450     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\models\roberta\modeling_roberta.py:313, in RobertaSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, past_key_values, output_attentions, cache_position)
#     300     return super().forward(
#     301         hidden_states,
#     302         attention_mask,
#    (...)    307         cache_position,
#     308     )
#     310 bsz, tgt_len, _ = hidden_states.size()
#     312 query_layer = (
# --> 313     self.query(hidden_states).view(bsz, -1, self.num_attention_heads, self.attention_head_size).transpose(1, 2)
#     314 )
#     316 is_updated = False
#     317 is_cross_attention = encoder_hidden_states is not None
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File c:\Users\student\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# `DataLoader`를 이용해 `batch_size = 128`, `shuffle = True`로 구성

# %%
# 배치 사이즈 만큼의 데이터를 생성
train_dl = DataLoader(train_ds, batch_size= 128, shuffle= True)
test_dl = DataLoader(test_ds, batch_size= 128, shuffle= True)

# %% [markdown]
# train, test 셋 만들었으니 검증, 예측하면 됨
